# %% [markdown]
# - This is the submission notebook where we will demonstrate different Actions performed in Trilink powered by BigQuery AI
# - You need to setup the datasets required for this process first suing the create_datasets and create_solution_embeddings first

# %%
import os
import sys
from pathlib import Path
# Add project root to sys.path
project_root = Path().resolve().parent  # one level up from notebooks/
sys.path.append(str(project_root))

import time
from datetime import datetime

from src.calltranscripts_simulation import EnhancedCallCenterDataGenerator

import pandas as pd
from google.cloud import bigquery
from pandas_gbq import to_gbq
from pprint import pprint
from src.utils import display_cases,display_agent_performance,display_customer_retention



##Set the project ID and database - Change to your project ID and database
project_id='trilink-472019'
database = 'database'
# Initialize BigQuery client
client = bigquery.Client(project=project_id)
# Load the extension
# %load_ext google.cloud.bigquery
# %load_ext bigquery_magics

# %% [markdown]
# #### Setup BigQuery

# %%
##Authineticate and login to gcloud env
# !gcloud auth login
# !gcloud config set project $project_id
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=muiHof9PVx2WqLC1k4Mkf6pjZ9IcvP&access_type=offline&code_challenge=0LPPfamcV7ZO8X1YgcNT-75D_5c0p-GTeFeWKgjPib8&code_challenge_method=S256
#
#
# You are now logged in as [hazardscarn10@gmail.com].
# Your current project is [trilink-472019].  You can change this setting by running:
#   $ gcloud config set project PROJECT_ID
# Updated property [core/project].

# %% [markdown]
# #### Initial Step
#
# Make sure your setup the project and datasets by running
#
#     1. create_simulated_datasets.ipynb
#     2. create_solution_embeddings.ipynb
#     3. create_models.ipynb
#
# Make sure you have enabled your project bigquery access in IAM

# %% [markdown]
# #### Action 1 - Create Follow Up/Next Best action Email
#
# - Idea is to create a personalized follow-up/Next Best action Email for all customers who called the within 24 hours of their call
#     - We first decide looking at the call transcript if the call needs a follow up email using AI.GENERATE_BOOL for calls in the period of interest (Demo done for 2025-09-15)
#     - For the calls that needs an email, we get their embeddings
#     - For each calls we will do vector search of the call embeddings with all the call transcript embeddings to find similar calls where the agent had a successful solution/conversation with customer. We do this by adding metadata filtering of overall_satisfaction > 6 and the most similar calls. These calls are then used for reference to add additional solutions for the customer which the agent might have missed
#     - For each calls we also do the vector search to the business problem solution table created to find the most similar problem and solution already mentioned by business. This could be used to find the solution that business offers in a similar situation and can help in adding more actionable items in followup email
#     - We will then get the customer and service info of all the products the customers who needs followup email
#     - Then we we will create the Hyper personalized Email with followup/next best action as primary objective and cross/upsell as secondary option for the customers with information like below in the prompt:-
#         - customer details
#         - internet plan details and status
#         - mobile plan details and status
#         - Home security product status and devices bought if any
#         - call transcript for which we are creating the follow up email
#         - similar call for additional solution reference
#         - Upsell/ Cross Sell Product Options to picth, if it seems reasonable to
#     - The whole customers have the email generated and is written to the followup email table, which can be triggered as a daily job to deliver the emails to each customer

# %% [markdown]
# ##### Create the script that creates the followup email for the date period selected
#
# - For demo we are creating the follow up email for the calls that happened from 2025-09-15 to 2025-09-22
# - Enterprises may set it up as daily, weekly or even process by hours depending on the volume
# - A corpus of ~100 calls run under a minute in this single query
# - Business can connect their automated marketing/mail boxes directly to this table to load the email content and send to customer
# - This will add customer satisfaction, clarity, possible cross/upsell

# %%
# %%bigquery  --project {project_id}
# ##Dates for which you want to run the follow up email
# DECLARE cdate1 DATE DEFAULT DATE('2025-09-15');
# DECLARE cdate2 DATE DEFAULT DATE('2025-09-22');
#
# CREATE OR REPLACE TABLE `database.follow_up_emails` AS (
#     WITH target_calls AS (
#   SELECT
#     call_id,
#     customer_id,
#     call_transcript,
#     call_date,
#     AI.GENERATE_BOOL(
#       CONCAT(
#         'Analyze this customer service call transcript and determine if it requires email follow-up. ',
#         'We want to err on the side of caution - SEND EMAIL FOLLOW-UP for ANY call that is NOT purely routine. ',
#         '',
#         'SEND EMAIL FOLLOW-UP if the call involves ANY of these: ',
#         '1. Customer expressed ANY dissatisfaction, frustration, confusion, or unhappiness ',
#         '2. ANY technical issues, problems, complaints, or concerns were mentioned ',
#         '3. ANY solutions, explanations, or troubleshooting steps were provided ',
#         '4. Customer asked questions about products, services, or account details ',
#         '5. ANY account changes, modifications, or requests were discussed ',
#         '6. Customer seemed uncertain or needed clarification on anything ',
#         '7. ANY follow-up actions, callbacks, or next steps were mentioned ',
#         '8. Opportunities for additional services or products were identified ',
#         '9. Customer tone suggested they were not completely satisfied ',
#         '10. Call involved anything beyond the most basic routine transactions. ',
#         '11. Call that says there is a possibility of upsell/cross sell to the customer'
#         '',
#         'ONLY skip email follow-up for these very limited routine cases: ',
#         '- Simple payment made with confirmed success and happy customer ',
#         '- Quick balance inquiry with no issues or questions ',
#         '- Brief, successful IVR navigation with satisfied customer ',
#         '- Standard account verification completed smoothly with no other discussion. ',
#         '',
#         'When in doubt, choose TRUE for email follow-up. Call transcript: "', call_transcript, '"'
#       ),
#       connection_id => 'us.vertex-ai-connection',
#       endpoint => 'gemini-2.5-flash'
#     ).result as email_needed
#
#   FROM `database.call_transcripts_raw`
#   WHERE PARSE_DATE('%Y-%m-%d', call_date) >= cdate1
#     AND PARSE_DATE('%Y-%m-%d', call_date) <= cdate2
# ),
#
# email_calls_with_embeddings AS (
#   SELECT *
#   FROM ML.GENERATE_EMBEDDING(
#     MODEL `database.text_embedding_005_model`,
#     (SELECT
#        call_transcript AS content,
#        call_id,
#        customer_id,
#        call_date,
#        email_needed
#      FROM target_calls
#      WHERE email_needed = TRUE),
#     STRUCT(TRUE AS flatten_json_output, 'RETRIEVAL_DOCUMENT' AS task_type)
#   )
# ),
#
# similar_email_added as (
#   SELECT query.call_id,
#   query.customer_id,
#   query.call_date,
#   query.content,base.call_transcript,base.primary_scenario,base.overall_rating,vs.distance
# FROM
#   VECTOR_SEARCH(
#     TABLE `database.call_transcripts_raw_embeddings`,
#     'call_transcript_embedding',
#     TABLE email_calls_with_embeddings,
#     'ml_generate_embedding_result',
#     top_k => 10,
#     distance_type => 'COSINE') vs
#   WHERE CAST(vs.base.overall_rating AS INT64) > 6
#
# ),
#
# similar_calls_added AS (
#   SELECT
#     call_id,
#     customer_id,
#     call_date,
#     content as current_call_transcript,
#
#     -- Concatenate all similar call transcripts and ratings
#     STRING_AGG(
#       CONCAT(
#         'Rating: ', overall_rating, '/10\n',
#         'Scenario: ', primary_scenario, '\n',
#         'Call: ', call_transcript, '\n\n---\n\n'
#       )
#       ORDER BY CAST(overall_rating AS INT64) DESC, distance ASC
#     ) as all_similar_calls
#
#   FROM similar_email_added
#   GROUP BY call_id, customer_id, call_date, content
# ),
#
# -- Aggregate security devices per customer
# security_aggregated AS (
#   SELECT
#     customer_id,
#     STRING_AGG(device_type, ', ' ORDER BY device_type) AS device_types_concat,
#     COUNT(device_type) AS total_security_devices
#   FROM `database.security_df`
#   GROUP BY customer_id
# ),
#
# --Add the best available solution for the call form the business solution search
# solution_base as
# (
#   SELECT
#     vs.base.problem AS similar_matched_problem,
#     vs.base.solution AS recommended_solution,
#     vs.base.sector AS sector,
#     vs.query.call_id as call_id,
#     vs.distance
#   FROM VECTOR_SEARCH(
#     TABLE `database.business_solution_embeddings`,
#     'problem_embedding',
#       TABLE email_calls_with_embeddings,
#     'ml_generate_embedding_result',
#     top_k => 1,
#     distance_type => 'COSINE'
#   ) AS vs
# ),
#
#
# --Get the current customer services and products and possibility for corrsell or upsell
# base AS (
#   SELECT
#     a.*,
#     e.age,
#     e.city,
#     e.family_size,
#     e.fiber_availability,
#     e.home_ownership,
#     e.home_type,
#     e.life_stage,
#     e.neighborhood_crime_rate,
#     e.work_from_home_flag,
#     b.device_types_concat,
#     b.total_security_devices,
#     c.speed_mbps AS internet_speed,
#     c.plan_tier AS internet_plan,
#     c.contract_type AS internet_contract_type,
#     c.internet_tenure_days,
#     d.plan_type AS mobile_plan,
#     d.contract_type AS mobile_contract_type,
#     d.data_overage_frequency AS mobile_data_overage_frequency,
#     d.monthly_cost AS mobile_monthly_cost,
#     f.similar_matched_problem,
#     f.recommended_solution,
#     f.sector,
#
#     -- Customer type flags
#     CASE WHEN b.device_types_concat IS NULL THEN 0 ELSE 1 END AS security_customer,
#     CASE WHEN c.internet_churn IS NULL THEN 'Never been our internet customer'
#       WHEN c.internet_churn = 1 THEN 'Churned internet customer'
#       ELSE 'Active internet customer' END AS internet_customer_status,
#     CASE WHEN d.mobile_churn IS NULL THEN 'Never been our mobile customer'
#       WHEN d.mobile_churn = 1 THEN 'Churned mobile customer'
#       ELSE 'Active mobile customer'
#     END AS mobile_customer_status
#
#   FROM similar_calls_added a
#   LEFT JOIN security_aggregated b ON a.customer_id = b.customer_id
#   LEFT JOIN `database.customer_df` e ON a.customer_id = e.customer_id
#   LEFT JOIN `database.internet_df` c ON a.customer_id = c.customer_id AND c.internet_churn = 0
#   LEFT JOIN `database.mobile_df` d ON a.customer_id = d.customer_id AND d.mobile_churn = 0
#   LEFT JOIN solution_base f on a.call_id = f.call_id
# )
#
# SELECT
#   call_id,
#   customer_id,
#   call_date,
#   current_call_transcript,
#   all_similar_calls,
#   similar_matched_problem,
#   recommended_solution,
#
#   AI.GENERATE(
#     CONCAT(
#       'Create a personalized follow-up/next best action for solving customers issues email based on this customer call and examples of successful agent approaches.\\n\\n',
#
#       '=== CUSTOMER INFO ===\\n',
#       'Customer ID: ', customer_id, '\\n',
#       'Customer Age: ', age, '\\n',
#       'Customer City: ', city, '\\n',
#       'Customer Family Size: ', family_size, '\\n',
#       'Customer Fiber Availability: ', CASE WHEN fiber_availability THEN 'Yes' ELSE 'No' END, '\\n',
#       'Customer Home Ownership: ', home_ownership, '\\n',
#       'Customer Home Type: ', home_type, '\\n',
#       'Customer Life Stage: ', life_stage, '\\n',
#       'Customer Neighborhood Crime Rate: ', neighborhood_crime_rate, '\\n',
#       'Customer Work From Home Flag: ', CASE WHEN work_from_home_flag THEN 'Yes' ELSE 'No' END, '\\n\\n',
#
#       '=== CUSTOMER CURRENT SERVICES ===\\n',
#       'Internet Status: ', internet_customer_status,
#       CASE WHEN internet_customer_status = 'Active internet customer'
#         THEN CONCAT(' (Plan: ', COALESCE(internet_plan, 'Unknown'), ', Speed: ', COALESCE(CAST(internet_speed AS STRING), 'Unknown'), ' Mbps)')
#         ELSE '' END, '\\n',
#       'Mobile Status: ', mobile_customer_status,
#       CASE WHEN mobile_customer_status = 'Active mobile customer'
#         THEN CONCAT(' (Plan: ', COALESCE(mobile_plan, 'Unknown'), ', Monthly Cost: $', COALESCE(CAST(mobile_monthly_cost AS STRING), 'Unknown'), ')')
#         ELSE '' END, '\\n',
#       'Security Services: ',
#       CASE WHEN security_customer = 1
#         THEN CONCAT('Yes (Devices: ', COALESCE(device_types_concat, 'Unknown'), ', Total: ', COALESCE(CAST(total_security_devices AS STRING), '0'), ')')
#         ELSE 'No security services' END, '\\n\\n',
#
#       '=== CURRENT CALL DETAILS ===\\n',
#       'Date: ', call_date, '\\n',
#       'Call ID: ', call_id, '\\n',
#       'Call Transcript: ', current_call_transcript, '\\n\\n',
#
#       '=== Business Solution ===\\n'
#       'From the business solution guidelines with potential solutions you can use to solve different problems, here is the most similar problem to what customers is\\n',
#       'Similar Problem:',similar_matched_problem,'\\n',
#       'Business Solution to the problem:',recommended_solution,'\\n',
#       'You may use this solution to add any additional solutions that could have been provided for the customer in the follow up email\\n',
#
#
#       '=== AVAILABLE UPGRADE/CROSS-SELL OPTIONS ===\\n',
#       'INTERNET PLANS AVAILABLE:\\n',
#       '• Premium Gig: 1000 Mbps at $100/month\\n',
#       '• Standard: 100 Mbps at $70/month\\n',
#       '• Basic: 25 Mbps at $40/month\\n\\n',
#
#       'MOBILE PLANS AVAILABLE:\\n',
#       '• Limited 2GB: $30/month (Canada only, international $1/min)\\n',
#       '• Limited 5GB: $40/month (Canada only, international $1/min)\\n',
#       '• Limited 10GB: $50/month (Canada only, international $1/min)\\n',
#       '• Unlimited Standard: $70/month (Free North America calls, 7-day international roaming)\\n',
#       '• Unlimited Premium: $90/month (Free worldwide calls, 7-day international roaming, Free Disney Plus for 1 year)\\n\\n',
#
#       'SECURITY DEVICES AVAILABLE:\\n',
#       '• Motion Sensor: $30 each\\n',
#       '• Window Sensor: $30 each\\n',
#       '• Smart Doorbell: $80 (optional $10/month monitoring)\\n',
#       '• Smart Lock: $60\\n',
#       '• Indoor Camera: $120 (audio communication +$30)\\n',
#       '• Outdoor Camera: $220 (optional $10/month monitoring, includes 1-year free Spotlight Pro)\\n',
#       '• Security Panel: $250 (requires $30/month monitoring for alarm setup)\\n\\n',
#
#       '=== SIMILAR SUCCESSFUL APPROACHES ===\\n',
#       'If the current call transcript shows a pending solution, you may reference how other agents handled similar cases:\\n',
#       COALESCE(all_similar_calls, 'No similar high-rated examples found'), '\\n\\n',
#
#       '=== EMAIL INSTRUCTIONS ===\\n',
#       'PRIMARY GOAL: Address the call transcript and provide appropriate follow-up/next best action for solving customers issues\\n',
#       'SECONDARY GOAL (if appropriate): Suggest relevant upgrades/cross-sells that adds business value\\n\\n',
#
#       'CROSS-SELL/UPSELL GUIDELINES:\\n',
#       '• ONLY suggest services they dont currently have or clear upgrades\\n',
#       '• Focus on how it could solve problems mentioned in the call or improve the customers current or future needs\\n',
#       '• Keep suggestions brief - maximum 2-4 sentences\\n',
#       '• Make it sound helpful, not sales-y. Add some small offers (none greater than 15$ for upsells/cross sells)\\n',
#       'Mention what the upsell/cross sell product is, what it offers, what plan it is(if its a mobile or internet one) and how it would be great fit for the customer'
#       '• If customer was upset/angry, DO NOT include any cross or upsell sales suggestions\\n\\n',
#
#       'EMAIL REQUIREMENTS:\\n',
#       '• Start with warm, professional greeting\\n',
#       '• Reference the specific conversation and any issues discussed\\n',
#       '• Provide clear next steps or resolution\\n',
#       '• If appropriate, briefly mention how additional services could help\\n',
#       '• End with contact information for further assistance\\n',
#       '• Sign as "TriLink Customer Success Team"\\n',
#       '• Keep tone personal and human, not automated\\n',
#       '• Total length should be concise but thorough\\n',
#       'Add the cross-sell and upsell options as long as it follows the guidelines',
#         'For upsell/cross sell cases customer could reach out to 1800-TRILINK'
#
#
#       '''****NOTE****:
#       Write the email with natural, personalized language.
#       Avoid placeholder text like [Customer Name],[Customers Full Name], [Company],
#       or other bracketed variables that make emails appear automated. If the customer's name is unknown, use 'Dear Valued Customer' as the greeting.
#
#       If the call transcript have a placeholder name for the customer, igonore that name. Use Dear Valued Customer.
#
#       IMPORTANT: The email should read as if it was written specifically for this recipient by a human, not generated from a template or an AI.'''
#
#     ),
#     connection_id => 'us.vertex-ai-connection',
#     endpoint => 'gemini-2.5-flash'
#   ).result AS personalized_email,
#   age,city,family_size,fiber_availability,home_ownership,home_type,life_stage,neighborhood_crime_rate,work_from_home_flag,device_types_concat,total_security_devices,internet_speed,internet_plan,internet_contract_type,internet_tenure_days,mobile_plan,mobile_contract_type,mobile_data_overage_frequency,mobile_monthly_cost,security_customer
#
# FROM base);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery followup_df  --project {project_id}
# select * from `database.follow_up_emails`;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
print(f"Fallup Email created for :{followup_df.shape[0]} customer calls")
followup_df.head(5)
# Out:
# Fallup Email created for :66 customer calls
#        call_id customer_id   call_date  \
# 0  CALL_000060   C00044296  2025-09-19
# 1  CALL_000313   C00045061  2025-09-21
# 2  CALL_000061   C00036613  2025-09-20
# 3  CALL_000302   C00070124  2025-09-19
# 4  CALL_000105   C00076025  2025-09-17
#
#                              current_call_transcript  \
# 0  **Call Transcript**\n\n**Date:** 2025-09-19\n*...
# 1  **TriLink Telecom Customer Service Call Transc...
# 2  **Call Transcript**\n\n**Date:** 2025-09-20\n*...
# 3  **TriLink Telecom - Customer Service Call Tran...
# 4  **TriLink Telecom Customer Service Transcript*...
#
#                                    all_similar_calls  \
# 0  Rating: 7/10\nScenario: cross_sell_internet\nC...
# 1  Rating: 8/10\nScenario: technical_support\nCal...
# 2  Rating: 7/10\nScenario: payment_assistance\nCa...
# 3  Rating: 7/10\nScenario: cross_sell_mobile\nCal...
# 4  Rating: 7/10\nScenario: contract_renewal\nCall...
#
#                              similar_matched_problem  \
# 0  Customer with Limited_2GB plan hitting data li...
# 1  Customer's window sensor triggering false alar...
# 2  Customer with Limited_2GB plan hitting data li...
# 3  Senior customer paying $85/month for premium p...
# 4  Customer with 8-year service history paying sa...
#
#                                 recommended_solution  \
# 0  Upgrade to Unlimited_Standard $69/month elimin...
# 1  Guide customer through app-based sensor test a...
# 2  Upgrade to Unlimited_Standard $69/month elimin...
# 3  Downgrade to senior-friendly Limited_5GB plan ...
# 4  Activate loyalty rewards with $20 monthly disc...
#
#                                   personalized_email  age      city  ...  \
# 0  Hi Maria,\n\nThank you for speaking with Ashle...   32   Toronto  ...
# 1  Dear Sarah Johnson,\n\nWe're following up on t...   16   Toronto  ...
# 2  Subject: Following Up on Your Call with Robert...   16  Hamilton  ...
# 3  Subject: Following Up on Your Mobile Service I...   46   Toronto  ...
# 4  Subject: Following Up on Your Recent Call with...   63   Toronto  ...
#
#    total_security_devices  internet_speed internet_plan  \
# 0                    <NA>            <NA>          None
# 1                       2            <NA>          None
# 2                    <NA>            <NA>          None
# 3                       2            <NA>          None
# 4                       3            <NA>          None
#
#   internet_contract_type internet_tenure_days  mobile_plan  \
# 0                   None                  NaN         None
# 1                   None                  NaN         None
# 2                   None                  NaN         None
# 3                   None                  NaN         None
# 4                   None                  NaN         None
#
#    mobile_contract_type mobile_data_overage_frequency  mobile_monthly_cost  \
# 0                  None                          <NA>                 <NA>
# 1                  None                          <NA>                 <NA>
# 2                  None                          <NA>                 <NA>
# 3                  None                          <NA>                 <NA>
# 4                  None                          <NA>                 <NA>
#
#    security_customer
# 0                  0
# 1                  1
# 2                  0
# 3                  1
# 4                  1
#
# [5 rows x 28 columns]

# %% [markdown]
# ##### Let's display some sample cases in detail

# %%
display_cases(followup_df,5)
# Out:
# Customer: C00075560 called on 2025-09-16:
# =============================================================================================
# Hyperpersonalized Follow Up Email Generated:
# =============================================================================================
# ('Dear Patricia Miller,\n'
#  '\n'
#  "We're writing to follow up on your recent call with James Thompson on "
#  'September 16th regarding your TriLink services. We understand your '
#  'frustration with the ongoing internet connectivity and speed issues, and we '
#  'sincerely apologize for the inconvenience and disruption this has caused, '
#  'especially given how essential reliable internet is for your work and '
#  'family.\n'
#  '\n'
#  'James has prioritized scheduling a dedicated technician to thoroughly '
#  'investigate and resolve the recurring problems with your internet service. '
#  'As discussed, a senior technician is scheduled to visit your home on '
#  '**Tuesday, September 23rd, between 9 AM and 1 PM**. This visit is crucial to '
#  "diagnose the root cause of the intermittent service you've been experiencing "
#  'and ensure a lasting solution, not just a temporary fix. You will receive a '
#  'confirmation email shortly with these details, and the technician will call '
#  'you when they are on their way.\n'
#  '\n'
#  'Our goal is to provide you with a consistently reliable and high-performing '
#  'internet experience. The technician will conduct a comprehensive line test '
#  'from the pole to your modem, and will ensure your equipment and connection '
#  "are optimized to deliver the speeds you expect. We're committed to getting "
#  "your internet back on track, ensuring it's stable for all your family's "
#  'needs, including your work-from-home schedule.\n'
#  '\n'
#  'Furthermore, as agreed during your call, James has scheduled a follow-up '
#  'call with you for **Wednesday, September 24th, after 2 PM**. This call will '
#  'be to check in on the resolution of your internet issues and to ensure you '
#  'are fully satisfied with your service. Once your internet is performing '
#  'reliably, we can then revisit the discussion about adding mobile services, '
#  'if you are still interested.\n'
#  '\n'
#  'We truly value your long-standing relationship with TriLink, and we are '
#  'committed to making things right. We hope this dedicated technician visit '
#  'will bring a permanent solution to your internet service.\n'
#  '\n'
#  "Should you have any immediate questions before the technician's visit, "
#  "please don't hesitate to reach out to us at 1800-TRILINK.\n"
#  '\n'
#  'Sincerely,\n'
#  '\n'
#  'TriLink Customer Success Team')
# =============================================================================================
# Similar problems and Business solution for it:
# =============================================================================================
# ('Elderly customer struggling with WiFi password changes and router setup, '
#  'frequently losing internet connection, family members constantly providing '
#  'technical support')
# =============================================================================================
# ('Provide managed WiFi service with automatic updates and remote '
#  'troubleshooting. Add senior technical support with phone assistance and '
#  'simplified equipment. Include family account access for remote assistance '
#  'and maintenance scheduling.')
# =============================================================================================
# Call Transcript:
# =============================================================================================
# ('**TriLink Telecom Customer Service Call Transcript**\n'
#  '\n'
#  '**Date:** 2025-09-16\n'
#  '**Customer ID:** C00075560 - Patricia Miller (Age: 56, Upper_Middle Income)\n'
#  '**Agent:** James Thompson (agent_004)\n'
#  '**Agent Specialization:** Retention Specialist\n'
#  '**Agent Experience Level:** 0.7/1.0\n'
#  '**Current Services:** Internet: Standard_100 (100 Mbps) - $67/month, '
#  'Security: 4 devices with monitoring.\n'
#  '**Monthly Bill Total:** $142\n'
#  '**Service Issues History:** 3 recent speed complaints, 5 recent outages, 8 '
#  'total problems.\n'
#  '**Call Reason:** Existing customer interested in adding mobile services.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '**TriLink Telecom (Automated):** Thank you for calling TriLink Telecom. Your '
#  'call may be recorded for quality assurance. Please enter your 10-digit phone '
#  'number or account number.\n'
#  '**(Customer enters number)**\n'
#  '**TriLink Telecom (Automated):** Thank you. Please hold while we connect you '
#  'to the next available representative.\n'
#  '**(Hold music plays for 1 minute, 20 seconds)**\n'
#  '\n'
#  '**Agent James Thompson:** Thank you for calling TriLink Telecom, my name is '
#  'James, how can I help you today?\n'
#  '\n'
#  "**Customer:** Hi James. My name is Patricia Miller, and I'm calling because "
#  "I'm interested in adding mobile service to my existing account. I've been "
#  'with TriLink for a few years for my internet and home security.\n'
#  '\n'
#  "**Agent James Thompson:** Ah, wonderful, Ms. Miller! It's great to hear "
#  "you're considering expanding your services with us. I can definitely help "
#  'you with that. To start, could you please confirm your full name and account '
#  'number for security purposes?\n'
#  '\n'
#  "**Customer:** Sure, it's Patricia Miller, and my account number is "
#  'C00075560.\n'
#  '\n'
#  '**Agent James Thompson:** Thank you, Ms. Miller. Just a moment while I pull '
#  'up your account... Okay, I see your account here. Patricia Miller, account '
#  'C00075560, you have our Standard_100 Internet plan and home security '
#  'monitoring. Is that correct?\n'
#  '\n'
#  "**Customer:** That's right. And that's actually part of why I'm calling. "
#  "Before I even get into mobile, I've been having a *lot* of issues with my "
#  'internet service lately. I mean, a *lot*. Why would I add another service if '
#  "the one I have isn't even working properly?\n"
#  '\n'
#  "**Agent James Thompson:** Oh, I'm very sorry to hear that, Ms. Miller. Let "
#  "me take a look... Hmm, I'm seeing a few notes here about recent service "
#  'issues on your internet connection. Yes, I see three recent complaints '
#  'regarding slow speeds and five reports of outages within the last couple of '
#  'months. And a total of eight service-related issues logged. My apologies for '
#  'the inconvenience these have caused you.\n'
#  '\n'
#  "**Customer:** Inconvenience? James, it's been a nightmare! My internet cuts "
#  'out in the middle of video calls for work, streaming is impossible most '
#  "evenings, and the speeds are nowhere near what I pay for. I'm paying $67 a "
#  "month for 100 Mbps, but I'm lucky if I get 20 sometimes. I've reset my "
#  'router more times than I can count.\n'
#  '\n'
#  '**Agent James Thompson:** I completely understand your frustration, Ms. '
#  "Miller. That's definitely not the experience we want for our customers, "
#  'especially a valued long-term customer like yourself. I see notes from '
#  "previous calls where we've tried some remote troubleshooting, and one where "
#  "a technician visit was scheduled, but, uh, I don't see the resolution notes "
#  'here. Was a technician able to resolve the issue for you?\n'
#  '\n'
#  '**Customer:** A technician came out about a month ago, yes. He fiddled with '
#  'some wires outside and said everything looked good on his end. It worked '
#  "okay for a few days, then it started acting up again, same as before. It's "
#  'like a never-ending cycle. I just gave up calling because it felt like I was '
#  'explaining the same thing over and over.\n'
#  '\n'
#  '**Agent James Thompson:** I see. And I sincerely apologize that the previous '
#  "visit didn't provide a lasting solution. As a retention specialist, my main "
#  "goal is to ensure you're happy with TriLink, and clearly, we're falling "
#  'short on your internet service right now. Would you be open to me scheduling '
#  'another technician visit for you, perhaps with a more senior technician who '
#  'can conduct a thorough line test and check everything from the pole to your '
#  'modem? There would be no charge for this, of course.\n'
#  '\n'
#  '**Customer:** (Sighs) James, I appreciate the offer, but how many times do I '
#  'have to do this? It takes half a day out of my schedule, and it just seems '
#  "to be a temporary fix at best. I was hoping you might have some... I don't "
#  "know, a better solution, or at least acknowledge that I'm not getting the "
#  'service I pay for.\n'
#  '\n'
#  '**Agent James Thompson:** I understand your hesitation, Ms. Miller, and '
#  "you're absolutely right to expect reliable service. Given the repeated "
#  'nature of these issues, a physical inspection is often the most effective '
#  'way to identify the root cause, especially if the problem is intermittent. '
#  'While I can confirm your modem is online and receiving signal *right now*, I '
#  "can't see the historical performance fluctuations or external line damage "
#  "from here. I'm also looking to see if there are any proactive credits for "
#  "the service disruptions, but unfortunately, our system doesn't show any "
#  'automatic adjustments for those past outages. I could potentially apply a '
#  "small credit for your trouble, but it wouldn't fix the underlying problem.\n"
#  '\n'
#  "**Customer:** So, what you're saying is, the only thing you can do for my "
#  'internet is send another technician? And for the outages and slow speeds, '
#  "there's nothing really?\n"
#  '\n'
#  '**Agent James Thompson:** For immediate resolution of the recurring '
#  'technical issues, yes, scheduling a technician is the most direct path '
#  'forward. They have the specialized tools and on-site diagnostic capabilities '
#  "that we don't have remotely. Regarding the outages, I can escalate a request "
#  "for a more detailed review of your service history to see if there's been a "
#  'pattern that our network operations team can investigate on a broader level, '
#  'but that would be a separate process. As for a credit, let me see... I can '
#  "offer you a one-time credit of $15 for the persistent issues you've faced "
#  'recently, as a goodwill gesture.\n'
#  '\n'
#  "**Customer:** Fifteen dollars? My bill is $142 a month! And I've had months "
#  "of this. That barely covers a day of service. Honestly, James, I'm really "
#  'starting to question staying with TriLink at all, let alone adding mobile.\n'
#  '\n'
#  '**Agent James Thompson:** Ms. Miller, I truly apologize that our current '
#  "offerings for resolving this aren't meeting your expectations. I genuinely "
#  'want to help. Perhaps, if we can get a technician scheduled for your '
#  "internet – what's the soonest you'd be available? – we could then revisit "
#  'the mobile plans. We actually have a fantastic bundle promotion right now '
#  'for existing internet customers, where you can get an unlimited mobile line '
#  'for as low as $45 a month, which includes some attractive data features.\n'
#  '\n'
#  "**Customer:** (Pauses, sighs) I... I don't know, James. It feels like you're "
#  'trying to sell me something new when the foundation is crumbling. If I '
#  'schedule another technician, can you guarantee me it will actually *fix* it '
#  'this time? Or is it just another band-aid?\n'
#  '\n'
#  "**Agent James Thompson:** I can't *guarantee* a fix without the technician's "
#  'assessment, Ms. Miller, as the issue is intermittent and on-site. But I can '
#  'assure you that we would prioritize getting a more experienced tech out '
#  'there. We aim to fix things permanently. Let me check the schedule for you. '
#  'How does this Friday afternoon, between 1 PM and 5 PM, sound? Or perhaps '
#  'early next week, Tuesday morning between 9 AM and 1 PM?\n'
#  '\n'
#  '**Customer:** (Hesitates) Friday afternoon... no, I have a meeting. Tuesday '
#  "morning might work. Look, James, I'm really hesitant. I just want reliable "
#  'internet. If you can get someone out Tuesday and they actually fix this, '
#  'then maybe we can talk about mobile. But honestly, if this technician '
#  "doesn't solve it, I'm probably going to start looking at other providers for "
#  '*all* my services.\n'
#  '\n'
#  "**Agent James Thompson:** I completely understand, Ms. Miller. Let's focus "
#  "on getting your internet back to reliable speeds first. I've scheduled a "
#  'priority technician visit for you for Tuesday, September 23rd, between 9 AM '
#  "and 1 PM. You'll receive a confirmation email shortly with the details. The "
#  "technician will call you when they are on their way. I've also made a "
#  'detailed note on your account, outlining the history and the need for a '
#  'thorough investigation to prevent recurrence.\n'
#  '\n'
#  '**Customer:** Okay. (Sighs again) Thank you, James. I really hope this '
#  'works.\n'
#  '\n'
#  "**Agent James Thompson:** I do too, Ms. Miller. I've done everything I can "
#  'from my end to flag this as a critical issue. Once the internet service is '
#  "stable and you're satisfied, please feel free to give us a call back, or I "
#  'can even schedule a follow-up call with you next Wednesday, say, after 2 PM, '
#  "to check in on the internet and then discuss those mobile options if you're "
#  'still interested. How does that sound?\n'
#  '\n'
#  "**Customer:** A follow-up call? Okay, that might be good. Let's do that. "
#  'Next Wednesday, after 2 PM.\n'
#  '\n'
#  "**Agent James Thompson:** Perfect. I'll make a note for a follow-up call for "
#  'you on Wednesday, September 24th, after 2 PM, to review your internet '
#  'service and discuss mobile plans. Is there anything else I can assist you '
#  'with regarding your current services today, Ms. Miller?\n'
#  '\n'
#  "**Customer:** No, I think that's it for now, James. Thank you for your "
#  'time.\n'
#  '\n'
#  '**Agent James Thompson:** Thank you for calling TriLink Telecom, Ms. Miller. '
#  "We appreciate your business and patience, and we'll do our best to get this "
#  'resolved for you. Have a good day.\n'
#  '\n'
#  '**Customer:** You too.\n'
#  '**(Call ends)**')
# =============================================================================================

# %%
display_cases(followup_df,25)
# Out:
# Customer: C00046689 called on 2025-09-17:
# =============================================================================================
# Hyperpersonalized Follow Up Email Generated:
# =============================================================================================
# ('Dear Valued Customer,\n'
#  '\n'
#  'Thank you for speaking with our agent, Lisa Wang, yesterday, September 17th, '
#  'regarding your TriLink services. We appreciate you reaching out and allowing '
#  'us to address your concerns.\n'
#  '\n'
#  "We understand that you've been experiencing frustrating issues with your "
#  'internet service, including slow speeds, buffering, and outages, especially '
#  'given that your home security system relies on a stable connection. We '
#  'sincerely apologize for the inconvenience and frustration this has caused.\n'
#  '\n'
#  'As discussed, our primary focus is to ensure your internet performs '
#  'reliably. To thoroughly investigate and resolve these issues, we have '
#  'scheduled a technician visit for you on **Tuesday, September 23rd, between 1 '
#  'PM and 5 PM**. Our technician will diagnose the problem, check your '
#  'equipment, and ensure that everything is optimized for the best possible '
#  'performance. Please be assured that there will be no charge for this service '
#  'visit, as it pertains to resolving existing service concerns. You will '
#  'receive a confirmation text message shortly with these details.\n'
#  '\n'
#  'We also noted your interest in exploring TriLink mobile services, and we '
#  'understand your hesitation to add new services while your current internet '
#  'performance is a concern. Once your internet service is restored to optimal '
#  'performance, we would be happy to revisit your mobile options to see how '
#  "bundling could potentially offer you value and convenience, as you're "
#  'already a valued internet and security customer.\n'
#  '\n'
#  'Our goal is your complete satisfaction with your TriLink services. We are '
#  'committed to getting your internet working as it should, and we appreciate '
#  'your patience as we work to resolve this.\n'
#  '\n'
#  "If you have any questions before your technician's visit or need further "
#  "assistance, please don't hesitate to call us directly at 1-800-TRILINK.\n"
#  '\n'
#  'Sincerely,\n'
#  '\n'
#  'The TriLink Customer Success Team')
# =============================================================================================
# Similar problems and Business solution for it:
# =============================================================================================
# ('Senior customer paying $85/month for premium plan but only using 1GB data '
#  'monthly for basic calls and messages, concerned about cost on fixed income, '
#  'unfamiliar with plan options')
# =============================================================================================
# ('Downgrade to senior-friendly Limited_5GB plan $35/month saving $50 monthly '
#  'with unlimited talk/text. Add medical alert integration through mobile app. '
#  'Include simplified billing, large-button phone option, and priority senior '
#  'customer support.')
# =============================================================================================
# Call Transcript:
# =============================================================================================
# ('**TriLink Telecom Customer Service Call Transcript**\n'
#  '\n'
#  '**Date:** 2025-09-17\n'
#  '**Agent:** Lisa Wang (agent_005) - Sales Specialist, 0.6 Experience\n'
#  '**Customer ID:** C00046689\n'
#  "**Customer Name:** [Customer Name - Let's assume Ms. Jenkins for the "
#  'transcript]\n'
#  '**Call Reason:** Existing customer interested in adding mobile services.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '**(Call Ringtone – two rings)**\n'
#  '\n'
#  '**Lisa Wang:** Thank you for calling TriLink Telecom, my name is Lisa, how '
#  'can I help you today?\n'
#  '\n'
#  '**Ms. Jenkins:** Hi Lisa, uhm, yeah. My name is Susan Jenkins. My customer '
#  'ID is C00046689. I actually called because I was interested in hearing about '
#  'adding a mobile plan. But, honestly, I also have to say, my internet has '
#  'been just terrible lately.\n'
#  '\n'
#  '**Lisa Wang:** (Typing) Alright, Ms. Jenkins, thank you. Let me just pull up '
#  'your account here with C00046689. Okay, I see that. Susan Jenkins, correct?\n'
#  '\n'
#  "**Ms. Jenkins:** That's me.\n"
#  '\n'
#  "**Lisa Wang:** Perfect. So you're looking into adding mobile service, but "
#  'also experiencing some internet issues. I can definitely help with both of '
#  'those. Before we dive into the mobile options, could you tell me a little '
#  "more about what's going on with your internet connection? I see you have our "
#  'Basic 25 Mbps plan.\n'
#  '\n'
#  "**Ms. Jenkins:** Yeah, the Basic_25. It's supposed to be 25, right? But I "
#  'barely get half that most evenings. I try to watch something on my streaming '
#  "service, and it's constantly buffering. And it's not just slow, it's been "
#  "cutting out entirely! I think it's happened three times in the last month "
#  'alone. My security system, you know, it relies on that internet, and when it '
#  "goes out, I get nervous. I'm paying $45 a month for this and I feel like I'm "
#  'getting maybe $10 worth of service.\n'
#  '\n'
#  "**Lisa Wang:** (Frowning slightly, scanning notes on her screen) I'm sorry "
#  "to hear you're experiencing that, Ms. Jenkins. Let me just check your "
#  "service history. (Pauses, types) Okay, I see here you've had a couple of "
#  'speed complaints logged, and yes, three recent outage reports in the last '
#  "month. You're right, the Basic 25 Mbps plan should provide a consistent "
#  'connection for general use.\n'
#  '\n'
#  '**Ms. Jenkins:** Consistent is a laugh. My total bill is $120 a month with '
#  "the internet and my three security devices, and frankly, that's already a "
#  "stretch for my budget. I don't want to add *more* services if the one I have "
#  "isn't even working properly.\n"
#  '\n'
#  "**Lisa Wang:** I completely understand your concern, Ms. Jenkins. It's "
#  "frustrating when your service isn't performing as expected, especially when "
#  'your security is tied to it. Looking at your plan, the Basic 25 Mbps, while '
#  'usually sufficient, can sometimes feel strained with multiple connected '
#  'devices and especially with the constant data flow from a security '
#  'monitoring system, particularly during peak usage hours in your area. Have '
#  'you tried any basic troubleshooting, like restarting your modem and router?\n'
#  '\n'
#  '**Ms. Jenkins:** Of course I have! Every single time it goes out, I unplug '
#  'it, wait, plug it back in. It works for a bit, then slows down again. And '
#  "restarting it doesn't make it any faster when it's already slow. I shouldn't "
#  'have to troubleshoot my own internet every other day.\n'
#  '\n'
#  "**Lisa Wang:** You're absolutely right, you shouldn't have to. While I'm "
#  'primarily on the sales side, I can see that this is a persistent issue. What '
#  'I can do for your internet, Ms. Jenkins, is schedule a technician to come '
#  'out to your home and thoroughly diagnose the problem. They can check the '
#  'signal to your house, test your equipment, and ensure everything is '
#  'optimized. Sometimes, an older modem might not be handling the speeds as '
#  'efficiently, or there could be an external line issue.\n'
#  '\n'
#  '**Ms. Jenkins:** A technician? Again? One came out about six months ago for '
#  'a similar issue and said everything looked fine, but here we are. Will that '
#  'cost me extra? Because, like I said, my budget is really tight.\n'
#  '\n'
#  "**Lisa Wang:** (Checks system notes) No, Ms. Jenkins, if it's a service "
#  "issue, there typically wouldn't be a charge for the visit. They'd diagnose "
#  'and fix any TriLink equipment or line issues. Would you like me to go ahead '
#  'and schedule that for you?\n'
#  '\n'
#  "**Ms. Jenkins:** (Sighs) Fine. I guess. What days are available? But let's "
#  'get back to the mobile thing. My phone contract is up soon, and I figured '
#  'maybe TriLink could save me some money if I bundle everything.\n'
#  '\n'
#  "**Lisa Wang:** Okay, great. For the technician, I'm showing next Tuesday, "
#  'September 23rd, between 1 PM and 5 PM, or Friday, September 26th, between 9 '
#  'AM and 1 PM. Which of those works better for you?\n'
#  '\n'
#  '**Ms. Jenkins:** Uhm, Tuesday the 23rd, 1 to 5, sounds better.\n'
#  '\n'
#  "**Lisa Wang:** Excellent. So, I've got that scheduled for you. You'll "
#  'receive a confirmation text message shortly. Now, regarding mobile services, '
#  "you're absolutely right, bundling with TriLink can offer significant "
#  'savings. You already have internet and security with us. We have several '
#  "plans, but considering your budget, let me tell you about our 'Essential "
#  "Mobile' plan. It includes 5GB of high-speed data, unlimited talk and text, "
#  'for just $30 a month. And with your existing services, we can apply a bundle '
#  'discount that would bring your internet bill down by another $5, making it '
#  '$40, and the mobile plan would also be reduced to $25. So, instead of a '
#  "separate $30 for mobile, you're looking at a total increase of only $25 on "
#  'your bill for the new mobile line, plus that $5 saving on your internet.\n'
#  '\n'
#  '**Ms. Jenkins:** So my internet would be $40, and the mobile would be $25? '
#  "That's $65, plus my security, which I think is still $75, so that's... $140 "
#  "total? That's *more* than I'm paying now. I thought it was supposed to save "
#  "me money. My current phone is costing me $40 a month. So I'd be saving $15 "
#  'on just the phone, but my overall bill would go up.\n'
#  '\n'
#  '**Lisa Wang:** (Hesitates, recalculating quickly) Let me clarify, Ms. '
#  'Jenkins. Your current internet is $45, and your security is $75, making your '
#  'current total $120. With the bundle, your internet goes to $40, and the '
#  "mobile is $25, so that's $65 for internet and mobile. Add your $75 for "
#  "security... yes, you're right, that would bring your total to $140. It's a "
#  'savings on the *individual* services compared to paying for them separately, '
#  "especially on mobile, but it does increase your overall bill if you're "
#  'adding a new service.\n'
#  '\n'
#  "**Ms. Jenkins:** That's not really a saving then, is it? It's just more "
#  "money out of my pocket. I can't afford $140 a month, especially if the "
#  "internet isn't even working reliably. Why would I add another TriLink "
#  "service if I'm not confident in the one I already have?\n"
#  '\n'
#  '**Lisa Wang:** I understand your hesitation, Ms. Jenkins. My apologies if I '
#  "didn't make the breakdown clear enough. The technician visit should help "
#  "resolve those internet performance issues, and once that's sorted, you might "
#  "find the bundle more appealing. We also have a 'Value Mobile' plan with 10GB "
#  'of data for $40, but the bundle savings are structured similarly.\n'
#  '\n'
#  '**Ms. Jenkins:** So, no cheaper mobile options? No way to get my total bill '
#  'down below $120 *and* add a phone?\n'
#  '\n'
#  '**Lisa Wang:** (Checks notes, thinking) Unfortunately, Ms. Jenkins, our '
#  'entry-level Essential Mobile plan is our most cost-effective option for a '
#  'single line with data. To get your total bill below $120 while adding '
#  "mobile, we'd need to look at removing one of your existing services, like "
#  "the security monitoring, which I don't think you'd want to do.\n"
#  '\n'
#  '**Ms. Jenkins:** No, I need the security. Well, this is frustrating. I guess '
#  "I'll wait for the technician for the internet. If they can actually fix it, "
#  "then maybe I'll call back about mobile. But honestly, I'm not feeling very "
#  'confident right now.\n'
#  '\n'
#  "**Lisa Wang:** I completely understand your position, Ms. Jenkins. I've "
#  'scheduled that technician for you for next Tuesday, September 23rd, between '
#  '1 PM and 5 PM. Hopefully, they can get your internet running smoothly again. '
#  "If you decide to look into mobile again after that, please don't hesitate to "
#  "call us back. We're here to help. Is there anything else I can assist you "
#  'with today regarding your account?\n'
#  '\n'
#  "**Ms. Jenkins:** No, I think that's it for now. Just really hoping that tech "
#  'can figure out the internet.\n'
#  '\n'
#  '**Lisa Wang:** Alright, Ms. Jenkins. Thank you for calling TriLink Telecom, '
#  'and have a good rest of your day.\n'
#  '\n'
#  '**Ms. Jenkins:** You too, Lisa. Bye.\n'
#  '\n'
#  '**Lisa Wang:** Goodbye.\n'
#  '\n'
#  '**(Call Ends)**')
# =============================================================================================

# %% [markdown]
# - A sample where the solution is offered with an upsell pitch also personalized to customer

# %%
display_cases(followup_df,41)
# Out:
# Customer: C00028734 called on 2025-09-18:
# =============================================================================================
# Hyperpersonalized Follow Up Email Generated:
# =============================================================================================
# ('Dear Mr. Chen,\n'
#  '\n'
#  'We understand you recently spoke with our representative, Sarah, on '
#  'September 18th, regarding your upcoming internet contract expiration and the '
#  "service issues you've been experiencing. We also noted that your call was "
#  'transferred for further assistance as you were looking for a more '
#  'satisfactory resolution.\n'
#  '\n'
#  'First and foremost, we want to sincerely apologize for the recent service '
#  'interruptions on September 5th and 12th, as well as the ongoing intermittent '
#  'connectivity issues that have impacted your work and overall experience. '
#  'Your feedback is extremely important to us, and we recognize that reliable '
#  'internet is crucial, especially with your work-from-home needs in Waterloo. '
#  'We are genuinely sorry that your service has not met the standard you expect '
#  'and deserve.\n'
#  '\n'
#  'To ensure we address the root cause of these issues and guarantee you '
#  'receive the reliable service you depend on, our immediate next step is to '
#  'schedule a priority technician visit to your home. Our technician will '
#  'thoroughly inspect your connection, internal wiring, and equipment to '
#  'identify and resolve any underlying problems that may be contributing to the '
#  'outages and intermittent connectivity. This crucial step will help restore '
#  'the stability and quality of your service.\n'
#  '\n'
#  'We understand the loyalty offers discussed during your call may not have '
#  'fully addressed your concerns about value and reliability. We want to assure '
#  'you that as a valued, long-standing customer, we have more comprehensive '
#  'solutions available to ensure your satisfaction. Once your service stability '
#  'is confirmed by the technician, we would like to offer you an exclusive '
#  'loyalty rate for your Standard_100 plan at **$55 per month** for 12 months, '
#  'reflecting a deeper appreciation for your continued business. Furthermore, '
#  'we would like to offer a complimentary 3-month trial of our **Deluxe_300 '
#  'plan (300 Mbps)** at no additional cost upon renewal, allowing you to '
#  'experience a significant speed boost that could greatly enhance your '
#  "work-from-home and family's internet experience after any underlying issues "
#  'are resolved.\n'
#  '\n'
#  'We are committed to resolving your concerns and ensuring you have a reliable '
#  'and positive experience with TriLink. Please call us directly at '
#  '1-800-TRILINK at your earliest convenience to schedule your priority '
#  'technician visit. Our team will be ready to assist you further and discuss '
#  'these enhanced loyalty options after your service has been fully optimized.\n'
#  '\n'
#  'We look forward to speaking with you soon.\n'
#  '\n'
#  'Sincerely,\n'
#  '\n'
#  'The TriLink Customer Success Team')
# =============================================================================================
# Similar problems and Business solution for it:
# =============================================================================================
# ('Customer with 8-year service history paying same rates as new customers, no '
#  'loyalty benefits, considering competitor offers advertising 40% savings for '
#  'switchers')
# =============================================================================================
# ('Activate loyalty rewards with $20 monthly discount retroactive 6 months. '
#  'Provide priority device upgrade at 50% off. Add exclusive pricing on home '
#  'internet 30% below standard rates. Assign dedicated customer success '
#  'representative for VIP treatment.')
# =============================================================================================
# Call Transcript:
# =============================================================================================
# ('**TriLink Telecom Customer Service Call Transcript**\n'
#  '\n'
#  '**Date:** 2025-09-18\n'
#  '**Time:** 10:15 AM EST\n'
#  '**Agent:** Sarah Mitchell (agent_001)\n'
#  '**Customer:** Mr. David Chen (Customer ID: C00028734)\n'
#  '**Call Reason:** Contract expiration and renewal discussions, existing '
#  'service issues.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '**(Call begins with standard IVR prompts and hold music, then connects to '
#  'agent)**\n'
#  '\n'
#  '**Sarah Mitchell:** Thank you for calling TriLink Telecom, my name is Sarah, '
#  'how can I help you today?\n'
#  '\n'
#  "**David Chen:** Hi Sarah, yes, my name is David Chen, and I'm calling "
#  "because my internet contract is expiring soon, and frankly, I'm not very "
#  'happy with my service recently. I want to discuss my options.\n'
#  '\n'
#  '**Sarah Mitchell:** Okay, Mr. Chen, I can certainly help with that. To '
#  'start, could you please confirm your account number or the phone number '
#  'associated with your account?\n'
#  '\n'
#  "**David Chen:** Sure, it's C00028734.\n"
#  '\n'
#  '**Sarah Mitchell:** Thank you, Mr. Chen. Just a moment while I pull up your '
#  'details... (typing sounds) ...Alright, I see your account here. David Chen, '
#  "located at [Customer's Address], is that correct?\n"
#  '\n'
#  "**David Chen:** That's right.\n"
#  '\n'
#  '**Sarah Mitchell:** Perfect. And I see your current service is the '
#  'Standard_100 internet plan, which is 100 Mbps, at $68 per month. Your '
#  "current contract is set to expire on October 31st, 2025. Is that what you're "
#  'referring to?\n'
#  '\n'
#  "**David Chen:** Yes, exactly. So what are my options? Because honestly, I've "
#  'had two significant outages in the last month alone. On September 5th, and '
#  "again just last week, on the 12th. Both times for several hours. When I'm "
#  "paying $68 a month for what's supposed to be reliable internet, it's just "
#  'not acceptable. It disrupted my work, and I even had a video conference '
#  'drop.\n'
#  '\n'
#  '**Sarah Mitchell:** I completely understand your frustration, Mr. Chen. Let '
#  'me check our records here... (typing sounds) ...Yes, I do see those two '
#  'service interruptions logged for your address, one on September 5th from '
#  'approximately 1 PM to 5 PM, and another on September 12th from 9 AM to 2 PM. '
#  "I also see you've had two previous service complaints this year, relating to "
#  "intermittent connectivity. I'm truly sorry for the inconvenience these "
#  'outages have caused, especially disrupting your work.\n'
#  '\n'
#  "**David Chen:** It's more than inconvenient, Sarah. It makes me question why "
#  "I'm staying with TriLink when I'm getting unreliable service at this price. "
#  'So, what are my renewal options? Am I just stuck with the same plan for the '
#  'same price, or worse, a higher price?\n'
#  '\n'
#  "**Sarah Mitchell:** That's a very fair question, Mr. Chen. Let me look at "
#  'the loyalty offers we have available for customers renewing their internet '
#  'service. (typing sounds, slight pause)\n'
#  '\n'
#  "**Sarah Mitchell:** Okay, so I'm seeing a few options for you.\n"
#  'First, you could renew your current Standard_100 plan for another 12 months '
#  'at the same rate of $68 per month.\n'
#  'We also have an offer for our Deluxe_300 plan, which would upgrade you to '
#  "300 Mbps download speed, for $85 per month on a 12-month agreement. It's a "
#  'significant speed boost.\n'
#  "And finally, there's a specific loyalty offer on your current Standard_100 "
#  'plan that would bring the price down to $65 per month for a 12-month '
#  'contract. This includes a small discount for remaining a TriLink customer.\n'
#  '\n'
#  '**David Chen:** (Slight sigh) So, the best you can do is $3 off my current '
#  'unreliable service? After two outages in a month and two prior complaints? '
#  "That doesn't really address the core issue, which is the service quality, "
#  "and frankly, it doesn't feel like much of an incentive to stay. I'm paying "
#  "$68 now, and a $3 discount isn't making up for the hours of lost "
#  'productivity.\n'
#  '\n'
#  '**Sarah Mitchell:** I hear you, Mr. Chen. I truly do understand that the '
#  'discount might not feel substantial given the recent service interruptions. '
#  'These are the specific loyalty offers that are generated in my system for '
#  'your account at this time. Regarding the outages, I can certainly schedule a '
#  'line diagnostic test from our end, or even schedule a technician visit if '
#  "you'd like, to investigate if there's an underlying issue with your "
#  'connection that needs to be resolved. This would be separate from the '
#  'contract renewal.\n'
#  '\n'
#  "**David Chen:** A technician visit? I've had two outages in the last two "
#  'weeks, and prior to that, two complaints about it cutting out '
#  "intermittently. Don't you guys have proactive monitoring? Why am I only "
#  "getting offered a tech visit now? It feels like I'm doing your job for you. "
#  "My primary concern right now isn't just the price, it's the value. I need "
#  "reliable internet. If TriLink can't provide that, then $65 or $68, it's all "
#  "the same. I'd rather pay more for something that works.\n"
#  '\n'
#  "**Sarah Mitchell:** Mr. Chen, I really do apologize that this hasn't been "
#  "addressed to your satisfaction yet. I'm a general specialist, and while I "
#  "can access your account and offer renewal options, I don't have the "
#  "authority to create custom discounts beyond what's available in my system. "
#  'However, I can definitely make a strong note of your service history and '
#  'dissatisfaction. Would you like me to connect you with a supervisor who '
#  'might have access to a wider range of retention offers, or perhaps to our '
#  'technical support team who can really deep-dive into those outage reports '
#  'and see what can be done to improve your stability?\n'
#  '\n'
#  "**David Chen:** (Pause) A supervisor, maybe. Because frankly, I'm just not "
#  "seeing a reason to sign another year right now. I'll just end up in the same "
#  "boat, paying for service that's not consistent. And if a supervisor can't "
#  "offer something more compelling, then I'll seriously be looking at other "
#  'providers. This is getting ridiculous.\n'
#  '\n'
#  "**Sarah Mitchell:** I completely understand your position, Mr. Chen. I'll do "
#  'my best to ensure you speak with someone who can thoroughly address your '
#  'concerns. Please hold for just a moment while I transfer you to a retention '
#  'specialist or supervisor who can review your account with a broader scope of '
#  "options. This might take a few minutes as they can be quite busy, but I'll "
#  'make sure all your notes about the outages and your desire for a better '
#  'offer are included in the transfer.\n'
#  '\n'
#  '**David Chen:** Okay, thanks Sarah. I appreciate you trying.\n'
#  '\n'
#  "**Sarah Mitchell:** You're very welcome, Mr. Chen. One moment please.\n"
#  '\n'
#  '**(Sarah initiates transfer. Hold music begins.)**')
# =============================================================================================

# %% [markdown]
# #### Action 2 - Weekly Agent Performance Evaluation
#
# - Idea is to create comprehensive weekly performance reports for all customer service agents to identify strengths, improvement areas, and provide coaching recommendations
#     - We first extract all calls for each agent within the evaluation week (Demo done for 2025-01-20 to 2025-01-25)
#     - For all calls in the evaluation period, we generate embeddings using the text embedding model
#     - For each agent's call, we perform vector search against all historical call transcript embeddings to find the top 3 most similar calls from OTHER agents with high performance (overall_rating > 6). This creates a benchmark of successful approaches for similar customer scenarios
#     - For each calls we also do the vector search to the business problem solution table created to find the most similar problem and solution already mentioned by business that agent ideally should implement
#     - We then analyze each individual call using AI to identify:
#         - Positive behaviors the agent demonstrated (professional communication, problem-solving, empathy, product knowledge)
#         - Areas where the agent could improve (missed opportunities, communication gaps, process issues)
#         - Specific better approaches the agent could have used based on the successful similar calls from other agents
#     - We aggregate all individual call analyses by agent to create weekly summaries with information like:
#         - Total calls handled, average rating, success rate
#         - All positive behaviors from the week (consolidated into key strengths)
#         - All improvement areas from the week (consolidated into development opportunities)
#         - All coaching suggestions from successful examples (consolidated into actionable recommendations)
#     - Finally, we generate three AI-powered consolidated reports per agent:
#         - **Weekly Positives**: 3-5 bullet points highlighting consistent strengths and good behaviors
#         - **Weekly Negatives**: 3-5 bullet points identifying patterns of improvement opportunities
#         - **Coaching Recommendations**: Specific coaching points, recommended phrases, skills to develop, and techniques for different scenarios
#     - The complete agent performance data is written to the weekly_agent_performance table, which can be used by managers for constructive performance reviews and targeted coaching sessions

# %%
# %%bigquery  --project {project_id}
# --Declare the week date variable
# DECLARE eval_week_start DATE DEFAULT DATE('2025-09-14');
# DECLARE eval_week_end DATE DEFAULT DATE('2025-09-20');
#
# CREATE OR REPLACE TABLE `database.weekly_agent_performance` AS (
#   WITH weekly_calls AS (
#     SELECT
#       agent_id,
#       agent_name,
#       call_id,
#       customer_id,
#       call_transcript,
#       overall_rating,
#       call_successful,
#       customer_monthly_spend,
#       customer_issue_history,
#       call_date,
#       primary_scenario
#     FROM `database.call_transcripts_raw`
#     WHERE PARSE_DATE('%Y-%m-%d', call_date) >= eval_week_start
#       AND PARSE_DATE('%Y-%m-%d', call_date) <= eval_week_end
#   ),
#
#   -- Generate embeddings for each call in the evaluation week
#   weekly_calls_with_embeddings AS (
#     SELECT *
#     FROM ML.GENERATE_EMBEDDING(
#       MODEL `database.text_embedding_005_model`,
#       (SELECT
#          call_transcript AS content,
#          agent_id,
#          agent_name,
#          call_id,
#          customer_id,
#          overall_rating,
#          call_successful,
#          customer_monthly_spend,
#          customer_issue_history,
#          call_date,
#          primary_scenario
#        FROM weekly_calls),
#       STRUCT(TRUE AS flatten_json_output, 'RETRIEVAL_DOCUMENT' AS task_type)
#     )
#   ),
#
#   -- Find similar high-performing calls for each weekly call (LEFT JOIN to preserve all records)
# similar_high_performance_calls AS (
#   SELECT
#     wc.agent_id,
#     wc.agent_name,
#     wc.call_id,
#     wc.customer_id,
#     wc.call_date,
#     wc.call_transcript as current_call_transcript,
#     wc.overall_rating as current_rating,
#     wc.call_successful as current_success,
#     wc.primary_scenario as current_scenario,
#
#     -- Get similar calls (will be NULL if none found)
#     STRING_AGG(
#       CONCAT(
#         'Agent: ', vs.base.agent_name, ' (ID: ', vs.base.agent_id, ')\n',
#         'Rating: ', vs.base.overall_rating, '/10\n',
#         'Success: ', CASE WHEN CAST(vs.base.call_successful AS STRING) = 'true' THEN 'Yes' ELSE 'No' END, '\n',
#         'Scenario: ', vs.base.primary_scenario, '\n',
#         'Call Transcript: ', vs.base.call_transcript, '\n\n---\n\n'
#       )
#       ORDER BY CAST(vs.base.overall_rating AS INT64) DESC, vs.distance ASC
#       LIMIT 3
#     ) as top_similar_calls
#
#   FROM weekly_calls wc  -- Start with ALL weekly calls
#   LEFT JOIN (           -- LEFT JOIN to preserve all
#     SELECT *
#     FROM VECTOR_SEARCH(
#       TABLE `database.call_transcripts_raw_embeddings`,
#       'call_transcript_embedding',
#       TABLE weekly_calls_with_embeddings,
#       'ml_generate_embedding_result',
#       top_k => 10,
#       distance_type => 'COSINE'
#     )
#     WHERE CAST(base.overall_rating AS INT64) > 6
#       AND base.agent_id != query.agent_id
#   ) vs ON wc.call_id = vs.query.call_id
#   GROUP BY
#     wc.agent_id, wc.agent_name, wc.call_id, wc.customer_id,
#     wc.call_date, wc.call_transcript, wc.overall_rating,
#     wc.call_successful, wc.primary_scenario
# ),
#
# --Add the best available solution for the call form the business solution search
# solution_base as
# (
#   SELECT
#     vs.base.problem AS similar_matched_problem,
#     vs.base.solution AS recommended_solution,
#     vs.base.sector AS sector,
#     vs.query.call_id as call_id,
#     vs.distance
#   FROM VECTOR_SEARCH(
#     TABLE `database.business_solution_embeddings`,
#     'problem_embedding',
#       TABLE weekly_calls_with_embeddings,
#       'ml_generate_embedding_result',
#     top_k => 1,
#     distance_type => 'COSINE'
#   ) AS vs
# ),
#
# base as
# (
#   select a.*,b.similar_matched_problem,b.recommended_solution
#    from similar_high_performance_calls a
#   left join solution_base b
#   on a.call_id = b.call_id
# ),
#
#   -- Analyze each individual call for positives, negatives, and improvements
#   individual_call_analysis AS (
#     SELECT
#       agent_id,
#       agent_name,
#       call_id,
#       customer_id,
#       call_date,
#       current_call_transcript,
#       current_rating,
#       current_success,
#       current_scenario,
#       top_similar_calls,
#
#       -- Analyze positive agent behaviors
#       AI.GENERATE(
#         CONCAT(
#           'Analyze this customer service call transcript and identify ALL positive things the agent did well. ',
#           'Focus on realistic agent behaviors within their control and job scope. ',
#           'Look for: professional communication, problem-solving attempts, empathy, product knowledge, ',
#           'following procedures, offering alternatives, setting expectations, active listening, etc.\n\n',
#
#           'Call Details:\n',
#           'Agent: ', agent_name, ' (ID: ', agent_id, ')\n',
#           'Rating: ', current_rating, '/10\n',
#           'Success: ', CASE WHEN CAST(current_success AS STRING) = 'true' THEN 'Yes' ELSE 'No' END, '\n',
#           'Scenario: ', current_scenario, '\n\n',
#
#           'Call Transcript:\n', current_call_transcript, '\n\n',
#
#           'List ONLY the positive things this agent did well in short bullet points. ',
#           'If no significant positives, respond with "No notable positives identified."'
#         ),
#         connection_id => 'us.vertex-ai-connection',
#         endpoint => 'gemini-2.5-flash'
#       ).result AS call_positives,
#
#       -- Analyze negative/improvement areas
#       AI.GENERATE(
#         CONCAT(
#           'Analyze this customer service call transcript and identify areas where the agent could improve. ',
#           'Focus on realistic, actionable feedback within agent control. Be constructive, not punitive. ',
#           'Look for: missed opportunities, communication gaps, process issues, knowledge gaps, ',
#           'empathy lapses, not offering alternatives, unclear explanations, etc.\n\n',
#
#           'Call Details:\n',
#           'Agent: ', agent_name, ' (ID: ', agent_id, ')\n',
#           'Rating: ', current_rating, '/10\n',
#           'Success: ', CASE WHEN CAST(current_success AS STRING) = 'true' THEN 'Yes' ELSE 'No' END, '\n',
#           'Scenario: ', current_scenario, '\n\n',
#
#           'Call Transcript:\n', current_call_transcript, '\n\n',
#
#           'List improvement areas in short bullet points focusing on what agent could control. ',
#           'If no significant issues, respond with "No notable improvement areas identified."'
#         ),
#         connection_id => 'us.vertex-ai-connection',
#         endpoint => 'gemini-2.5-flash'
#       ).result AS call_negatives,
#
#       -- Suggest better approaches based on similar successful calls
#       AI.GENERATE(
#         CONCAT(
#           'Based on this agents call and examples of similar successful calls by other agents, ',
#           'suggest specific things this agent could have done better to improve the outcome.\n\n',
#
#           'CURRENT AGENT CALL:\n',
#           'Agent: ', agent_name, ' (ID: ', agent_id, ')\n',
#           'Rating: ', current_rating, '/10\n',
#           'Success: ', CASE WHEN CAST(current_success AS STRING) = 'true' THEN 'Yes' ELSE 'No' END, '\n',
#           'Scenario: ', current_scenario, '\n',
#           'Transcript: ', current_call_transcript, '\n\n',
#
#                 '=== Business Solution ===\\n'
#       'From the business solution guidelines with potential solutions you can use to solve different problems, here is the most similar problem to what customers is\\n',
#       'Similar Problem:',similar_matched_problem,'\\n',
#       'Business Solution to the problem:',recommended_solution,'\\n',
#       'You may use this solution to add any additional solutions that could have been provided for the customer in the follow up email\\n',
#
#
#           'EXAMPLES OF SUCCESSFUL SIMILAR CALLS:\n',
#           COALESCE(top_similar_calls, 'No similar high-rated examples found'), '\n\n',
#
#           'Based on the successful examples, what specific approaches could ', agent_name, ' have used? ',
#           'Focus on concrete, actionable suggestions like specific phrases, procedures, or techniques. ',
#           'List as short bullet points. If no improvements needed, respond with "Current approach was appropriate."'
#         ),
#         connection_id => 'us.vertex-ai-connection',
#         endpoint => 'gemini-2.5-flash'
#       ).result AS call_improvements
#
#     FROM base
#   ),
#
#   -- Aggregate weekly performance by agent - this should preserve ALL agents
#   weekly_agent_summary AS (
#     SELECT
#       agent_id,
#       agent_name,
#
#       -- Call volume and performance metrics
#       COUNT(*) as total_calls,
#       ROUND(AVG(CAST(current_rating AS FLOAT64)), 1) as avg_rating,
#       COUNT(CASE WHEN CAST(current_success AS STRING) = 'true' THEN 1 END) as successful_calls,
#       ROUND(COUNT(CASE WHEN CAST(current_success AS STRING) = 'true' THEN 1 END) * 100.0 / COUNT(*), 1) as success_rate_pct,
#
#       -- Aggregate all positives from individual calls
#       STRING_AGG(
#         CASE WHEN call_positives != 'No notable positives identified.'
#           THEN call_positives ELSE NULL END,
#         '\n\n'
#       ) as all_call_positives,
#
#       -- Aggregate all negatives from individual calls
#       STRING_AGG(
#         CASE WHEN call_negatives != 'No notable improvement areas identified.'
#           THEN call_negatives ELSE NULL END,
#         '\n\n'
#       ) as all_call_negatives,
#
#       -- Aggregate all improvement suggestions
#       STRING_AGG(
#         CASE WHEN call_improvements != 'Current approach was appropriate.'
#           THEN call_improvements ELSE NULL END,
#         '\n\n'
#       ) as all_call_improvements
#
#     FROM individual_call_analysis
#     GROUP BY agent_id, agent_name
#   )
#
#   -- Final consolidated weekly report
#   SELECT
#     agent_id,
#     agent_name,
#     total_calls,
#     avg_rating,
#     successful_calls,
#     success_rate_pct,
#
#     -- Consolidated positive themes
#     AI.GENERATE(
#       CONCAT(
#         'Analyze all these positive agent behaviors from the week and create a consolidated summary. ',
#         'Group similar behaviors and create short bullet points of key strengths:\n\n',
#         'Agent: ', agent_name, '\n',
#         'Total Calls: ', total_calls, '\n',
#         'Avg Rating: ', avg_rating, '/10\n',
#         'Success Rate: ', success_rate_pct, '%\n\n',
#         'All Positive Behaviors This Week:\n',
#         COALESCE(all_call_positives, 'No notable positives identified across calls'), '\n\n',
#         'Create 3-5 consolidated bullet points highlighting this agents key strengths and consistent positive behaviors.'
#       ),
#       connection_id => 'us.vertex-ai-connection',
#       endpoint => 'gemini-2.5-flash'
#     ).result AS weekly_positives,
#
#     -- Consolidated improvement areas
#     AI.GENERATE(
#       CONCAT(
#         'Analyze all improvement areas from this agents calls this week and create consolidated feedback. ',
#         'Group similar issues and create short bullet points of key improvement opportunities:\n\n',
#         'Agent: ', agent_name, '\n',
#         'Total Calls: ', total_calls, '\n',
#         'Avg Rating: ', avg_rating, '/10\n',
#         'Success Rate: ', success_rate_pct, '%\n\n',
#         'All Improvement Areas This Week:\n',
#         COALESCE(all_call_negatives, 'No notable improvement areas identified across calls'), '\n\n',
#         'Create 3-5 consolidated bullet points highlighting consistent improvement opportunities. ',
#         'Focus on patterns, not individual incidents.'
#       ),
#       connection_id => 'us.vertex-ai-connection',
#       endpoint => 'gemini-2.5-flash'
#     ).result AS weekly_negatives,
#
#     -- Best practices and coaching recommendations
#     AI.GENERATE(
#       CONCAT(
#         'Based on this agents performance and successful examples from other agents, create specific coaching recommendations:\n\n',
#         'Agent: ', agent_name, '\n',
#         'Performance Summary:\n',
#         '- Total Calls: ', total_calls, '\n',
#         '- Avg Rating: ', avg_rating, '/10\n',
#         '- Success Rate: ', success_rate_pct, '%\n\n',
#
#         'Improvement Suggestions From Successful Examples:\n',
#         COALESCE(all_call_improvements, 'No specific improvements identified'), '\n\n',
#
#         'Provide:\n',
#         '1. Top 3-4 specific coaching points with concrete actions\n',
#         '2. Recommended phrases or approaches for common scenarios\n',
#         '3. Skills to focus on for professional development\n',
#         '4. Specific situations where agent should apply different techniques\n\n',
#         'Make recommendations actionable and supportive, focusing on growth opportunities.'
#       ),
#       connection_id => 'us.vertex-ai-connection',
#       endpoint => 'gemini-2.5-flash'
#     ).result AS coaching_recommendations,
#
#     -- Evaluation metadata
#     eval_week_start,
#     eval_week_end,
#     CURRENT_TIMESTAMP() AS report_generated_at
#
#   FROM weekly_agent_summary
#   ORDER BY total_calls DESC
# );
# Out:
# Executing query with job ID: 765fdac1-a1cc-474e-991e-d404fa191c19
# Query executing: 10.67s

# %%
# %%bigquery agent_eval  --project {project_id}
#
# select * from `database.weekly_agent_performance`;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
print(f"Agent Training Data Shape for 10 Agents :{agent_eval.shape[0]}")
agent_eval
# Out:
# Agent Training Data Shape for 10 Agents :10
#     agent_id       agent_name  total_calls  avg_rating  successful_calls  \
# 0  agent_006    Michael Brown           15         5.9                12
# 1  agent_003  Maria Rodriguez           12         5.4                 7
# 2  agent_002       David Chen           12         6.0                10
# 3  agent_010  Carlos Martinez           11         6.3                10
# 4  agent_007   Jennifer Davis            8         5.4                 6
# 5  agent_005        Lisa Wang            7         5.1                 4
# 6  agent_009   Ashley Johnson            7         6.3                 4
# 7  agent_004   James Thompson            7         6.1                 4
# 8  agent_008       Robert Kim            3         6.0                 3
# 9  agent_001   Sarah Mitchell            2         4.5                 0
#
#    success_rate_pct                                   weekly_positives  \
# 0              80.0  Michael Brown consistently demonstrates a stro...
# 1              58.3  Maria Rodriguez consistently demonstrates the ...
# 2              83.3  David Chen consistently demonstrates several k...
# 3              90.9  Carlos Martinez consistently demonstrates exce...
# 4              75.0  Here are Jennifer Davis's key strengths and co...
# 5              57.1  Based on Lisa Wang's positive behaviors from t...
# 6              57.1  Here are 4 consolidated bullet points highligh...
# 7              57.1  Here are 3-5 consolidated bullet points highli...
# 8             100.0  Here are 3-5 consolidated bullet points highli...
# 9               0.0  Here are 3 consolidated bullet points highligh...
#
#                                     weekly_negatives  \
# 0  Michael Brown demonstrates strong foundational...
# 1  Here's a consolidated feedback for Maria Rodri...
# 2  Here are the consolidated improvement areas fo...
# 3  Here are consolidated feedback points highligh...
# 4  Here are the consolidated feedback and key imp...
# 5  Here are the consolidated feedback areas for L...
# 6  Ashley has many opportunities to elevate her c...
# 7  James Thompson shows potential but has several...
# 8  Here is the consolidated feedback for Robert K...
# 9  Here is consolidated feedback for Sarah Mitche...
#
#                             coaching_recommendations eval_week_start  \
# 0  Michael Brown demonstrates a solid foundation ...      2025-09-14
# 1  Maria's performance indicates a significant op...      2025-09-14
# 2  David, your commitment to resolving immediate ...      2025-09-14
# 3  ## Coaching Recommendations for Carlos Martine...      2025-09-14
# 4  Here are specific coaching recommendations for...      2025-09-14
# 5  Here are specific coaching recommendations for...      2025-09-14
# 6  Ashley, your dedication to resolving customer ...      2025-09-14
# 7  Here are specific coaching recommendations for...      2025-09-14
# 8  Here are specific coaching recommendations for...      2025-09-14
# 9  Sarah, your recent call performance indicates ...      2025-09-14
#
#   eval_week_end              report_generated_at
# 0    2025-09-20 2025-09-18 02:53:03.779655+00:00
# 1    2025-09-20 2025-09-18 02:53:03.779655+00:00
# 2    2025-09-20 2025-09-18 02:53:03.779655+00:00
# 3    2025-09-20 2025-09-18 02:53:03.779655+00:00
# 4    2025-09-20 2025-09-18 02:53:03.779655+00:00
# 5    2025-09-20 2025-09-18 02:53:03.779655+00:00
# 6    2025-09-20 2025-09-18 02:53:03.779655+00:00
# 7    2025-09-20 2025-09-18 02:53:03.779655+00:00
# 8    2025-09-20 2025-09-18 02:53:03.779655+00:00
# 9    2025-09-20 2025-09-18 02:53:03.779655+00:00

# %%
display_agent_performance(df_agents=agent_eval.sort_values(by='avg_rating',ascending=True),i=0)
# Out:
# Agent: Sarah Mitchell (ID: agent_001)
# Evaluation Period: 2025-09-14 to 2025-09-20
# Average Rating: 4.50
# Successful Calls: 0 | Success Rate: 0.0%
# ================================================================================
# THINGS YOU EXCEL AT:
# --------------------
# Here are 3 consolidated bullet points highlighting Sarah Mitchell's key strengths and consistent positive behaviors:
#
# *   **Exceptional Customer-Centric Communication:** Sarah consistently demonstrated active listening, expressed genuine empathy for customer frustrations, and maintained a highly professional and polite demeanor, acknowledging specific concerns and impacts throughout her interactions.
# *   **Thorough Problem Assessment and Proactive Solutions:** She effectively leveraged her comprehensive product and system knowledge to accurately assess complex issues, offering a wide range of practical solutions, alternatives, and clear problem-solving paths (e.g., diagnostics, escalations, specialized tickets, plan reviews).
# *   **Reliable Procedural Adherence and Information Management:** Sarah meticulously followed company protocols for account verification, provided accurate account details, thoroughly documented call specifics, and skillfully managed customer expectations and smooth handoffs.
#
# THINGS YOU COULD IMPROVE ON:
# ------------------------------
# Here is consolidated feedback for Sarah Mitchell, grouping similar issues and highlighting key improvement opportunities:
#
# *   **Prioritize and Proactively Address Core Customer Issues:** Sarah frequently delays addressing the fundamental problems (e.g., service outages, system discrepancies, unrecognized services) in favor of less relevant discussions or internal processes (e.g., renewals, upsells). She needs to immediately investigate, validate, and propose solutions for the customer's primary concern before moving to secondary topics.
# *   **Enhance Empathy and Deepen Customer Validation:** While expressing apologies, Sarah often misses opportunities for deeper validation. She should acknowledge and echo the customer's specific emotional state and experience, particularly when they express strong dissatisfaction, describe significant disruption, or when system information contradicts their firm belief.
# *   **Improve Customer-Centric Communication and Effective Resource Utilization:** Sarah's explanations often focus on internal processes and limitations rather than customer benefits. She should translate internal complexities into clear actions and proactively leverage available resources (e.g., specialists, escalation paths) earlier in the conversation to ensure efficient and customer-centric problem resolution.
# *   **Strategic Call Management and Setting Clear Expectations:** Sarah struggles with the appropriate timing of offers and structuring complex calls. She needs to avoid attempting upsells during moments of high customer frustration and consistently summarize all agreed-upon next steps, expectations, and actions, especially when multiple issues are being discussed.
#
# HERE ARE SHORT RECOMMENDATIONS FOR IMPROVING AND GETTING THE BEST:
# ----------------------------------------------------------------------
# Sarah, your recent call performance indicates significant opportunities for growth in crucial areas of customer engagement and problem-solving. Your 0% success rate and average rating of 4.5/10 highlight that customers felt their issues weren't adequately addressed or that their value wasn't recognized.
#
# The detailed examples from your calls provide clear insights into where improvements can be made. This coaching aims to equip you with strategies to build stronger customer relationships, drive successful outcomes, and elevate your confidence in handling complex situations.
#
# ---
#
# ### **1. Top 3-4 Specific Coaching Points with Concrete Actions**
#
# **Coaching Point 1: Elevate Empathy & Ownership to Build Immediate Trust**
# *   **Concrete Action:** Start every interaction with genuine empathy, explicitly validating the customer's frustration or experience. Immediately take ownership for any company-related issues, even if it's a system discrepancy, without making excuses.
# *   **Why it matters:** Customers are often frustrated before they even speak to you. Acknowledging their feelings and showing that you're on their side, rather than just representing the company, disarms them and builds trust. Your current approach might unintentionally sound defensive or dismissive ("I don't seem to have any record," "my system has standard offers").
#
# **Coaching Point 2: Proactive, Holistic & Value-Driven Problem Solving**
# *   **Concrete Action:** Move beyond reactive, isolated solutions. After understanding all customer pain points, proactively offer comprehensive solutions that address underlying concerns (e.g., reliability, total cost, convenience). Emphasize the *value* and *peace of mind* these solutions provide, not just features or prices. This includes leveraging more substantial incentives strategically when appropriate.
# *   **Why it matters:** Offering a small discount or addressing one issue in isolation often fails to satisfy a customer with multiple, deeper frustrations (like Mr. Chen's outages or Ms. Davies' complex billing). A holistic approach demonstrates you understand their overall needs and are invested in their long-term satisfaction.
#
# **Coaching Point 3: Demonstrate Empowerment & Advocate for the Customer**
# *   **Concrete Action:** Whenever standard solutions seem insufficient for a complex or highly frustrated customer, proactively seek exceptions or consult with a team lead *on the customer's behalf*. Clearly communicate that you are personally advocating for them. Structure a clear "path forward" for all issues identified.
# *   **Why it matters:** Customers want to feel heard and that their unique situation is being considered. When you express limitations without showing initiative to overcome them, it can lead to customer churn. Showing you're willing to go the extra mile, even if it means stepping outside the usual process, significantly enhances customer perception and builds loyalty.
#
# ---
#
# ### **2. Recommended Phrases or Approaches for Common Scenarios**
#
# **When a customer expresses frustration or an issue:**
# *   **Instead of:** "I don't seem to have any record..." or "my system has standard offers..."
# *   **Try:**
#     *   "Mr./Ms. [Name], I completely understand your frustration/surprise. It's highly unusual/unacceptable that [issue]. I sincerely apologize for this discrepancy/oversight on our end. My priority right now is to get to the bottom of this for you."
#     *   "This is a serious oversight on TriLink's part, and I assure you we will investigate why [security service] isn't appearing correctly on your account."
#
# **When offering solutions or incentives:**
# *   **Instead of:** "I can offer you a $3 discount..."
# *   **Try:**
#     *   "Mr./Ms. [Name], given the service issues you've experienced, that's certainly not the experience we want for a valued customer like you. If you renew today, we will immediately schedule a priority technician visit at no charge to ensure your line is fully optimized, and as an apology, we'll also apply a **significant one-time credit of [e.g., $X] and a substantial loyalty discount of [e.g., $Y/month]** to your new contract."
#     *   "To provide you with greater peace of mind and ensure stable service, as part of your renewed contract, we can also offer a 'service reliability guarantee' or proactive monitoring with dedicated support to ensure your connection remains stable."
#     *   "With these proactive measures and your new loyalty rate, you'll be getting reliable, high-speed internet that supports your work, *and* the peace of mind knowing we're actively monitoring your connection."
#     *   "Given your [high mobile usage/overage charges] and [internet speed concerns], I can see a clear path to both *save you money* and ensure all your services truly meet your needs. Our [plan] could eliminate your overages entirely, and combined with a review of your internet, we could restructure your package for better value and performance."
#
# **When an issue is complex or requires escalation/advocacy:**
# *   **Instead of:** Immediately transferring or stating system limitations.
# *   **Try:**
#     *   "Mr./Ms. [Name], while my system has standard offers, your situation with recent outages/discrepancies is clearly exceptional. Please allow me a moment to consult with my team lead right now to see if we can get special approval for a more compelling retention package/resolution given your specific challenges." (Then, if approval is given, return with the offer. If not, explain *what* you tried and *why* it wasn't possible, then offer the next best step).
#     *   "So, here's our plan to address everything: First, I'm escalating the [security system] issue with an urgent ticket to our specialized team, and they will reach out within [timeframe]. In the meantime, I can immediately perform a line test for your internet and then walk you through a mobile plan analysis that I believe will better serve your family's needs and potentially reduce your overall bill. How does that sound?"
#     *   "I'll personally follow up with you after the technician visit/security team contact to ensure everything is resolved to your satisfaction."
#
# ---
#
# ### **3. Skills to Focus On for Professional Development**
#
# *   **Active Listening & Empathetic Probing:** Practice listening not just for facts, but for underlying emotions, frustrations, and unstated needs. Ask open-ended questions to fully understand the customer's perspective and priorities.
# *   **De-escalation & Conflict Resolution:** Develop techniques to calm highly frustrated customers, diffuse tension, and redirect conversations towards solutions effectively.
# *   **Value-Based Selling & Strategic Negotiation:** Move beyond simply quoting prices or features. Learn to articulate the *benefits* and *overall value* of solutions, and how to strategically offer incentives (discounts, credits, guarantees) to secure retention and satisfaction.
# *   **Proactive Problem Solving & Critical Thinking:** Enhance your ability to analyze complex customer scenarios, anticipate future issues, and craft holistic solutions that address multiple pain points, rather than just the immediate request.
# *   **Ownership & Empowerment Mindset:** Cultivate a stronger sense of personal responsibility for customer outcomes. Practice advocating for customers, seeking creative solutions, and leveraging internal resources effectively to resolve unique situations.
#
# ---
#
# ### **4. Specific Situations Where Agent Should Apply Different Techniques**
#
# *   **Customer with Service Outages/Technical Frustration (e.g., Mr. Chen):**
#     *   **Techniques:** Immediately apply **"Elevate Empathy & Ownership"** (e.g., "I understand how frustrating unreliable internet is"). Then, use **"Proactive, Holistic & Value-Driven Problem Solving"** by tying service resolution directly to renewal, offering substantial loyalty incentives, and guaranteeing future reliability. **"Demonstrate Empowerment & Advocate"** by offering to personally consult a lead for an exceptional offer.
# *   **Long-Term Customer with Complex Discrepancies/High Bill (e.g., Ms. Davies):**
#     *   **Techniques:** Start with strong **"Elevate Empathy & Ownership"** (e.g., "It's unacceptable that a loyal customer like you is experiencing this"). Immediately **"Demonstrate Empowerment & Advocate"** by taking full company ownership of the discrepancy, escalating the issue internally, and providing a clear, confident path forward for *all* issues. Follow with **"Proactive, Holistic & Value-Driven Problem Solving"** by offering a goodwill credit and structuring a comprehensive plan to optimize all services for better value and performance.
# *   **Customer Mentioning Competitor Offers:**
#     *   **Techniques:** Focus heavily on **"Value-Driven Problem Solving."** Acknowledge the competitor but pivot to highlighting TriLink's unique benefits, personalized support, service guarantees, and tailored loyalty offers that go beyond just price matching. Use **"Demonstrate Empowerment & Advocate"** to see if a special loyalty rate or bundling option can be created.
# *   **Any Customer Expressing a Specific Pain Point (e.g., slow internet, high mobile bill):**
#     *   **Techniques:** Proactively validate *all* existing services early in the call. Then, instead of just fixing that one issue, apply **"Proactive, Holistic & Value-Driven Problem Solving"** to see how you can bundle, save them money overall, or offer greater peace of mind across their entire service portfolio.
#
# ---
#
# Sarah, your willingness to learn and improve is key. By focusing on these areas, you can transform challenging calls into successful customer retention opportunities, significantly boost your ratings, and grow into an even more effective and trusted agent. Your coach will work closely with you to practice these techniques and provide ongoing support.
# ================================================================================

# %%
display_agent_performance(df_agents=agent_eval.sort_values(by='avg_rating',ascending=True),i=4)
# Out:
# Agent: Michael Brown (ID: agent_006)
# Evaluation Period: 2025-09-14 to 2025-09-20
# Average Rating: 5.90
# Successful Calls: 12 | Success Rate: 80.0%
# ================================================================================
# THINGS YOU EXCEL AT:
# --------------------
# Michael Brown consistently demonstrates a strong skill set in customer interactions, characterized by:
#
# *   **Exceptional Empathy and Professional Communication:** Consistently uses a polite, reassuring tone, actively listens to and validates customer frustrations, offers sincere apologies, and clearly communicates even complex technical information in an understandable way.
# *   **Expert Problem Diagnosis and Resolution:** Proactively reviews account history, utilizes in-depth product knowledge, performs thorough diagnostics, accurately identifies root causes, and proposes concrete, effective solutions (e.g., technician dispatches, plan upgrades, or temporary workarounds).
# *   **Proactive Expectation Management and Customer Advocacy:** Meticulously sets clear expectations regarding next steps, timelines, potential costs, and follow-up processes. He advocates for customers by offering goodwill gestures (e.g., credits), documenting issues thoroughly for continuity, and guiding them toward the most beneficial outcomes within his authority.
#
# THINGS YOU COULD IMPROVE ON:
# ------------------------------
# Michael Brown demonstrates strong foundational skills, but consistent patterns emerge across his calls this week that, if addressed, could significantly elevate his customer interactions and success rate.
#
# Here are Michael's key improvement opportunities:
#
# *   **Deepen Empathy and Validate Specific Customer Impact:** While Michael frequently uses empathy statements, he often misses opportunities to explicitly acknowledge the *specific* emotional state, financial constraints, historical issues, and direct impact (e.g., on work, churn risk) that customers voice. This involves mirroring language, validating documented history, and acknowledging the full scope of a customer's frustration more directly.
# *   **Proactive & Holistic Problem Solving for At-Risk Customers:** For customers expressing recurring issues, budget concerns, or churn risk, Michael could be more proactive in offering retention-focused solutions. This includes re-evaluating cost-effective alternatives, framing solutions with clear customer benefits, offering goodwill gestures, ensuring clear pathways for credits, and taking ownership with proactive follow-ups or warm handoffs to specialized departments.
# *   **Enhance Communication Clarity and Proactive Process Management:** Michael can improve by being more transparent and proactive about internal processes and limitations (e.g., credit authority, transfer needs, technician charges, follow-up expectations for credits). Clearly explaining next steps and empowering customers with choices earlier in the call helps set accurate expectations and reduces customer frustration, especially when navigating complex or multi-departmental issues.
#
# HERE ARE SHORT RECOMMENDATIONS FOR IMPROVING AND GETTING THE BEST:
# ----------------------------------------------------------------------
# Michael Brown demonstrates a solid foundation with an 80% success rate in resolving immediate issues, but his average rating of 5.9/10 indicates a significant opportunity to enhance the customer experience. The detailed feedback highlights a need to move beyond functional resolution to truly *satisfying* and *retaining* customers, especially those with complex or recurring issues.
#
# Here are specific coaching recommendations for Michael:
#
# ---
#
# ### **1. Top 3-4 Specific Coaching Points with Concrete Actions**
#
# 1.  **Elevate Empathy & Proactive Acknowledgment of Cumulative Frustration:**
#     *   **Action:** Move beyond generic apologies to explicitly validate the customer's *history* and *cumulative impact* of their issues. Show you understand not just *what* is happening, but *how it makes them feel* and the broader implications (e.g., for work, finances).
#     *   **Goal:** Build deeper rapport and trust, making the customer feel truly heard and understood. This is critical for customers experiencing recurring problems or considering churn.
#
# 2.  **Strategic & Proactive Value Delivery (Credits, Retention, Holistic Solutions):**
#     *   **Action:** Don't wait for customers to ask for credits or loyalty offers. Proactively offer goodwill gestures (like waiving fees/overages or small credits) given persistent issues. Frame potential upgrades or bundles as *cost-saving* or *problem-solving* solutions, leveraging business solution insights to address long-term needs rather than just the immediate symptom.
#     *   **Goal:** Shift from reactive problem-fixing to proactive value-adding, demonstrating TriLink's commitment to the customer's satisfaction and retention, and potentially increasing ARPU through strategic upgrades.
#
# 3.  **Build Confidence & Set Clear, Reassuring Expectations:**
#     *   **Action:** Provide comprehensive reassurance about the resolution process. This includes explicit documentation of detailed notes for technicians, clear reference numbers, definitive statements on charges (especially when waiving them), and proactive instructions for next steps. When explaining technical issues, simplify for clarity and elaborate on *how* the solution will address their specific pain points.
#     *   **Goal:** Reduce customer anxiety, instill confidence in the proposed solution, and minimize follow-up calls by making expectations transparent and manageable.
#
# 4.  **Take Holistic Ownership & Empower Through Options:**
#     *   **Action:** View the customer's entire account and all their expressed frustrations (internet, mobile, billing) as interconnected. Offer warm transfers for issues outside immediate scope, commit to personal follow-ups, and present solutions (technical fixes, plan changes, credits) as a comprehensive package. Empower customers by giving them options and explaining the benefits of each.
#     *   **Goal:** Streamline the customer's journey, prevent them from having to repeat their story, and present a unified, efficient path to resolution, enhancing overall satisfaction.
#
# ---
#
# ### **2. Recommended Phrases or Approaches for Common Scenarios**
#
# *   **When a customer expresses frustration about *recurring* issues:**
#     *   *Instead of:* "I understand your frustration."
#     *   *Try:* "I truly apologize that you're experiencing these *repeated* issues, Mr./Ms. [Name]. I understand this isn't a new problem, and that's incredibly frustrating, especially when your internet is so critical for your work. Let's make sure we get to the root of this." (Similar to David Chen)
#     *   *Approach:* Acknowledge the history, validate the specific impact (e.g., work, family), and immediately signal a commitment to a lasting solution.
#
# *   **When discussing potential technician charges for an issue on TriLink's end:**
#     *   *Instead of:* "It's highly unlikely you'd be charged."
#     *   *Try:* "Based on our diagnostics showing an issue on our end, I can confirm that **we will waive the standard service call fee for this visit.** You will not be charged for the technician to come out and resolve this problem." (Similar to David Chen)
#     *   *Approach:* Be definitive and proactive to immediately ease a major customer concern and build trust.
#
# *   **When a customer mentions considering other providers/retention concerns:**
#     *   *Instead of:* Just acknowledging the sentiment.
#     *   *Try:* "I absolutely understand your concern about looking into other providers. Please know we truly value your business, and my priority is to ensure this issue is resolved permanently so you don't have to consider that. I'll personally make a note to follow up with you a day or two after the technician visit to confirm everything is working smoothly."
#     *   *Approach:* Acknowledge, commit to retention, and offer a concrete, personalized follow-up.
#
# *   **When presenting an upgrade or bundle as a solution (especially for overages/speed):**
#     *   *Instead of:* "The new plan costs $X more per month."
#     *   *Try:* "I hear your frustration with the data overages. Many customers in your situation find our Unlimited_Standard plan a much better value. It could actually *save you money* compared to your current plan plus typical overages, and provide the peace of mind you need. For instance, if you're currently paying $60 + $15-20 in overages, moving to the $69 unlimited plan means you'd get more data for less overall, with no surprises." (Leveraging business solution)
#     *   *Approach:* Frame it as a solution to a pain point and a *value proposition* (saving money, peace of mind) rather than just an increased cost. Mention promotional offers if available ("first 3 months at 50% off").
#
# *   **When scheduling a technician and reinforcing the fix:**
#     *   *Instead of:* "We'll do our best."
#     *   *Try:* "Our technicians are highly trained to resolve these types of issues. They will thoroughly investigate everything and implement a solution. If for any reason the technician is unable to resolve it on-site, they will escalate the issue to our network engineering team, and we'll ensure it gets fixed. My goal, and the technician's goal, is to get your internet working reliably for you." (Similar to David Chen)
#     *   *Approach:* Provide detailed assurance, explain escalation paths, and emphasize commitment to a full resolution.
#
# ---
#
# ### **3. Skills to Focus On for Professional Development**
#
# 1.  **Advanced Empathetic Communication:** Developing the ability to truly hear, validate, and articulate understanding of a customer's underlying emotions and cumulative frustrations, not just the surface problem. This includes active listening, reflective statements, and emotional intelligence.
# 2.  **Proactive Solution Design & Value Selling:** Learning to identify unspoken needs or long-term pain points (e.g., WFH, recurring overages) and proactively presenting holistic solutions (e.g., bundles, upgrades, loyalty offers) that align with the customer's financial and service goals, framing them as value-added or cost-saving.
# 3.  **Retention & De-escalation Strategies:** Mastering techniques to acknowledge retention threats, offer compelling reasons to stay, and skillfully navigate difficult conversations by offering tangible goodwill and a clear path to resolution, often involving discretionary powers.
# 4.  **Confident Account Ownership & Escalation Management:** Gaining confidence in making discretionary offers (credits, fee waivers) when justified, or seamlessly warm transferring to specialists (e.g., Retention, Mobile Support) while maintaining a sense of ownership and ensuring the customer's journey remains smooth.
#
# ---
#
# ### **4. Specific Situations Where Agent Should Apply Different Techniques**
#
# *   **Customer expresses frustration about *any recurring* issue (internet, mobile, billing):** Immediately apply **Elevated Empathy** and proactively consider **Strategic Value Delivery** (e.g., a goodwill credit, fee waiver) before proceeding with diagnostics.
# *   **Customer explicitly mentions *cost, billing, or potential overages*:** This is a prime opportunity for **Strategic Value Delivery**. Proactively offer to waive overages or present a plan upgrade as a cost-saving measure with promotional incentives, framing it as a long-term solution.
# *   **Customer expresses *apprehension about a technician visit* (e.g., "What if they can't fix it?", "Will I be charged?"):** Immediately apply **Confidence Building** by definitively waiving fees (if applicable), reassuring them about the technician's expertise, explaining detailed work order notes, and outlining escalation paths.
# *   **Customer mentions *work-from-home (WFH) or critical reliance on service*:** This triggers the need for **Holistic Ownership**. Beyond fixing the immediate issue, Michael should subtly probe for deeper WFH needs and proactively suggest long-term reliability solutions (e.g., higher internet tiers, backup hotspots, managed Wi-Fi).
# *   **Customer has *multiple, interconnected issues* (e.g., internet speed + mobile overages + security cameras):** This calls for **Holistic Ownership**. Michael should acknowledge all issues, frame the resolution as a comprehensive approach, and confidently offer warm transfers for parts he can't directly resolve, ensuring a seamless experience.
# *   **Customer mentions *their contract ending or considering competitor*:** This is a clear retention trigger. Michael should immediately apply **Elevated Empathy** and **Proactive Value Delivery**, considering a warm transfer to Retention with a strong value proposition, or offering loyalty discounts/promotions directly if empowered.
# ================================================================================

# %% [markdown]
# #### Action 3 - ML-Powered Personalized Retention Emails
#
# **Idea**: Transform traditional churn prediction models into hyper-personalized retention campaigns that address individual customer risk factors
#
# **The Problem**:
# - Business ML models predict churn events but only generate generic target lists
# - All high-risk customers receive identical "cookie-cutter" retention messages
# - Rich model insights about WHY customers churn are completely ignored
# - A/B testing still uses generic content variations instead of personalized approaches
#
# **The Solution**:
# - **Build XGBoost churn models** in BigQuery ML for internet and mobile customers
# - **Use ML.EXPLAIN_PREDICT** to extract individual feature contributions (not just probability)
# - **AI-analyze risk factors** to convert technical features into customer pain points
# - **Vector-match business solutions** to find proven approaches for similar problems
# - **Generate personalized emails** that address specific churn drivers for each customer
#
# **Process Flow**:
# - **Target Segmentation**: Filter high-risk customers (95%+ churn probability) from specific demographics (young employed, work-from-home, upper-middle income)
# - **Feature Attribution Analysis**: Extract why each customer is at risk using ML.EXPLAIN_PREDICT feature contributions
# - **Problem Description Generation**: AI converts technical risk factors into comprehensive customer problem statements
# - **Business Solution Matching**: Vector search against solution database to find proven retention approaches for similar issues
# - **Service Portfolio Analysis**: Gather current customer services (mobile, internet, security) to identify cross-sell opportunities
# - **Personalized Email Creation**: Generate retention emails addressing specific risk factors with relevant service recommendations
#
# **Why This Works**:
# - **Addresses root causes** instead of generic retention offers
# - **Speaks to actual pain points** each customer experiences
# - **Provides relevant solutions** based on their specific risk factors
# - **Maximizes ML model intelligence** beyond simple targeting
# - **Increases retention effectiveness** through precise personalization

# %%
# %%bigquery   --project {project_id}
#
# select count(*) from `database.mobile_churn_data`
#        WHERE tenure_years > 1
#          AND age < 30
#          AND mobile_churn = 0
#          AND work_from_home_flag = True
#  ;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     f0_
# 0  1270

# %% [markdown]
# - Let's try to create targeted retention email for young customers who are working from home and have tenure more than 1 year etc. 1220 customers
# - We will score the model and identify customers with high churn score from model (>95%)
# - For these subset with high churn prob a table with personalized retention email will be created f with the best actions possible to reduce their churn
# - Business can simply export/connect this table to the marketing tool and send it on demand to customers
# - Any segments can be targetd here. Demo with this subset of ~1200 customers since it's running on my personal Gemini account
# - Takes little as 5 mins for 1000 personalized emails in simple bigquery system below at a cost of less than ~2$ (Using Gemini 2.5 Flash - could be even cheaper as models scales or using smaller mdoel)
# - Demo shown below is for mobile customers but the same can be replicated to the internet customers customized prompt to internet services. We have the churn model created for internet services as well

# %%
# %%bigquery  --project {project_id}
#
# CREATE OR REPLACE TABLE `database.mobile_retention_email_young_employed` AS (
#
# -- Base customer churn predictions for multiple customers
# WITH customer_churn_base AS (
#   SELECT
#     customer_id,
#     predicted_mobile_churn,
#     ROUND(probability * 100, 1) AS churn_probability_percent,
#     age,
#     plan_type,
#     monthly_cost,
#     contract_type,
#     tenure_years,
#     data_overage_frequency,
#     family_plan_flag,
#     household_income,
#     family_size,
#     home_ownership,
#     work_from_home_flag,
#     education_level,
#     life_stage,
#     income_per_person,
#     cost_per_line,
#     fiber_availability,
#     neighborhood_crime_rate,
#
#
#     -- Risk category
#     CASE
#       WHEN probability >= 0.8 THEN 'CRITICAL RISK'
#       WHEN probability >= 0.6 THEN 'HIGH RISK'
#       WHEN probability >= 0.4 THEN 'MEDIUM RISK'
#       ELSE 'LOW RISK'
#     END AS risk_category,
#
#     top_feature_attributions
#   FROM (
#     SELECT *
#     FROM ML.EXPLAIN_PREDICT(
#       MODEL `database.mobile_churn_predictor`,
#       (SELECT * FROM `database.mobile_churn_data`
#        WHERE tenure_years > 1
#          AND age < 30
#          AND age>25
#          AND mobile_churn = 0
#          AND work_from_home_flag = True
#          AND income_bracket = 'Upper_Middle'
#       )
#     )
#     WHERE probability > 0.95
#   )
# ) ,
#
#
# -- Security services aggregation
# customer_security AS (
#   SELECT
#     customer_id,
#     STRING_AGG(device_type, ', ' ORDER BY device_type) AS device_types_concat,
#     COUNT(device_type) AS total_security_devices
#   FROM `database.security_df`
#   WHERE customer_id IN (SELECT customer_id FROM customer_churn_base)
#   GROUP BY customer_id
# ),
#
# -- Active internet services
# customer_internet AS (
#   SELECT
#     customer_id,
#     speed_mbps AS internet_speed,
#     plan_tier AS internet_plan,
#     contract_type AS internet_contract_type,
#     internet_tenure_days
#   FROM `database.internet_df`
#   WHERE customer_id IN (SELECT customer_id FROM customer_churn_base)
#     AND internet_churn = 0
# ),
#
# -- Active mobile services (non-churned)
# customer_mobile AS (
#   SELECT
#     customer_id,
#     plan_type AS current_mobile_plan,
#     contract_type AS current_mobile_contract_type,
#     data_overage_frequency AS current_mobile_data_overage,
#     monthly_cost AS current_mobile_cost
#   FROM `database.mobile_df`
#   WHERE customer_id IN (SELECT customer_id FROM customer_churn_base)
#     AND mobile_churn = 0
# ),
#
# -- Problem descriptions for business solution matching (AI-generated)
# customer_problems AS (
#   SELECT
#     cb.customer_id,
#     AI.GENERATE(
#       CONCAT(
#         'Analyze this mobile customer situation and identify their key problems/pain points in under 150 words. Start with "Customer is facing...":\\n\\n',
#         'Customer Profile:\\n',
#         '- Age: ', CAST(cb.age AS STRING), ' years (', cb.life_stage, ')\\n',
#         '- Income: $', CAST(cb.household_income AS STRING), ' household, $', CAST(CAST(cb.income_per_person AS INT64) AS STRING), ' per person\\n',
#         '- Family: ', CAST(cb.family_size AS STRING), ' people, ', cb.home_ownership, '\\n',
#         '- Education: ', cb.education_level, '\\n',
#         '- Works from home: ', CAST(cb.work_from_home_flag AS STRING), '\\n',
#         'Mobile Service:\\n',
#         '- Plan: ', cb.plan_type, '\\n',
#         '- Cost: $', CAST(cb.monthly_cost AS STRING), '/month ($', CAST(CAST(cb.cost_per_line AS INT64) AS STRING), ' per line)\\n',
#         '- Contract: ', cb.contract_type, '\\n',
#         '- Tenure: ', CAST(cb.tenure_years AS STRING), ' years\\n',
#         '- Data overages: ', CAST(cb.data_overage_frequency AS STRING), ' per month\\n',
#         '- Family plan: ', CAST(cb.family_plan_flag AS STRING), '\\n',
#         '- Fiber available: ', CAST(cb.fiber_availability AS STRING), '\\n\\n',
#         'Churn Analysis:\\n',
#         '- Risk: ', CAST(cb.churn_probability_percent AS STRING), '% (', cb.risk_category, ')\\n',
#         '- Key factors: ', ARRAY_TO_STRING(
#           ARRAY(
#             SELECT CONCAT(feature, ': ', CAST(ROUND(attribution, 3) AS STRING))
#             FROM UNNEST(cb.top_feature_attributions)
#             ORDER BY ABS(attribution) DESC
#             LIMIT 5
#           ), ', '
#         ), '\\n\\n',
#         'Task: Write a detailed problem analysis identifying:\\n',
#         'Why they are at risk of churning? What could be the possible reasons and or frustration customer is facing\\n',
#         'Format as a comprehensive problem statement for vector similarity matching with business solutions later.'
#       ),
#       connection_id => 'us.vertex-ai-connection',
#       endpoint => 'gemini-2.5-flash'
#     ).result AS problem_description
#   FROM customer_churn_base cb
# ),
#
# -- Generate embeddings for customer problems
# customer_problem_embeddings AS (
#   SELECT *
#   FROM ML.GENERATE_EMBEDDING(
#     MODEL `database.text_embedding_005_model`,
#     (SELECT
#        problem_description AS content,
#        customer_id
#      FROM customer_problems),
#     STRUCT(TRUE AS flatten_json_output, 'RETRIEVAL_DOCUMENT' AS task_type)
#   )
# ),
#
# -- Business solution matching
# business_solutions AS (
#   SELECT
#     vs.query.customer_id,
#     vs.base.problem AS similar_matched_problem,
#     vs.base.solution AS recommended_solution,
#     vs.base.sector AS sector,
#     vs.distance AS solution_match_score
#   FROM VECTOR_SEARCH(
#     TABLE `database.business_solution_embeddings`,
#     'problem_embedding',
#     TABLE customer_problem_embeddings,
#     'ml_generate_embedding_result',
#     top_k => 1,
#     distance_type => 'COSINE'
#   ) AS vs
# ),
#
# -- Consolidated customer data
# customer_consolidated AS (
#   SELECT
#     cb.*,
#
#     -- Security services
#     COALESCE(cs.device_types_concat, 'None') AS device_types_concat,
#     COALESCE(cs.total_security_devices, 0) AS total_security_devices,
#     CASE WHEN cs.customer_id IS NOT NULL THEN 1 ELSE 0 END AS security_customer,
#
#     -- Internet services
#     ci.internet_speed,
#     ci.internet_plan,
#     ci.internet_contract_type,
#     ci.internet_tenure_days,
#     CASE
#       WHEN ci.customer_id IS NULL THEN 'No internet service'
#       ELSE 'Active internet customer'
#     END AS internet_customer_status,
#
#     -- Mobile services (from churn table vs active table)
#     cm.current_mobile_plan,
#     cm.current_mobile_contract_type,
#     cm.current_mobile_data_overage,
#     cm.current_mobile_cost,
#     CASE
#       WHEN cm.customer_id IS NULL THEN 'Mobile service at risk'
#       ELSE 'Active mobile customer'
#     END AS mobile_customer_status,
#
#     -- Business solutions
#     bs.similar_matched_problem,
#     bs.recommended_solution,
#     bs.sector,
#     bs.solution_match_score
#
#   FROM customer_churn_base cb
#   LEFT JOIN customer_security cs ON cb.customer_id = cs.customer_id
#   LEFT JOIN customer_internet ci ON cb.customer_id = ci.customer_id
#   LEFT JOIN customer_mobile cm ON cb.customer_id = cm.customer_id
#   LEFT JOIN business_solutions bs ON cb.customer_id = bs.customer_id
# )
#
# -- Final output with email generation
# SELECT
#   cc.customer_id,
#   churn_probability_percent,
#   risk_category,
#   plan_type,
#   monthly_cost,
#   internet_customer_status,
#   mobile_customer_status,
#   security_customer,
#
#   -- Use the AI-generated problem description from solution matching
#   cp.problem_description AS problem_analysis,
#   similar_matched_problem,
#   recommended_solution,
#   solution_match_score,
#
#   -- Enhanced retention email generation
#   AI.GENERATE(
#     CONCAT(
#       'Create a personalized retention email for this at-risk mobile customer. Address their specific churn risks and suggest relevant additional services:\\n\\n',
#
#       '=== CUSTOMER OVERVIEW ===\\n',
#       'Customer ID: ', cc.customer_id, '\\n',
#       'Churn Risk: ', CAST(churn_probability_percent AS STRING), '% (', risk_category, ')\\n',
#       'Profile: ', CAST(age AS STRING), '-year-old ', life_stage, '\\n',
#       'Family: ', CAST(family_size AS STRING), ' people, ', home_ownership, '\\n',
#       'Income: $', CAST(household_income AS STRING), ' household\\n',
#       'Work Setup: ', CASE WHEN work_from_home_flag THEN 'Works from home' ELSE 'Traditional workplace' END, '\\n\\n',
#
#       '=== CURRENT SERVICE PORTFOLIO ===\\n',
#       'Mobile Service: ', CAST(tenure_years AS STRING), ' years with us\\n',
#       '- Plan: ', plan_type, ' ($', CAST(monthly_cost AS STRING), '/month)\\n',
#       '- Contract: ', contract_type, '\\n',
#       '- Data Issues: ', CAST(data_overage_frequency AS STRING), ' overages/month\\n',
#       '- Family Plan: ', CAST(family_plan_flag AS STRING), '\\n\\n',
#
#       'Internet Service: ', internet_customer_status, '\\n',
#       CASE WHEN internet_customer_status = 'Active internet customer' THEN
#         CONCAT('- Plan: ', internet_plan, ' (', CAST(internet_speed AS STRING), ' Mbps)\\n',
#                '- Contract: ', internet_contract_type, '\\n')
#         ELSE CONCAT('- Opportunity: Fiber available = ', CAST(fiber_availability AS STRING), '\\n') END,
#
#       'Security Service: ', CASE WHEN security_customer = 1
#         THEN CONCAT('Active (', CAST(total_security_devices AS STRING), ' devices: ', device_types_concat, ')')
#         ELSE 'Not subscribed' END, '\\n',
#         CASE WHEN security_customer = 0 THEN
#         CONCAT('- Area Crime Rate: ', neighborhood_crime_rate, '\\n') ELSE '' END, '\\n',
#
#
#       '=== CHURN RISK FACTORS ===\\n',
#       'Risk Level: ', risk_category, ' (', CAST(churn_probability_percent AS STRING), '%)\\n',
#       'Key Risk Drivers:\\n',
#       ARRAY_TO_STRING(
#         ARRAY(
#           SELECT CONCAT('• ', feature, ': ',
#             CASE WHEN attribution > 0 THEN 'Increasing churn risk'
#                  ELSE 'Reducing churn risk' END,
#             ' (', CAST(ROUND(attribution, 3) AS STRING), ')')
#           FROM UNNEST(top_feature_attributions)
#           ORDER BY ABS(attribution) DESC
#           LIMIT 5
#         ), '\\n'
#       ), '\\n\\n',
#
#       '=== BUSINESS SOLUTION GUIDANCE ===\\n',
#       'From the business solution book, we found a problem most similar to this customers issue: ', COALESCE(similar_matched_problem, 'Standard mobile service retention'), '\\n',
#       'And the business solution to this was: ', COALESCE(recommended_solution, 'Personalized value demonstration and service optimization'), '\\n',
#
#       '=== AVAILABLE SERVICE OPTIONS ===\\n',
#       'MOBILE PLANS:\\n',
#       '• Limited 2GB: $30/month\\n',
#       '• Limited 5GB: $40/month\\n',
#       '• Limited 10GB: $50/month\\n',
#       '• Unlimited Standard: $70/month\\n',
#       '• Unlimited Premium: $90/month (includes Disney+)\\n\\n',
#
#       'INTERNET PLANS:\\n',
#       '• Basic: 25 Mbps at $40/month\\n',
#       '• Standard: 100 Mbps at $70/month\\n',
#       '• Premium Gig: 1000 Mbps at $100/month\\n\\n',
#
#       'SECURITY OPTIONS:\\n',
#       '• Starter Kit: Motion + Window sensors ($60)\\n',
#       '• Smart Security: Doorbell + Indoor Camera ($200)\\n',
#       '• Complete Protection: Full system with monitoring ($350 + $30/month)\\n\\n',
#
#       '=== EMAIL REQUIREMENTS ===\\n',
#       '**PRIMARY GOAL**: Prevent churn by addressing specific risk factors and demonstrating value. Prvoide the best solutions customer could do or we as business could do to solve the issues for customer\\n',
#       '**SECONDARY GOAL**: Suggest relevant services (cros-sell) they dont have as long as its logical and is not a deterrance to customer retention efforts\\n\\n',
#
#       '**STRUCTURE**:\\n',
#       '1. Warm personal greeting (no placeholder names)\\n',
#       '2. Acknowledge their ', CAST(tenure_years AS STRING), '-year relationship\\n',
#       '3. Address top 2-3 churn risk factors specifically\\n',
#       '4. Apply the business solution approach provided\\n',
#       '5. Present 1-2 relevant additional services (only if they dont have them)\\n',
#       '6. Offer meaningful retention incentive '
#             '- YOU ARE ALLOWED TO OFFER ONLY A Maximum 20$ discount. YOU CANNOT OFFER ANY RETENTION OFFER BY DECREASING RATES MORE THAN BY 20$\\n',
#             '- RETENTION OFFERS ARE TO INCREASE THE CUSTOMER LIFETIME VALUE. OFFERS PROVIDED SHOULD ALWAYS CONSIDER AND OPTIMIZE FOR THAT',
#             '- YOU CAN OFFER FREE FIRST MONTH OFFER FOR MOBILE OR INTERNET CROSS SELL OFFERS IF YOU MAKE ONE\\n'
#             '- YOU CAN MAKE 50$ OFFER FOR SECURITY DEVICES IF YOU MAKE ANY CROSS-SELL FOR FOR IT ONE\\n'
#       '7. Clear next steps and contact info\\n\\n',
#
#       '**CROSS-SELL LOGIC**:\\n',
#       '• No Internet + WFH = Emphasize internet bundle\\n',
#       '• No Security + High Crime = Home protection focus\\n',
#       '• Data Overages = Unlimited plan upgrade\\n',
#       '• Family + Limited Plan = Family plan benefits\\n',
#       '• Keep suggestions brief and value-focused\\n',
#       '• Include small incentives for new services\\n\\n',
#
#       '**TONE**: Empathetic, solution-focused, value-driven, personally crafted\\n',
#       '**LENGTH**: 350-450 words\\n',
#       '**SIGNATURE**: TriLink Customer Success Team\\n',
#       '**CONTACT**: 1-800-TRILINK or customercare@trilink.com\\n\\n',
#
#       'Generate the complete retention email:'
#     ),
#     connection_id => 'us.vertex-ai-connection',
#     endpoint => 'gemini-2.5-flash'
#   ).result AS personalized_retention_email,
#
#   -- Additional columns for analysis
#   top_feature_attributions,
#   device_types_concat,
#   total_security_devices,
#   internet_speed,
#   internet_plan
#
# FROM customer_consolidated cc
# LEFT JOIN customer_problems cp ON cc.customer_id = cp.customer_id
# ORDER BY churn_probability_percent DESC
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery  mobile_email_campaign_retention  --project {project_id}
#
# select * from `trilink-472019.database.mobile_retention_email_young_employed`;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
print(f"Number of customers with high churn probability the email is generated for: {mobile_email_campaign_retention.shape[0]}")
# Out:
# Number of customers with high churn probability the email is generated for: 22

# %%
mobile_email_campaign_retention.head(20)
# Out:
#    customer_id  churn_probability_percent  risk_category           plan_type  \
# 0    C00096527                       96.5  CRITICAL RISK   Unlimited_Premium
# 1    C00009009                       96.5  CRITICAL RISK  Unlimited_Standard
# 2    C00079038                       96.5  CRITICAL RISK  Unlimited_Standard
# 3    C00090448                       96.5  CRITICAL RISK  Unlimited_Standard
# 4    C00067487                       96.5  CRITICAL RISK   Unlimited_Premium
# 5    C00045009                       96.3  CRITICAL RISK  Unlimited_Standard
# 6    C00098454                       96.3  CRITICAL RISK  Unlimited_Standard
# 7    C00005609                       96.3  CRITICAL RISK  Unlimited_Standard
# 8    C00061220                       96.3  CRITICAL RISK  Unlimited_Standard
# 9    C00021580                       96.3  CRITICAL RISK  Unlimited_Standard
# 10   C00009465                       96.3  CRITICAL RISK  Unlimited_Standard
# 11   C00029699                       96.1  CRITICAL RISK  Unlimited_Standard
# 12   C00040720                       95.8  CRITICAL RISK  Unlimited_Standard
# 13   C00062239                       95.8  CRITICAL RISK  Unlimited_Standard
# 14   C00000748                       95.7  CRITICAL RISK  Unlimited_Standard
# 15   C00013609                       95.7  CRITICAL RISK   Unlimited_Premium
# 16   C00082404                       95.6  CRITICAL RISK  Unlimited_Standard
# 17   C00035863                       95.4  CRITICAL RISK   Unlimited_Premium
# 18   C00086327                       95.1  CRITICAL RISK        Limited_10GB
# 19   C00069439                       95.1  CRITICAL RISK        Limited_10GB
#
#     monthly_cost  internet_customer_status  mobile_customer_status  \
# 0            215  Active internet customer  Active mobile customer
# 1            174       No internet service  Active mobile customer
# 2            227  Active internet customer  Active mobile customer
# 3            222       No internet service  Active mobile customer
# 4            222  Active internet customer  Active mobile customer
# 5            171       No internet service  Active mobile customer
# 6            114  Active internet customer  Active mobile customer
# 7            120       No internet service  Active mobile customer
# 8            170  Active internet customer  Active mobile customer
# 9            128  Active internet customer  Active mobile customer
# 10           176  Active internet customer  Active mobile customer
# 11           117  Active internet customer  Active mobile customer
# 12           169  Active internet customer  Active mobile customer
# 13           230  Active internet customer  Active mobile customer
# 14           126  Active internet customer  Active mobile customer
# 15           153  Active internet customer  Active mobile customer
# 16           176  Active internet customer  Active mobile customer
# 17           216  Active internet customer  Active mobile customer
# 18           139  Active internet customer  Active mobile customer
# 19           139  Active internet customer  Active mobile customer
#
#     security_customer                                   problem_analysis  \
# 0                   0  Customer is facing significant dissatisfaction...
# 1                   1  Customer is facing a critical churn risk stemm...
# 2                   1  Customer is facing critical churn risk primari...
# 3                   1  Customer is facing critical dissatisfaction ro...
# 4                   1  Customer is facing critical churn risk primari...
# 5                   0  Customer is facing critical churn risk primari...
# 6                   1  Customer is facing critical churn risk primari...
# 7                   0  Customer is facing critical churn risk primari...
# 8                   1  Customer is facing critical churn risk stemmin...
# 9                   0  Customer is facing critical churn risk primari...
# 10                  1  Customer is facing dissatisfaction primarily d...
# 11                  1  Customer is facing critical churn risk primari...
# 12                  0  Customer is facing critical churn risk primari...
# 13                  0  Customer is facing a critical churn risk due t...
# 14                  1  Customer is facing critical churn risk primari...
# 15                  0  Customer is facing a critical 95.7% churn risk...
# 16                  0  Customer is facing a critical churn risk due t...
# 17                  1  Customer is facing critical churn risk primari...
# 18                  0  Customer is facing chronic data insufficiency ...
# 19                  1  Customer is facing critical dissatisfaction du...
#
#                               similar_matched_problem  \
# 0   Customer with Limited_2GB plan hitting data li...
# 1   Customer with Limited_2GB plan hitting data li...
# 2   Customer with Limited_2GB plan hitting data li...
# 3   Customer with Limited_2GB plan hitting data li...
# 4   Customer with Limited_2GB plan hitting data li...
# 5   Customer with 8-year service history paying sa...
# 6   Customer with Limited_2GB plan hitting data li...
# 7   Customer with Limited_2GB plan hitting data li...
# 8   Customer with Limited_2GB plan hitting data li...
# 9   Customer with Limited_2GB plan hitting data li...
# 10  Customer with Limited_2GB plan hitting data li...
# 11  Customer with Limited_2GB plan hitting data li...
# 12  Customer with Limited_2GB plan hitting data li...
# 13  Customer with Limited_2GB plan hitting data li...
# 14  Customer with Limited_2GB plan hitting data li...
# 15  Customer with Limited_2GB plan hitting data li...
# 16  Customer with Limited_2GB plan hitting data li...
# 17  Customer with Limited_2GB plan hitting data li...
# 18  Customer with Limited_2GB plan hitting data li...
# 19  Customer with Limited_2GB plan hitting data li...
#
#                                  recommended_solution  solution_match_score  \
# 0   Upgrade to Unlimited_Standard $69/month elimin...              0.263670
# 1   Upgrade to Unlimited_Standard $69/month elimin...              0.258375
# 2   Upgrade to Unlimited_Standard $69/month elimin...              0.275510
# 3   Upgrade to Unlimited_Standard $69/month elimin...              0.272503
# 4   Upgrade to Unlimited_Standard $69/month elimin...              0.248110
# 5   Activate loyalty rewards with $20 monthly disc...              0.301886
# 6   Upgrade to Unlimited_Standard $69/month elimin...              0.280703
# 7   Upgrade to Unlimited_Standard $69/month elimin...              0.282076
# 8   Upgrade to Unlimited_Standard $69/month elimin...              0.272296
# 9   Upgrade to Unlimited_Standard $69/month elimin...              0.238327
# 10  Upgrade to Unlimited_Standard $69/month elimin...              0.267664
# 11  Upgrade to Unlimited_Standard $69/month elimin...              0.249309
# 12  Upgrade to Unlimited_Standard $69/month elimin...              0.267648
# 13  Upgrade to Unlimited_Standard $69/month elimin...              0.252766
# 14  Upgrade to Unlimited_Standard $69/month elimin...              0.253557
# 15  Upgrade to Unlimited_Standard $69/month elimin...              0.261986
# 16  Upgrade to Unlimited_Standard $69/month elimin...              0.261268
# 17  Upgrade to Unlimited_Standard $69/month elimin...              0.277231
# 18  Upgrade to Unlimited_Standard $69/month elimin...              0.256660
# 19  Upgrade to Unlimited_Standard $69/month elimin...              0.265099
#
#                          personalized_retention_email  \
# 0   Subject: An Important Update on Your TriLink S...
# 1   **Subject: An Important Update on Your TriLink...
# 2   Subject: An Important Update on Your TriLink S...
# 3   Subject: An Exclusive Offer to Enhance Your Tr...
# 4   Subject: An Important Update Regarding Your Tr...
# 5   Dear Valued TriLink Customer,\n\nWe noticed th...
# 6   Subject: An Important Update on Your TriLink S...
# 7   **Subject**: An Important Message Regarding Yo...
# 8   Subject: An Important Update on Your TriLink S...
# 9   Subject: An Exclusive Offer to Enhance Your Tr...
# 10  Subject: A Special Thank You from TriLink – En...
# 11  Subject: An Exclusive Offer Just For You: Enha...
# 12  Subject: An Important Update to Your TriLink M...
# 13  **Subject**: An Important Message Regarding Yo...
# 14  Subject: An Important Update on Your TriLink M...
# 15  Subject: An Exclusive Offer Just for You, Valu...
# 16  Subject: A Special Thank You from TriLink – En...
# 17  Subject: An Important Message Regarding Your T...
# 18  Subject: Your Exclusive Savings & Service Enha...
# 19  Subject: An Important Update About Your TriLin...
#
#                              top_feature_attributions  \
# 0   [{'feature': 'tenure_years', 'attribution': 0....
# 1   [{'feature': 'tenure_years', 'attribution': 0....
# 2   [{'feature': 'tenure_years', 'attribution': 0....
# 3   [{'feature': 'tenure_years', 'attribution': 0....
# 4   [{'feature': 'tenure_years', 'attribution': 0....
# 5   [{'feature': 'tenure_years', 'attribution': 0....
# 6   [{'feature': 'tenure_years', 'attribution': 0....
# 7   [{'feature': 'tenure_years', 'attribution': 0....
# 8   [{'feature': 'tenure_years', 'attribution': 0....
# 9   [{'feature': 'tenure_years', 'attribution': 0....
# 10  [{'feature': 'tenure_years', 'attribution': 0....
# 11  [{'feature': 'tenure_years', 'attribution': 0....
# 12  [{'feature': 'tenure_years', 'attribution': 0....
# 13  [{'feature': 'tenure_years', 'attribution': 0....
# 14  [{'feature': 'tenure_years', 'attribution': 0....
# 15  [{'feature': 'tenure_years', 'attribution': 0....
# 16  [{'feature': 'tenure_years', 'attribution': 0....
# 17  [{'feature': 'tenure_years', 'attribution': 0....
# 18  [{'feature': 'tenure_years', 'attribution': 1....
# 19  [{'feature': 'tenure_years', 'attribution': 1....
#
#                                   device_types_concat  total_security_devices  \
# 0                                                None                       0
# 1   Indoor_Camera, Motion_Sensor, Smart_Doorbell, ...                       4
# 2   Indoor_Camera, Outdoor_Camera, Security_Panel,...                       5
# 3   Motion_Sensor, Outdoor_Camera, Security_Panel,...                       4
# 4   Indoor_Camera, Smart_Doorbell, Smart_Lock, Win...                       4
# 5                                                None                       0
# 6   Indoor_Camera, Outdoor_Camera, Security_Panel,...                       5
# 7                                                None                       0
# 8                      Outdoor_Camera, Smart_Doorbell                       2
# 9                                                None                       0
# 10  Indoor_Camera, Outdoor_Camera, Security_Panel,...                       6
# 11  Indoor_Camera, Motion_Sensor, Outdoor_Camera, ...                       5
# 12                                               None                       0
# 13                                               None                       0
# 14  Outdoor_Camera, Security_Panel, Smart_Doorbell...                       4
# 15                                               None                       0
# 16                                               None                       0
# 17  Motion_Sensor, Outdoor_Camera, Smart_Doorbell,...                       4
# 18                                               None                       0
# 19      Indoor_Camera, Outdoor_Camera, Smart_Doorbell                       3
#
#     internet_speed internet_plan
# 0               25      Basic_25
# 1             <NA>          None
# 2              100  Standard_100
# 3             <NA>          None
# 4             1000   Premium_Gig
# 5             <NA>          None
# 6              100  Standard_100
# 7             <NA>          None
# 8              100  Standard_100
# 9              100  Standard_100
# 10            1000   Premium_Gig
# 11             100  Standard_100
# 12            1000   Premium_Gig
# 13            1000   Premium_Gig
# 14            1000   Premium_Gig
# 15             100  Standard_100
# 16             100  Standard_100
# 17            1000   Premium_Gig
# 18             100  Standard_100
# 19             100  Standard_100

# %%
display_customer_retention(df_customers=mobile_email_campaign_retention,i=0)
# Out:
# Total Customers in Dataset: 22
# ================================================================================
#
# Customer: C00096527
# Churn Risk: CRITICAL RISK (96.5%)
# Internet Plan: Basic_25 | Speed: 25
# Devices: None | Security Devices: 0
# Solution Match Score: 0.26
# ================================================================================
# PROBLEM ANALYSIS:
# --------------------
# ('Customer is facing significant dissatisfaction due to an expensive '
#  'Unlimited_Premium mobile plan ($215/month, $72/line) that provides features '
#  "they don't fully utilize. As a young family with a work-from-home parent, "
#  'their reliance on mobile data is reduced, resulting in zero data overages '
#  'and contributing to a perception of overpaying. This high monthly cost, '
#  'coupled with a tenure nearing three years without perceived value matching '
#  'the premium service, creates a critical 96.5% churn risk. They are likely '
#  'seeking a more cost-effective mobile solution tailored to their actual usage '
#  'patterns and current life stage.')
#
# PERSONALIZED RETENTION EMAIL:
# -----------------------------------
# ("Subject: An Important Update on Your TriLink Services, C00096527 – Let's "
#  'Enhance Your Value\n'
#  '\n'
#  'Dear Valued TriLink Customer C00096527,\n'
#  '\n'
#  'We want to take a moment to acknowledge your nearly three years with '
#  'TriLink; your loyalty since becoming a mobile customer 2.87 years ago is '
#  "truly appreciated. We regularly review our long-standing customers' accounts "
#  "to ensure you're always getting the best value and services tailored to your "
#  'evolving needs.\n'
#  '\n'
#  'Our analysis indicates that your current mobile plan, at $215/month, might '
#  'no longer be providing the most competitive rate available today, which we '
#  "believe is a significant factor in your account's current health. For "
#  'families like yours, balancing household income and monthly expenses is key, '
#  'and we want to help you optimize your services to fit your budget better.\n'
#  '\n'
#  "**Here's how we can significantly enhance your value and savings:**\n"
#  '\n'
#  "*   **Mobile Plan Optimization:** You're currently on an Unlimited Premium "
#  'plan costing $215/month. We can easily transition you to our modern '
#  '**Unlimited Premium** plan, which includes benefits like Disney+ and the '
#  'top-tier performance you expect, for **just $90/month**. This move would '
#  'instantly save you a remarkable **$125 every single month!** To make this '
#  "transition even more rewarding, we'd like to offer you your **first month on "
#  'this new Unlimited Premium plan absolutely free.**\n'
#  '\n'
#  "Beyond these immediate savings, we've identified a couple of additional ways "
#  'TriLink could better support your family:\n'
#  '\n'
#  '*   **Elevate Your Work-From-Home Experience:** As someone who works from '
#  'home, a robust internet connection is crucial for productivity and family '
#  'use. Your current Basic 25 Mbps plan might struggle with video calls and '
#  'other online activities for a household of three. Upgrading to our '
#  '**Standard 100 Mbps internet plan for $70/month** would provide a much '
#  'smoother, more reliable experience for everyone. If you choose to upgrade, '
#  'your **first month of Standard 100 Mbps internet will be on us!**\n'
#  '\n'
#  '*   **Enhanced Home Security for Your Family:** With a young family and your '
#  'local area crime rate at 4.7, peace of mind regarding home security is '
#  "paramount. While you don't currently have a security system, our **Smart "
#  'Security package** (including a video doorbell and indoor camera for $200) '
#  'offers an excellent way to keep an eye on things. If you decide to add this '
#  "to your services, we'll provide a **$50 discount on the device cost.**\n"
#  '\n'
#  'By making these simple adjustments, you could not only enjoy substantial '
#  "monthly savings on your mobile service but also enhance your home's "
#  'connectivity and security, ensuring your TriLink services truly support your '
#  "family's lifestyle.\n"
#  '\n'
#  "We're here to make these changes straightforward and beneficial for you. "
#  "Please don't hesitate to reach out to discuss these personalized "
#  'recommendations.\n'
#  '\n'
#  'Sincerely,\n'
#  '\n'
#  'The TriLink Customer Success Team\n'
#  '1-800-TRILINK | customercare@trilink.com')
#
# TOP FEATURE ATTRIBUTIONS:
# ------------------------------
# array([{'feature': 'tenure_years', 'attribution': 0.6349834203720093},
#        {'feature': 'data_overage_frequency', 'attribution': 0.1613076627254486},
#        {'feature': 'household_income', 'attribution': 0.1478891670703888},
#        {'feature': 'work_from_home_flag', 'attribution': 0.03918340802192688},
#        {'feature': 'monthly_cost', 'attribution': 0.036684632301330566}],
#       dtype=object)
# ================================================================================

# %%
display_customer_retention(df_customers=mobile_email_campaign_retention,i=4)
# Out:
# Total Customers in Dataset: 22
# ================================================================================
#
# Customer: C00067487
# Churn Risk: CRITICAL RISK (96.5%)
# Internet Plan: Premium_Gig | Speed: 1000
# Devices: Indoor_Camera, Smart_Doorbell, Smart_Lock, Window_Sensor | Security Devices: 4
# Solution Match Score: 0.25
# ================================================================================
# PROBLEM ANALYSIS:
# --------------------
# ('Customer is facing critical churn risk primarily due to being out of '
#  'contract (2.88 years tenure vs. 24-month contract), enabling easy switching. '
#  'They are likely experiencing frustration with the high monthly cost ($222 '
#  'for 4 lines) relative to their per-person income and perceived value. The '
#  '"Unlimited_Premium" plan appears to be overkill, given zero data overages '
#  'and their work-from-home status, suggesting underutilized features and an '
#  'unnecessarily expensive plan. This budget sensitivity, typical for a young '
#  'family, makes them highly susceptible to competitors offering better value '
#  'or lower costs.')
#
# PERSONALIZED RETENTION EMAIL:
# -----------------------------------
# ('Subject: An Important Update Regarding Your TriLink Mobile & Home Services - '
#  'Valued Customer Since 2021\n'
#  '\n'
#  'Dear Valued TriLink Customer,\n'
#  '\n'
#  'As a long-standing member of the TriLink family for nearly three years, we '
#  "truly appreciate your loyalty and trust in our services. We're reaching out "
#  "today because we want to ensure you're always getting the best value and "
#  'experience from us.\n'
#  '\n'
#  'Our records indicate that you’re currently on our Unlimited Premium mobile '
#  'plan, which you’ve relied on for seamless connectivity for your family of '
#  'four, especially with your work-from-home setup. While we’re glad you '
#  "haven't experienced any data overages, we've noticed your current monthly "
#  'cost for this plan ($222) is significantly higher than our latest offerings. '
#  'As a loyal customer, we believe you deserve to benefit from our most '
#  'competitive pricing.\n'
#  '\n'
#  '**To immediately enhance your value and demonstrate our appreciation for '
#  'your loyalty, we propose moving you to our current Unlimited Premium plan, '
#  'which is available for just $90/month.** This change would maintain all the '
#  'benefits you currently enjoy, including family plan features and unlimited '
#  'data, while reducing your monthly mobile bill by a substantial $132. This is '
#  'our way of ensuring your long tenure with us is continually rewarded with '
#  "outstanding value, aligning your service with your household's financial "
#  'expectations.\n'
#  '\n'
#  'Furthermore, we understand how critical reliable connectivity is for your '
#  "work-from-home setup. You're already enjoying the robust performance of our "
#  'Premium Gig internet, providing the 1000 Mbps speeds essential for video '
#  'calls and all your family’s online needs. This premium service, combined '
#  'with your optimized mobile plan, ensures a powerful and reliable TriLink '
#  'experience for your entire household.\n'
#  '\n'
#  '**As a special thank you for your loyalty and for accepting this plan '
#  "adjustment, we'd like to offer you the first month of your new $90 Unlimited "
#  'Premium mobile plan completely free.** That’s an immediate saving of $90 in '
#  'addition to your ongoing monthly reduction!\n'
#  '\n'
#  'While you already have an excellent foundation with your current security '
#  'devices (Indoor Camera, Smart Doorbell, Smart Lock, Window Sensor), you '
#  "might consider enhancing your home's safety with our **Complete Protection** "
#  'package, which includes professional monitoring for just $30/month. For a '
#  'limited time, we can offer you a **$50 credit towards upgrading your '
#  'security setup or adding new smart devices** when you activate this '
#  'comprehensive monitoring service. This would provide ultimate peace of mind '
#  'for your family.\n'
#  '\n'
#  "We're committed to ensuring your satisfaction and want to make this "
#  'transition as smooth as possible. To discuss these options, claim your free '
#  'month, and lock in your new plan, please contact us at your convenience.\n'
#  '\n'
#  'Sincerely,\n'
#  '\n'
#  'TriLink Customer Success Team\n'
#  '1-800-TRILINK | customercare@trilink.com')
#
# TOP FEATURE ATTRIBUTIONS:
# ------------------------------
# array([{'feature': 'tenure_years', 'attribution': 0.6313890218734741},
#        {'feature': 'data_overage_frequency', 'attribution': 0.15467818081378937},
#        {'feature': 'household_income', 'attribution': 0.1453203409910202},
#        {'feature': 'monthly_cost', 'attribution': 0.03687742352485657},
#        {'feature': 'work_from_home_flag', 'attribution': 0.036337390542030334}],
#       dtype=object)
# ================================================================================

# %%
display_customer_retention(df_customers=mobile_email_campaign_retention,i=11)
# Out:
# Total Customers in Dataset: 22
# ================================================================================
#
# Customer: C00029699
# Churn Risk: CRITICAL RISK (96.1%)
# Internet Plan: Standard_100 | Speed: 100
# Devices: Indoor_Camera, Motion_Sensor, Outdoor_Camera, Smart_Doorbell, Smart_Lock | Security Devices: 5
# Solution Match Score: 0.25
# ================================================================================
# PROBLEM ANALYSIS:
# --------------------
# ('Customer is facing critical churn risk primarily due to a perceived lack of '
#  'value from their existing mobile plan. Despite high income and nearly three '
#  'years of tenure, they likely feel unappreciated and that their $117/month '
#  'Unlimited_Standard plan is overpriced for their actual mobile data '
#  'consumption, especially given their work-from-home lifestyle and readily '
#  'available fiber internet. This situation suggests a mismatch between their '
#  'mobile service and current needs, leading to dissatisfaction with their '
#  'cost-to-value proposition and openness to competitor offerings better '
#  'aligned with their professional, WFH demands.')
#
# PERSONALIZED RETENTION EMAIL:
# -----------------------------------
# ('Subject: An Exclusive Offer Just For You: Enhancing Your TriLink Experience, '
#  'C00029699\n'
#  '\n'
#  'Dear Valued Customer,\n'
#  '\n'
#  'As a valued member of the TriLink family for nearly three years, we want to '
#  "ensure you're always getting the best value and service from us. We've "
#  "noticed you're a long-standing customer, and we understand that your needs "
#  'and the market evolve. We also recognize the importance of reliable '
#  'connectivity for your work-from-home setup, especially as part of a young '
#  'family.\n'
#  '\n'
#  "We've reviewed your current services and believe there's an exciting "
#  'opportunity to enhance your experience while delivering significant savings, '
#  "especially concerning your mobile plan's monthly cost.\n"
#  '\n'
#  'Currently, you enjoy our Unlimited Standard mobile plan and robust 100 Mbps '
#  'home internet. We want to reward your loyalty and ensure these essential '
#  'services remain highly competitive. We’d like to offer you a special bundle '
#  'that brings your Unlimited Standard mobile plan down to just **$69/month** '
#  'and your Standard 100 Mbps internet to **$49/month**. This re-pricing means '
#  'you could be saving approximately **$69 every month** compared to your '
#  'current combined spend, while maintaining the same great service you rely on '
#  'for seamless work and family life.\n'
#  '\n'
#  'This exclusive bundle not only ensures you continue to enjoy unlimited '
#  'mobile data and reliable internet for your work-from-home demands but also '
#  'demonstrates our commitment to providing exceptional value to our '
#  'longest-standing customers.\n'
#  '\n'
#  "But we don't want to stop there. As a young family, we understand how "
#  'important entertainment and connectivity are. For an even richer experience, '
#  'consider upgrading to our **Unlimited Premium mobile plan**. For just '
#  '**$90/month** within this new bundle (which is still less than your current '
#  "mobile plan cost!), you'll get everything in Unlimited Standard PLUS a "
#  'complimentary Disney+ subscription, perfect for family movie nights. As a '
#  "special thank you, if you choose to upgrade to Unlimited Premium, we'll give "
#  'you the **first month completely free!**\n'
#  '\n'
#  'This tailored offer is designed to reduce your monthly costs significantly '
#  'and deliver even more value, ensuring TriLink remains your trusted provider '
#  'for years to come.\n'
#  '\n'
#  'To discuss these options and activate your new savings, please reach out to '
#  'us at your convenience.\n'
#  '\n'
#  "We're here to help you get the most out of your TriLink services.\n"
#  '\n'
#  'Sincerely,\n'
#  '\n'
#  'TriLink Customer Success Team\n'
#  '1-800-TRILINK\n'
#  'customercare@trilink.com')
#
# TOP FEATURE ATTRIBUTIONS:
# ------------------------------
# array([{'feature': 'tenure_years', 'attribution': 0.6125738024711609},
#        {'feature': 'household_income', 'attribution': 0.14315912127494812},
#        {'feature': 'data_overage_frequency', 'attribution': 0.1372428834438324},
#        {'feature': 'work_from_home_flag', 'attribution': 0.039053115993738174},
#        {'feature': 'monthly_cost', 'attribution': 0.030489755794405937}],
#       dtype=object)
# ================================================================================

# %% [markdown]
# #### Action 4 - Automated Ticket Handling for Home Security
#
# - Idea: When customers have issues with the devices, they usually call/add and create a ticket for resolution. Often times what happens is the customer explaining what the problem is and the agent/bot creates a ticket for them adding some details of what customer told their issue is. Then a technician is assigned that ticket and visits the customers site to solve it in few days as fast as possible. However there are few problems in this traditional approach:-
#     - Information Loss: The agent who handles customers issue won't be highly technical as is most customers. So what's noted down as issue or identified from the software doesn't explain the actual issues that might be there for a technical person. So the issue noted down might not be covering the whole base and technicain when they arrive at site could get stumped with different issues for which they might not have been prepared for
#     - Severity of issue: Oftentimes a good number of tickets created are DIY tasks. FOr example if a customer finds their doorbell camera not having the 2 way audi working, it could be a software issue that could be solved with a software update. You don't need to send a technician for that. This is a huge waste of resource, money and the technicians valued time that could be focused more technical issue. No point in techncian driving in heavy traffic to do a app reboot which customer can do on their own, as long we provide them with step by step instructions
#     - Technician preparedness: Technciains gets assigned with tickets with tasks assigned with target number of tickets. But it would be more practial and idea to assign the tickets effectively with their speciality and of severity instead of quantity
#
#     So the ticket creation now will also ask the customer to upload images of the issue/device issue. Now we will use these images as well as the issue customer described with AI.GENERATE_TABLE and OBJ.MAKE_REF to automatically understand what device the issue is for, is it a hardware or software issue, does it need a on site visit by a technician, if Yes a report for technician to understand what the issue is detailed from image and issue description, if no technician needed, a step by step DIY instruction to send to customer as email or on a guided call to solve issue.
#
#     This can be ran as a daily job on all the issues logged for that day. This is going to save a lot of time and money. Also with this structured issue data created, there can be much more efficient technician assignment where they are assigned by severity, city, device type, location etc

# %%
from IPython.display import display, Image, HTML
import requests
from io import BytesIO
from google.cloud import storage

# %%
# %%bigquery  --project {project_id}
#
# --create a gemini 2.5 flash model connection to use in our AI.GENERAT_TABLE call
#
# CREATE OR REPLACE MODEL `database.gemini_flash`
# REMOTE WITH CONNECTION `us.vertex-ai-connection`
#   OPTIONS(ENDPOINT = 'gemini-2.5-flash');
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# - We have the ticket_id, customer_id, the issue description added in ticket by customer/agent, the URI of the image clicked by customer which shows what the issue was

# %%
# %%bigquery  --project {project_id}
# --Let's load the issues data we have for Trilink homesecurity. In the sample data created we have 100 tickets for which we will run the Multimodal process
#
#
# select * from `database.active_customer_tickets` limit 10;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     ticket_id customer_id technician_id  \
# 0  TICKET_002   C00025032       tech001
# 1  TICKET_007   C00054731       tech001
# 2  TICKET_010   C00008654       tech001
# 3  TICKET_013   C00071155       tech001
# 4  TICKET_017   C00071465       tech001
# 5  TICKET_021   C00097411       tech001
# 6  TICKET_025   C00053965       tech001
# 7  TICKET_029   C00030278       tech001
# 8  TICKET_032   C00071732       tech001
# 9  TICKET_036   C00098830       tech001
#
#                                    issue_description  \
# 0  The touchscreen on our Security Panel is compl...
# 1  The time on my keypad is off by about an hour ...
# 2  My security system is interfering with my gara...
# 3  There are small black dots or specks all over ...
# 4  The timestamp on my recorded video clips is wr...
# 5  The little magnet piece for my window sensor f...
# 6  The adhesive on my door sensor has failed and ...
# 7  The plastic on my window sensor has yellowed b...
# 8  My smart lock keypad is not lighting up when I...
# 9  The motion detection on my doorbell is too sen...
#
#                                       gcs_uri
# 0  gs://trilink/ticket-images/TICKET_002.jpeg
# 1  gs://trilink/ticket-images/TICKET_007.jpeg
# 2  gs://trilink/ticket-images/TICKET_010.jpeg
# 3  gs://trilink/ticket-images/TICKET_013.jpeg
# 4  gs://trilink/ticket-images/TICKET_017.jpeg
# 5  gs://trilink/ticket-images/TICKET_021.jpeg
# 6  gs://trilink/ticket-images/TICKET_025.jpeg
# 7  gs://trilink/ticket-images/TICKET_029.jpeg
# 8  gs://trilink/ticket-images/TICKET_032.jpeg
# 9  gs://trilink/ticket-images/TICKET_036.jpeg

# %% [markdown]
# - We will now create a new table with the images added is as ObjectRef field which we can use in BigQuery to query on multimodal objects easily
# - We will also bring in some customer details to get personalized content further down the line
# - We can see the image_ref created which will be used further down to add curated contents

# %%
# %%bigquery  --project {project_id}
# CREATE OR REPLACE TABLE `database.active_customer_tickets_mm` AS
# SELECT
#   a.*,
#   OBJ.FETCH_METADATA(OBJ.MAKE_REF(gcs_uri, 'us.vertex-ai-connection')) as image_ref,
#   b.age,b.city,b.life_stage,b.home_type,b.work_from_home_flag,b.family_size,b.home_ownership,b.postal_code
# FROM `database.active_customer_tickets` a
# left join `database.customer_df` b
# on a.customer_id=b.customer_id;
#
# select * from `database.active_customer_tickets_mm` limit 10;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     ticket_id customer_id technician_id  \
# 0  TICKET_051   C00044659       tech001
# 1  TICKET_001   C00044659       tech002
# 2  TICKET_058   C00042917       tech002
# 3  TICKET_008   C00042917       tech004
# 4  TICKET_005   C00078974       tech002
# 5  TICKET_055   C00078974       tech003
# 6  TICKET_017   C00071465       tech001
# 7  TICKET_011   C00004651       tech003
# 8  TICKET_074   C00078739       tech005
# 9  TICKET_067   C00017724       tech002
#
#                                    issue_description  \
# 0  The smoke detector in my hallway went off for ...
# 1  My main Security Panel is beeping every minute...
# 2  I have a heat detector in my attic. It went of...
# 3  I need to reset my master code. My ex-partner ...
# 4  I can't arm my system. The panel says 'Device ...
# 5  I'm renovating my kitchen and the drywall dust...
# 6  The timestamp on my recorded video clips is wr...
# 7  My outdoor camera over the garage has a big sp...
# 8  The solar panel for my outdoor camera doesn't ...
# 9  My outdoor camera view is blocked by a large t...
#
#                                       gcs_uri  \
# 0  gs://trilink/ticket-images/TICKET_051.jpeg
# 1  gs://trilink/ticket-images/TICKET_001.jpeg
# 2  gs://trilink/ticket-images/TICKET_058.jpeg
# 3  gs://trilink/ticket-images/TICKET_008.jpeg
# 4  gs://trilink/ticket-images/TICKET_005.jpeg
# 5  gs://trilink/ticket-images/TICKET_055.jpeg
# 6  gs://trilink/ticket-images/TICKET_017.jpeg
# 7  gs://trilink/ticket-images/TICKET_011.jpeg
# 8  gs://trilink/ticket-images/TICKET_074.jpeg
# 9  gs://trilink/ticket-images/TICKET_067.jpeg
#
#                                            image_ref  age         city  \
# 0  {'uri': 'gs://trilink/ticket-images/TICKET_051...   64     Hamilton
# 1  {'uri': 'gs://trilink/ticket-images/TICKET_001...   64     Hamilton
# 2  {'uri': 'gs://trilink/ticket-images/TICKET_058...   54  Mississauga
# 3  {'uri': 'gs://trilink/ticket-images/TICKET_008...   54  Mississauga
# 4  {'uri': 'gs://trilink/ticket-images/TICKET_005...   58      Toronto
# 5  {'uri': 'gs://trilink/ticket-images/TICKET_055...   58      Toronto
# 6  {'uri': 'gs://trilink/ticket-images/TICKET_017...   76      Toronto
# 7  {'uri': 'gs://trilink/ticket-images/TICKET_011...   30  Mississauga
# 8  {'uri': 'gs://trilink/ticket-images/TICKET_074...   57  Mississauga
# 9  {'uri': 'gs://trilink/ticket-images/TICKET_067...   36      Toronto
#
#      life_stage      home_type  work_from_home_flag  family_size  \
# 0    Empty_Nest      Townhouse                False            1
# 1    Empty_Nest      Townhouse                False            1
# 2    Empty_Nest  Single_Family                False            1
# 3    Empty_Nest  Single_Family                False            1
# 4    Empty_Nest      Townhouse                 True            1
# 5    Empty_Nest      Townhouse                 True            1
# 6        Senior  Single_Family                False            1
# 7  Young_Family  Single_Family                 True            2
# 8    Empty_Nest  Single_Family                False            2
# 9  Young_Family  Single_Family                 True            2
#
#   home_ownership postal_code
# 0            Own     L7S 9U3
# 1            Own     L7S 9U3
# 2            Own     L8G 8H8
# 3            Own     L8G 8H8
# 4            Own     M6G 0L8
# 5            Own     M6G 0L8
# 6            Own     M6W 3D3
# 7            Own     L6E 3Z4
# 8            Own     L9M 6H2
# 9            Own     M2D 8N4

# %% [markdown]
# We will now create a table with the solutions for all tickets. The inputs passed to query are the image ObjectRef, issue descrption as well as some customer features for personalization.
# Using AI.GENERATE_TABLE with  Gemini 2.5-Flash we will now create a table that will have:-
#
# - device_name :  Idenitfy what security device the issue is primarily on
# - harware_software: A string that tells if it's a gardware, software or neither problem. Software problems can be troubleshooted from HQ itself
# - need_on_site_visit: A boolean flag weherwe ask the model from image added and issue desc whether a technician needs to be assigned for this. Most of the issues might be simpler where we can guide the customer through problems as DIY task
# - urgency: A numeric rating from 1-5 showing 5 as most urgent issue. This helps business to priortize technician assignment better than the current random assignment
# - technician_report: When a technician is needed on site for solution, we will ask the model to create a structured formatted report for the technciain to understand the problem. Information loss can be corrected now that we will take models help to get the whole info from iamge and issue desc to technciain in a standard format with more details on tools needed, expected time it might take etc. This will help technicians have a heads up already on what to expect, what to do etc.
# - diy_instructions: If a technicial on site was not needed, then we ask the model to create a personalized step by step instruction to be send to the customer via an email or a guided call, to solve their problem where customer can do it themselves the solution from instructions we pass as long as a solution is there. If the issue was hardware beyond repaair we will send them the message that a new one can be send right on to replace

# %%
# %%bigquery  --project {project_id}
#
# CREATE OR REPLACE TABLE `database.active_customer_tickets_solutions` AS
# (SELECT
#   ticket_id,
#   issue_description,
#   device_name,
#   hardware_or_software,
#   need_on_site_visit,
#   urgency,
#   technician_report,
#   diy_instructions,
#   gcs_uri
# FROM AI.GENERATE_TABLE(
#   MODEL `database.gemini_flash`,
#   (
#     SELECT (
#       'CUSTOMER PROFILE: ',
#       'Age: ', CAST(age AS STRING), ', ',
#       'Life Stage: ', life_stage, ', ',
#       'Home Type: ', home_type, ', ',
#       'Family Size: ', CAST(family_size AS STRING), ', ',
#       'Work From Home: ', CASE WHEN work_from_home_flag THEN 'Yes' ELSE 'No' END, ', ',
#       'Home Ownership: ', home_ownership, ', ',
#       'Location: ', city, ', Postal Code: ', postal_code, '. ',
#
#       'CUSTOMER ISSUE: ', issue_description, '. ',
#
#       'ANALYSIS REQUIRED: ',
#       '1. Device name (doorbell, camera, sensor, keypad, lock, etc.) ',
#       '2. Is this Hardware or Software issue? ',
#       '3. Onsite visit required: TRUE if technician needed, FALSE if customer can fix with guidance ',
#       '4. Urgency: Measure the urgency on a scale of 1-5 with 5 being the highest'
#       '5. TECHNICIAN REPORT (if onsite visit TRUE): ',
#       '   Include customer context - Customer is ', CAST(age AS STRING), ' years old, ',
#       life_stage, ', located in ', city, ' (Postal: ', postal_code, '). ',
#       home_type, ' home with ', CASE WHEN work_from_home_flag THEN 'work from home setup' ELSE 'traditional work arrangement' END, '. ',
#       '   Then provide: Issue verification, Severity (Low/Medium/High), Required tools and parts, Step-by-step repair actions, Estimated time ',
#
#       '6. DIY INSTRUCTIONS (if onsite visit FALSE): ',
#       '   Personalize for this customer profile - Consider they are ', life_stage,
#       CASE WHEN work_from_home_flag THEN ' working from home' ELSE '' END,
#       ' in a ', home_type, '. ',
#       '   Provide simple, numbered steps they can follow during a guided support call. ',
#       '   Make instructions appropriate for their technical comfort level.',
#       image_ref
#     ) AS prompt,
#     ticket_id,
#     customer_id,
#     technician_id,
#     issue_description,
#     gcs_uri
#     FROM `database.active_customer_tickets_mm`
#   ),
#   STRUCT(
#     "device_name STRING, hardware_or_software STRING,need_on_site_visit BOOL,urgency INT64, technician_report STRING ,diy_instructions STRING" AS output_schema
#   )
# ));
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Let's look at the table created a look at few sample cases

# %%
# %%bigquery tech_soln  --project {project_id}
#
# select * from `database.active_customer_tickets_solutions` order by ticket_id;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
##Display the table
tech_soln['hardware_or_software']=tech_soln['hardware_or_software'].str.lower()
tech_soln['has_tech_report'] = tech_soln['technician_report'].apply(lambda x: 0 if pd.isna(x) or x == '' else 1)
tech_soln['has_diy_instruction'] = tech_soln['diy_instructions'].apply(lambda x: 0 if pd.isna(x) or x == '' else 1)

tech_soln
# Out:
#      ticket_id                                  issue_description  \
# 0   TICKET_001  My main Security Panel is beeping every minute...
# 1   TICKET_002  The touchscreen on our Security Panel is compl...
# 2   TICKET_003  There's a 'Comm Fail' error on our security pa...
# 3   TICKET_004  My panel keeps losing AC power and then gettin...
# 4   TICKET_005  I can't arm my system. The panel says 'Device ...
# ..         ...                                                ...
# 95  TICKET_096  My doorbell transformer is in the attic and I ...
# 96  TICKET_097  The indoor camera keeps detecting the reflecti...
# 97  TICKET_098  My doorbell is not sending any motion alerts a...
# 98  TICKET_099  The plastic mount for my indoor camera broke. ...
# 99  TICKET_100  My outdoor camera is offline. I checked the po...
#
#                            device_name hardware_or_software  \
# 0             Security Panel (TriLink)             hardware
# 1                       Security Panel             hardware
# 2                Security Panel/Keypad             hardware
# 3   Security System Panel Power Supply             hardware
# 4                      security system             hardware
# ..                                 ...                  ...
# 95                Doorbell transformer             hardware
# 96                              camera             software
# 97                            doorbell             software
# 98                       indoor camera             hardware
# 99                              camera             hardware
#
#     need_on_site_visit  urgency  \
# 0                 True        4
# 1                 True        5
# 2                 True        5
# 3                False        3
# 4                 True        5
# ..                 ...      ...
# 95                True        3
# 96               False        2
# 97               False        3
# 98               False        2
# 99                True        4
#
#                                     technician_report  \
# 0   Customer is 64 years old, Empty_Nest, located ...
# 1   Customer is 46 years old, part of a Young_Fami...
# 2   Customer is 57 years old, part of an Establish...
# 3
# 4   Customer (58, Empty_Nest, working from home in...
# ..                                                ...
# 95  Customer context: Customer is 45 years old, pa...
# 96
# 97                                               null
# 98
# 99  Customer is 39 years old, part of an Establish...
#
#                                      diy_instructions  \
# 0
# 1
# 2
# 3   Hello! We understand that a constantly beeping...
# 4
# ..                                                ...
# 95
# 96  Hello! We understand that false motion alerts ...
# 97  Hello! We understand it's important for your f...
# 98  Hello! We understand that a reliable indoor ca...
# 99  Given the symptoms and the nature of an outdoo...
#
#                                        gcs_uri  has_tech_report  \
# 0   gs://trilink/ticket-images/TICKET_001.jpeg                1
# 1   gs://trilink/ticket-images/TICKET_002.jpeg                1
# 2   gs://trilink/ticket-images/TICKET_003.jpeg                1
# 3   gs://trilink/ticket-images/TICKET_004.jpeg                0
# 4   gs://trilink/ticket-images/TICKET_005.jpeg                1
# ..                                         ...              ...
# 95  gs://trilink/ticket-images/TICKET_096.jpeg                1
# 96  gs://trilink/ticket-images/TICKET_097.jpeg                0
# 97  gs://trilink/ticket-images/TICKET_098.jpeg                1
# 98  gs://trilink/ticket-images/TICKET_099.jpeg                0
# 99  gs://trilink/ticket-images/TICKET_100.jpeg                1
#
#     has_diy_instruction
# 0                     0
# 1                     0
# 2                     0
# 3                     1
# 4                     0
# ..                  ...
# 95                    0
# 96                    1
# 97                    1
# 98                    1
# 99                    1
#
# [100 rows x 11 columns]

# %% [markdown]
# Summary analysis == Let's look at:
#
# - Freq of tickets that needs a technician
# - Freq of issue type (hardware/software)
# - Freq of Urgency
#
# Then let's look at few cases and see what the issue was, solution deemed and correspodning reports made

# %%
for col in ['need_on_site_visit', 'hardware_or_software', 'urgency','has_tech_report','has_diy_instruction']:
    print(f"\n{col}:")
    print(tech_soln.groupby(col).agg({'ticket_id':'count'}))
# Out:
# need_on_site_visit:
#                     ticket_id
# need_on_site_visit
# False                      62
# True                       36
#
# hardware_or_software:
#                       ticket_id
# hardware_or_software
# hardware                     63
# service quality               1
# software                     34
#
# urgency:
#          ticket_id
# urgency
# 1                3
# 2                7
# 3               35
# 4               38
# 5               15
#
# has_tech_report:
#                  ticket_id
# has_tech_report
# 0                       45
# 1                       55
#
# has_diy_instruction:
#                      ticket_id
# has_diy_instruction
# 0                           27
# 1                           73

# %% [markdown]
# - We see some cases where the DIY and Tech report is created. However the usage of them depends on the need_on_site_visit flag. Business can double check these manually if needed to, but the urgency and need_on_site_visit should help business prioritize what tikets to assign to techniciains on prority so their valuable time can be used to optimal maximum
#
# - Let's see some sample customer cases now

# %%
tickt_id = 'TICKET_070'
xdf = tech_soln[tech_soln['ticket_id'] == tickt_id].iloc[0]

print(f"🎫 Ticket: {tickt_id}")
print(f"📋 Issue: {xdf['issue_description']}")
print(f"🔧 Device: {xdf['device_name']} | Type: {xdf['hardware_or_software']}")
print(f"🚨 Urgency: {xdf['urgency']}/5 | Onsite Visit Needed: {'Yes' if xdf['need_on_site_visit'] == True else 'No'}\n")

# Display image
gcs_uri = xdf['gcs_uri']
public_url = gcs_uri.replace('gs://', 'https://storage.googleapis.com/')
display(Image(url=public_url, width=500))

# Show resolution
if xdf['need_on_site_visit'] == True:
    print("\n👨‍🔧 TECHNICIAN REPORT:")
    print(xdf['technician_report'] if xdf['technician_report'] != 'null' else 'Not available')
else:
    print("\n🛠️ DIY INSTRUCTIONS:")
    print(xdf['diy_instructions'])
# Out:
# 🎫 Ticket: TICKET_070
# 📋 Issue: There is a loud humming noise coming from my main security panel box in the closet. It just started today and I'm worried it's a fire hazard.
# 🔧 Device: Security Panel | Type: hardware
# 🚨 Urgency: 5/5 | Onsite Visit Needed: Yes
# <img src="https://storage.googleapis.com/trilink/ticket-images/TICKET_070.jpeg" width="500"/>
# 👨‍🔧 TECHNICIAN REPORT:
# Customer (44 years old, Established_Family, Single_Family home, 4 family members, not WFH, home owner in Toronto, M1S 0F1) reports a loud humming noise from the main security panel box in their closet, starting today, and is concerned about a fire hazard.
#
# Issue verification: The humming noise likely originates from the transformer or power supply circuit within the security panel, as indicated by the presence of a transformer in the provided image. This could signify an electrical fault or component failure.
# Severity: High. A loud hum from an electrical component, especially with a stated fire hazard concern, warrants immediate professional attention.
# Required tools and parts: Multimeter, insulated screwdriver set, wire strippers, potentially a replacement power supply board or transformer for the security panel.
# Step-by-step repair actions: 1. Safely de-energize the security panel by locating and turning off the corresponding circuit breaker. 2. Visually inspect the panel's internal components for signs of overheating, bulging capacitors, loose connections, or burnt areas, focusing on the transformer and power supply board. 3. Use a multimeter to test voltage outputs and continuity within the power supply circuit to pinpoint the exact source of the electrical hum or fault. 4. If the transformer or power supply board is identified as faulty, carefully replace the component with a compatible part. 5. Ensure all wiring connections are secure and properly insulated. 6. Re-energize the panel and monitor the system to confirm the humming noise has ceased and all security functions are operating correctly.
# Estimated time: 1-2 hours.

# %%
tickt_id = 'TICKET_081'
xdf = tech_soln[tech_soln['ticket_id'] == tickt_id].iloc[0]

print(f"🎫 Ticket: {tickt_id}")
print(f"📋 Issue: {xdf['issue_description']}")
print(f"🔧 Device: {xdf['device_name']} | Type: {xdf['hardware_or_software']}")
print(f"🚨 Urgency: {xdf['urgency']}/5 | Onsite Visit Needed: {'Yes' if xdf['need_on_site_visit'] == True else 'No'}\n")

# Display image
gcs_uri = xdf['gcs_uri']
public_url = gcs_uri.replace('gs://', 'https://storage.googleapis.com/')
display(Image(url=public_url, width=500))

# Show resolution
if xdf['need_on_site_visit'] == True:
    print("\n👨‍🔧 TECHNICIAN REPORT:")
    print(xdf['technician_report'] if xdf['technician_report'] != 'null' else 'Not available')
else:
    print("\n🛠️ DIY INSTRUCTIONS:")
    print(xdf['diy_instructions'])
# Out:
# 🎫 Ticket: TICKET_081
# 📋 Issue: My doorbell camera is recording clips, but there is no sound at all. I have checked all the volume settings.
# 🔧 Device: doorbell camera | Type: software
# 🚨 Urgency: 3/5 | Onsite Visit Needed: No
# <img src="https://storage.googleapis.com/trilink/ticket-images/TICKET_081.jpeg" width="500"/>
# 🛠️ DIY INSTRUCTIONS:
# Hello! We understand you're experiencing issues with the audio on your doorbell camera recordings. As an Established_Family in your Toronto home, it's important to have all your security features working correctly. It looks like the audio might simply be disabled in the app settings. Here are some steps you can follow during our call to enable it: 1. Open the Trillink app on your smartphone. 2. Navigate to the Live View of your Front Door Camera. 3. Look for a gear icon (⚙️) or settings icon, often located near the 'Audio Disabled' text or at the bottom right of the video player. 4. Tap on this settings icon to access the camera's specific settings. 5. Within the camera settings, locate an option related to 'Audio Recording', 'Microphone', or 'Sound'. 6. Ensure that this option is toggled 'On' or 'Enabled'. It might currently be set to 'Off' or 'Disabled'. 7. Save any changes if prompted. 8. Exit the settings and test your doorbell camera by recording a new clip or viewing live footage to confirm the audio is now working.

# %%
tickt_id = 'TICKET_005'
xdf = tech_soln[tech_soln['ticket_id'] == tickt_id].iloc[0]

print(f"🎫 Ticket: {tickt_id}")
print(f"📋 Issue: {xdf['issue_description']}")
print(f"🔧 Device: {xdf['device_name']} | Type: {xdf['hardware_or_software']}")
print(f"🚨 Urgency: {xdf['urgency']}/5 | Onsite Visit Needed: {'Yes' if xdf['need_on_site_visit'] == True else 'No'}\n")

# Display image
gcs_uri = xdf['gcs_uri']
public_url = gcs_uri.replace('gs://', 'https://storage.googleapis.com/')
display(Image(url=public_url, width=500))

# Show resolution
if xdf['need_on_site_visit'] == True:
    print("\n👨‍🔧 TECHNICIAN REPORT:")
    print(xdf['technician_report'] if xdf['technician_report'] != 'null' else 'Not available')
else:
    print("\n🛠️ DIY INSTRUCTIONS:")
    print(xdf['diy_instructions'])
# Out:
# 🎫 Ticket: TICKET_005
# 📋 Issue: I can't arm my system. The panel says 'Device Fault' but doesn't tell me which sensor is the problem. All my doors and windows are closed. This just started happening today.
# 🔧 Device: security system | Type: hardware
# 🚨 Urgency: 5/5 | Onsite Visit Needed: Yes
# <img src="https://storage.googleapis.com/trilink/ticket-images/TICKET_005.jpeg" width="500"/>
# 👨‍🔧 TECHNICIAN REPORT:
# Customer (58, Empty_Nest, working from home in a Toronto Townhouse, Postal: M6G 0L8) is unable to arm their security system due to a 'Device Fault' message displayed on the panel/app. The system does not specify which sensor is causing the problem, despite the customer confirming all doors and windows are closed. This issue began today.
#
# Issue verification: Confirm 'Device Fault' message and inability to arm the system. Attempt to access the system's diagnostic menu or fault log to identify the specific faulty device. Perform a full walk-test of all zones if system diagnostics are unspecific.
# Severity: Medium (Security system compromised).
# Required tools and parts: Security system diagnostic tool, multimeter, various sensor batteries (e.g., CR2032, AA, AAA, 12V), common replacement sensors (door/window contact, motion detector), small electronics screwdriver set.
# Step-by-step repair actions:1. Verify the 'Device Fault' message on the customer's panel/app and confirm the inability to arm the system.2. Access the security system's main panel or technician interface to retrieve detailed fault codes or status for all connected devices.3. Identify the specific sensor or device causing the 'Device Fault'. If not immediately apparent, perform a comprehensive walk-test of all installed sensors to pinpoint the non-responsive or faulty unit.4. Once the faulty device is identified, troubleshoot it by:   a. Checking and replacing its battery.   b. Inspecting for any physical damage, misalignment, or obstruction.   c. Verifying wireless signal strength or wired connections.5. If troubleshooting steps fail, replace the faulty sensor/device with a new one and re-enroll it into the system.6. Conduct a full system test, including arming/disarming cycles and a complete walk-test, to ensure all zones are functioning correctly and the system can be armed without issues.7. Review basic system status checking with the customer to help them identify future minor issues.
# Estimated time: 1.5 - 2 hours.

# %%
tickt_id = 'TICKET_056'
xdf = tech_soln[tech_soln['ticket_id'] == tickt_id].iloc[0]

print(f"🎫 Ticket: {tickt_id}")
print(f"📋 Issue: {xdf['issue_description']}")
print(f"🔧 Device: {xdf['device_name']} | Type: {xdf['hardware_or_software']}")
print(f"🚨 Urgency: {xdf['urgency']}/5 | Onsite Visit Needed: {'Yes' if xdf['need_on_site_visit'] == True else 'No'}\n")

# Display image
gcs_uri = xdf['gcs_uri']
public_url = gcs_uri.replace('gs://', 'https://storage.googleapis.com/')
display(Image(url=public_url, width=500))

# Show resolution
if xdf['need_on_site_visit'] == True:
    print("\n👨‍🔧 TECHNICIAN REPORT:")
    print(xdf['technician_report'] if xdf['technician_report'] != 'null' else 'Not available')
else:
    print("\n🛠️ DIY INSTRUCTIONS:")
    print(xdf['diy_instructions'])
# Out:
# 🎫 Ticket: TICKET_056
# 📋 Issue: I pressed the 'Test' button on my smoke alarm and it's very quiet. The sound is muffled and weak, not loud like it should be.
# 🔧 Device: smoke alarm | Type: hardware
# 🚨 Urgency: 5/5 | Onsite Visit Needed: No
# <img src="https://storage.googleapis.com/trilink/ticket-images/TICKET_056.jpeg" width="500"/>
# 🛠️ DIY INSTRUCTIONS:
# Hello! It's understandable to be concerned about your smoke alarm not sounding properly, especially for your family's safety in your Toronto townhouse. Let's try some simple steps together to get it working as it should. Please take your time and follow these instructions carefully:
# 1.  Safety First: If your smoke alarm is on the ceiling, please ensure you have a stable step stool or ladder to reach it safely. You might find it helpful to have another family member assist you.
# 2.  Inspect for Obstructions: Carefully look at the vents and openings on the side of the smoke alarm. Sometimes dust, cobwebs, or even paint can partially block the speaker. If safe to do so, gently wipe around these openings with a dry cloth or use a soft brush to clear any visible debris.
# 3.  Replace Batteries: The most common reason for a weak or muffled alarm is low batteries. Even if the alarm chirps intermittently, a weak test sound often points to this.
#     *   Gently twist or unlatch the smoke alarm from its mounting bracket on the ceiling. (Refer to your alarm's manual if unsure).
#     *   Locate the battery compartment, usually on the back or side. Open it.
#     *   Carefully remove the old batteries. Take note of the positive (+) and negative (-) terminals.
#     *   Insert brand-new, fresh batteries (e.g., 9V, AA, or AAA, depending on your model), ensuring they are correctly oriented according to the markings.
#     *   Close the battery compartment securely and reattach the smoke alarm firmly to its mounting bracket.
# 4.  Test Again: Once the new batteries are in and the alarm is back in place, press and hold the 'Test' button firmly for a few seconds. Listen carefully to the loudness of the alarm. It should now be a clear, piercing, loud sound.
# 5.  If the Issue Persists: If the alarm is still muffled or quiet after replacing the batteries, or if you have a sealed-battery alarm where batteries cannot be replaced, it likely indicates that the unit itself needs to be replaced. Please contact us again for further assistance, and we can discuss replacement options or arrange for a technician if installation is complex for your townhouse.

# %%
tickt_id = 'TICKET_013'
xdf = tech_soln[tech_soln['ticket_id'] == tickt_id].iloc[0]

print(f"🎫 Ticket: {tickt_id}")
print(f"📋 Issue: {xdf['issue_description']}")
print(f"🔧 Device: {xdf['device_name']} | Type: {xdf['hardware_or_software']}")
print(f"🚨 Urgency: {xdf['urgency']}/5 | Onsite Visit Needed: {'Yes' if xdf['need_on_site_visit'] == True else 'No'}\n")

# Display image
gcs_uri = xdf['gcs_uri']
public_url = gcs_uri.replace('gs://', 'https://storage.googleapis.com/')
display(Image(url=public_url, width=500))

# Show resolution
if xdf['need_on_site_visit'] == True:
    print("\n👨‍🔧 TECHNICIAN REPORT:")
    print(xdf['technician_report'] if xdf['technician_report'] != 'null' else 'Not available')
else:
    print("\n🛠️ DIY INSTRUCTIONS:")
    print(xdf['diy_instructions'])
# Out:
# 🎫 Ticket: TICKET_013
# 📋 Issue: There are small black dots or specks all over my indoor camera's video feed. I've wiped the outside of the lens but they're still there. It's like there is dust inside it.
# 🔧 Device: indoor camera | Type: hardware
# 🚨 Urgency: 4/5 | Onsite Visit Needed: Yes
# <img src="https://storage.googleapis.com/trilink/ticket-images/TICKET_013.jpeg" width="500"/>
# 👨‍🔧 TECHNICIAN REPORT:
# Customer (40, Young_Family) located in a Single_Family home in Toronto (M2Z 5X4) with a work-from-home setup. Issue verification: The customer's indoor camera displays numerous small black dots/specks across the video feed, significantly obstructing the view. This indicates internal debris or dust within the camera's lens assembly, not externally cleanable. Severity: High, as the camera's primary function of clear monitoring is severely compromised. Required tools and parts: New Trilinik Indoor Cam unit, basic technician toolkit (screwdrivers, mounting hardware), ladder (if camera is mounted high). Step-by-step repair actions: 1. Arrive at the customer's Single_Family home. 2. Greet the customer and verify the reported issue by observing the camera's live feed, confirming the black specks. 3. Confirm that the issue is due to internal hardware failure/debris by noting no external damage or smudges. 4. Safely unmount the existing faulty Trilinik Indoor Cam. 5. Install the new Trilinik Indoor Cam unit in the same location, ensuring secure mounting. 6. Connect the new camera to the customer's system and ensure it is properly configured and online. 7. Test the live video feed to confirm a clear, unobstructed image. 8. Verify full functionality with the customer before concluding the visit. Estimated time: 30-45 minutes.

# %% [markdown]
# #### Action 5 - BigQuery AI powered ADK agent as chatbot
#
# - Idea:
#     - We have a personalized emailing for retention, vector search for similar calls, best actions, agent coaching etc. created
#     - These are jobs that can be scheduled for mass campaigns or weekly scheduled reports
#     - However, we can also make this available as a real time assistant with same BigQuery tools added as tools to an ADK agent
#     - For example, the call center agent can now:-
#         - Get basic details about the customer and so initial approaches agent should follow at the start of the call
#         - During the call can ask for next best actions given a scenario and can get it pulled up straght from business actions vector search from bigquery as tool
#         - During the live call, pull up the customized personal message to make for the retention customer using similar bigquery AI.Generate ran for that customer
#         - During live call Pull similar calls and how other agents handled it
#         - Pull up the DIY ticket solution for a customer and walk them through it to solve a ticket on phone saving valuable techncian and customer's time
#     - A Technician can now:-
#         - Ask details about the work order scheduled by asking like "Give me the most urgent ticket to solve in Toronto that needs repair on security panel"
#         - Ask about most similar techncial solutions to a problem using the vector search
#     - Business:-
#         - Can use BigQuery AI questions about customer base, current tickets, brainstorm on how to assign tickets efficiently etc among many things

# %% [markdown]
# NOTE: Make sure you add the below in .env file. Querystore loads the database and project from .env
#
#     project_id='your-project-id'
#     database_name = 'your-database'

# %%
from typing import Dict, List, Any, Optional
from google.adk.agents import LlmAgent
from google.adk.tools import FunctionTool

from queries.querystore import QueryStore
from google.adk.agents import Agent
from google.adk.runners import InMemoryRunner
from google.adk.sessions import InMemorySessionService
from google.genai import types

import asyncio
import datetime
import requests
import os
import warnings
# Suppress warnings
warnings.filterwarnings("ignore")
os.environ["PYTHONWARNINGS"] = "ignore"
# Set only one API key to avoid the "Both GOOGLE_API_KEY and GEMINI_API_KEY" warning
if "GEMINI_API_KEY" in os.environ:
    del os.environ["GEMINI_API_KEY"]
client = bigquery.Client(project=project_id)

qs=QueryStore()

# %% [markdown]
# ##### Create BigQuery Tools for Agent Assistant

# %%
def get_customer_personalized_retention_message(customer_id: str) -> Dict[str, Any]:
    """
    Generate a personalized retention script and problem analysis for a specific customer 
    using BigQuery AI capabilities.
    
    This function performs the following operations:
    1. Executes ML.EXPLAIN_PREDICT to analyze churn risk factors
    2. Uses VECTOR_SEARCH to find similar business problems and solutions
    3. Generates personalized retention script using AI.GENERATE
    4. Returns formatted results for agent use
    
    Args:
        customer_id (str): The unique customer identifier to analyze.
                          Must be a valid customer ID that exists in the database.
                          Example: "c123456"
    
    Returns:
        Dict[str, Any]: A dictionary containing:
            - success (bool): True if query executed successfully, False otherwise
            - retention_script (str): AI-generated personalized retention script for agent
            - customer_problem_identified (str): Analysis of customer's pain points and issues
            - error (str, optional): Error message if success=False
            - customer_id (str): The input customer ID for reference
    """
    try:
        query = qs.get_retention_call_script_mobile_query(customer_id=customer_id)
        query_job = client.query(query)
        df = query_job.to_dataframe()
        if df.empty:
            return {
                "success": False,
                "error": f"No data found for customer {customer_id}",
                "customer_id": customer_id
            }
        else:
            return {
                "success": True,
                "retention_script": str(df['live_retention_script'].iloc[0]),
                "customer_problem_identified": str(df["problem_analysis"].iloc[0]),
                "customer_churn_probability": df['churn_probability_percent'].iloc[0],
                "customer_id": customer_id
            }
    except Exception as e:
        return {
            "success": False,
            "error": f"Error processing customer {customer_id}: {str(e)}",
            "customer_id": customer_id
        }

# %%
def get_customer_info(customer_id: str) -> Dict[str, Any]:
    """
    Generates the basic details about the customer and so initial approaches agent should follow  
    using BigQuery AI capabilities.
    
    This function performs the following operations:
    1. Collects customers demographcis and all 3 service information if available
    2. Generates a quick Note for Agent using AI.GENERATE on gemini-2.5-flash-lite on 
        - Who the customer is
        - Personalized Conversation approach to follow
        - Key Talking points to discuss in case any delay on system processing or call hold is happenign
        - Potential cross/upsell opportunities available for customer 
    4. Returns formatted results for agent use
    
    Args:
        customer_id (str): The unique customer identifier to analyze.
                          Must be a valid customer ID that exists in the database.
                          Example: "c123456"
    
    Returns:
        Dict[str, Any]: A dictionary containing:
            - success (bool): True if query executed successfully, False otherwise
            - customer_info (str): AI-generated quick Note for Agent to use in his/her conversation with customer at start
            - error (str, optional): Error message if success=False
            - customer_id (str): The input customer ID for reference
    """
    try:
        query = qs.get_customer_info(customer_id=customer_id)
        query_job = client.query(query)
        df = query_job.to_dataframe()
        if df.empty:
            return {
                "success": False,
                "error": f"No data found for customer {customer_id}",
                "customer_id": customer_id
            }
        else:
            return {
                "success": True,
                "customer_info": str(df['customer_info'].iloc[0]),
                "customer_id": customer_id
            }
    except Exception as e:
        return {
            "success": False,
            "error": f"Error processing customer {customer_id}: {str(e)}",
            "customer_id": customer_id
        }

# %%
def get_business_solution_recommendations(problem_description: str):
    """
    Finds the closest matching business solutions based on problem description
    using vector similarity search
    
    This function performs the following operations:
    1. Agent can pass the problem customer is facing
    2. Vector search is done with the business solution vector store and the closest matching problem and its business solution is returned
    3. Root agent summarized and gives the best solution possible to agent
    
    Args:
        problem_description: The description of the problem the customer is facing that the agent is looking a solution for  
        
    Returns:
        Dictionary containing:
            - success: True if query executed successfully, False otherwise
            - problem_description: AI-generated quick Note for Agent to use in his/her conversation with customer at start
            - closest_matched_business_problem: The closest matched business problem from vector store
            - matched_problem: The business solution to the closest matched business problem to customers issue
            - error: Error message if success=False
    """
    try:
        query = qs.get_business_solution_recommendations(problem_description=problem_description)
        query_job = client.query(query)
        df = query_job.to_dataframe()
        if df.empty:
            return {
                "success": False,
                "error": f"No data found for problem_description {problem_description}"
            }
        else:
            return {
                "success": True,
                "problem_description": f"Customers Problem is: {problem_description}",
                "matched_problem": f"Closest Matched problem from business solution book is: {str(df['matched_problem'].iloc[0])}",
                "solution": f"Solution to this matched problem by business is: {str(df['recommended_solution'].iloc[0])}"
            }
    except Exception as e:
        return {
            "success": False,
            "error": f"Error processing customer {problem_description}: {str(e)}",
        }

# %%
def get_ticket_solution(customer_id: str) -> Dict[str, Any]:
    """
    Pulls up the solutions created for the tickets customer have made for their security devices.
    
    Will provide the resolution made for all the tickets and Step by step DIY instructions 
    if the issue was deemed to be solved on phone by agent.
    
    This function performs the following operations:
    1. Looks up the solutions for customer tickets created by customer_id
    2. Collects the resolution note and instructions to pass to customer for next actions
    3. If the resolution states a technician visit, convey the message to customer that 
       a technician will be coming shortly to solve their problem and they have all the 
       details of the issues
    4. If the resolution states "We will troubleshoot this on phone now", explain to 
       customer step by step how to solve their problem on phone
    
    Args:
        customer_id (str): The unique customer identifier to analyze.
                          Must be a valid customer ID that exists in the database.
                          Example: "c123456"
    
    Returns:
        Dict[str, Any]: A dictionary containing:
            - success (bool): True if query executed successfully, False otherwise
            - tickets (List[Dict]): List of ticket resolutions with details
            - ticket_count (int): Number of tickets found
            - customer_id (str): The input customer ID for reference
            - error (str, optional): Error message if success=False
    """
    try:
        query = qs.get_diy_solution(customer_id=customer_id)
        query_job = client.query(query)
        df = query_job.to_dataframe()
        
        if df.empty:
            return {
                "success": False,
                "error": f"No ticket resolutions found for customer {customer_id}",
                "customer_id": customer_id,
                "ticket_count": 0
            }
        
        # Convert DataFrame rows to list of dictionaries with structured information
        tickets = []
        for _, row in df.iterrows():
            ticket_info = {
                "issue_description": row.get('issue_description', ''),
                "device_name": row.get('device_name', ''),
                "hardware_or_software": row.get('hardware_or_software', ''),
                "urgency": row.get('urgency', ''),
                "resolution_mode": row.get('resolution_mode', ''),
                "diy_instructions": row.get('diy_instructions', '')
            }
            tickets.append(ticket_info)
        
        return {
            "success": True,
            "tickets": tickets,
            "ticket_count": len(tickets),
            "customer_id": customer_id,
            "summary": f"Found {len(tickets)} ticket resolution(s) for customer {customer_id}"
        }
        
    except Exception as e:
        return {
            "success": False,
            "error": f"Error processing customer {customer_id}: {str(e)}",
            "customer_id": customer_id,
            "ticket_count": 0
        }

# %% [markdown]
# ##### Create BigQuery Tools for Technician Assistant

# %%
def get_tech_reports(tech_id: str, city: str) -> Dict[str, Any]:
    """
    Retrieves all active tickets assigned to a specific technician in a given city.
    
    This function pulls complete ticket information including issue descriptions,
    device details, urgency levels, and detailed technician reports for on-site visits.
    
    Args:
        tech_id (str): The unique technician identifier.
                      Example: "TECH001"
        city (str): The city where tickets are located.
                   Example: "Toronto"
    
    Returns:
        Dict[str, Any]: A dictionary containing:
            - success (bool): True if query executed successfully, False otherwise
            - tickets (List[Dict]): List of active tickets with full details
            - ticket_count (int): Number of tickets found
            - tech_id (str): The input technician ID for reference
            - city (str): The input city for reference
            - urgency_summary (Dict): Count of tickets by urgency level
            - error (str, optional): Error message if success=False
    """
    try:
        query = qs.get_tech_reports(tech_id=tech_id, city=city)
        query_job = client.query(query)
        df = query_job.to_dataframe()
        
        if df.empty:
            return {
                "success": False,
                "error": f"No active tickets found for technician {tech_id} in {city}",
                "tech_id": tech_id,
                "city": city,
                "ticket_count": 0
            }
        
        # Convert DataFrame rows to list of dictionaries with structured information
        tickets = []
        urgency_counts = {}
        
        for _, row in df.iterrows():
            urgency = str(row.get('urgency', ''))
            urgency_counts[urgency] = urgency_counts.get(urgency, 0) + 1
            
            ticket_info = {
                "ticket_id": row.get('ticket_id', ''),
                "device_name": row.get('device_name', ''),
                "hardware_or_software": row.get('hardware_or_software', ''),
                "urgency": urgency,
                "issue_description": row.get('issue_description', ''),
                "technician_report": row.get('technician_report', ''),
                "city": row.get('city', ''),
                "postal_code": row.get('postal_code', '')
            }
            tickets.append(ticket_info)
        
        # Sort tickets by urgency (highest first)
        tickets.sort(key=lambda x: int(x['urgency']) if x['urgency'].isdigit() else 0, reverse=True)
        
        return {
            "success": True,
            "tickets": tickets,
            "ticket_count": len(tickets),
            "tech_id": tech_id,
            "city": city,
            "urgency_summary": urgency_counts,
            "summary": f"Found {len(tickets)} active ticket(s) for technician {tech_id} in {city}"
        }
        
    except Exception as e:
        return {
            "success": False,
            "error": f"Error retrieving tickets for technician {tech_id} in {city}: {str(e)}",
            "tech_id": tech_id,
            "city": city,
            "ticket_count": 0
        }
        
def get_tech_solution(question: str) -> Dict[str, Any]:
    """
    Searches the knowledge base for similar technical issues and their solutions.
    
    This function uses vector similarity search to find the most relevant past issues
    and their solutions based on the technician's question. Returns detailed solution
    steps and technician notes from previous similar cases.
    
    Args:
        question (str): The technical question or problem description from the technician.
                       Should be a clear description of the issue they're facing.
                       Example: "Camera showing flickering lines on the screen"
    
    Returns:
        Dict[str, Any]: A dictionary containing:
            - success (bool): True if query executed successfully, False otherwise
            - solutions (List[Dict]): List of similar problems with solutions and notes
            - solution_count (int): Number of relevant solutions found
            - question (str): The input question for reference
            - has_relevant_solutions (bool): True if distance <= 0.3 for any result
            - best_match_distance (float, optional): Distance score of best match
            - error (str, optional): Error message if success=False
    """
    try:
        query = qs.get_tech_solution(question=f"'{question}'")
        query_job = client.query(query)
        df = query_job.to_dataframe()
        
        if df.empty:
            return {
                "success": True,
                "solutions": [],
                "solution_count": 0,
                "question": question,
                "has_relevant_solutions": False,
                "message": "No highly relevant solutions found in knowledge base. This appears to be a new or unique issue."
            }
        
        # Convert DataFrame rows to list of dictionaries with structured information
        solutions = []
        
        for _, row in df.iterrows():
            solution_info = {
                "matched_problem": row.get('matched_problem', ''),
                "recommended_solution": row.get('recommended_solution', ''),
                "technician_notes": row.get('technician_notes', ''),
                "similarity_distance": float(row.get('distance', 1.0))
            }
            solutions.append(solution_info)
        
        # Sort by distance (closest match first)
        solutions.sort(key=lambda x: x['similarity_distance'])
        
        best_distance = solutions[0]['similarity_distance'] if solutions else 1.0
        
        return {
            "success": True,
            "solutions": solutions,
            "solution_count": len(solutions),
            "question": question,
            "has_relevant_solutions": best_distance <= 0.3,
            "best_match_distance": best_distance,
            "summary": f"Found {len(solutions)} similar case(s) in knowledge base"
        }
        
    except Exception as e:
        return {
            "success": False,
            "error": f"Error searching knowledge base for '{question}': {str(e)}",
            "question": question,
            "solution_count": 0,
            "has_relevant_solutions": False
        }

# %%
# Define the Agent assitant agent
agent_assistant = LlmAgent(
    name="agent_assistant",
    model="gemini-2.5-flash",
    instruction= """You are an agent assitant at TriLink. Your job is to help the agent find answers to their questions using the appropriate tools you have access to.
    If you don't know or don't have the tools to answer, say Sorry I can't help with that
    
    
    **Tool Usage Guidelines:**
    
    - If agent asks for a customer summary/notes/who the customer is  - use get_customer_info tool
    - If agent needs a retention script to follow or agent needs help to prevent churn for a customer, use get_customer_personalized_retention_message tool
    - If agent asks for help with an issue or look for what's the ideal businesss solution for a problem 
        - use get_business_solution_recommendations tool to get the matched problem and it's solution
        - Then analyze the actual customer issue,similarity of that to matched problem, who the customer is and what their plans/services are etc if it's available
        - Then create a personalized solution to offer for customers issue
        
     - **If agent asks about existing tickets, ticket resolutions, DIY instructions, or help with previously reported issues - use get_ticket_solution tool**
    
    **When using get_ticket_solution:**
    1. The tool will return multiple tickets if they exist
    2. For EACH ticket, check the resolution_mode field:
    
       **If resolution_mode = "Technician will visit site soon":**
       - Inform the customer that a technician has been scheduled to visit their location
       - Assure them the technician has all the details about their device_name issue
       - Let them know the technician will resolve the problem professionally
       - Ask if they have any questions while they wait
       
       **If resolution_mode = "We will troubleshoot this on phone now":**
       - Tell the customer you can help them resolve this issue right now over the phone
       - Present the DIY instructions step-by-step in a clear, easy-to-follow format
       - After presenting the instructions, ask: "Would you like me to walk you through these steps one at a time?"
       - If they say yes, guide them through each step, waiting for confirmation before moving to the next
       - If they say no, ask if they need clarification on any specific step
       - Check if the solution worked and if they need any additional help
    
    3. If multiple tickets are returned, address each one separately and ask which issue they'd like to focus on first
    
    **Communication Style:**
    - Be warm, patient, and reassuring
    - Use simple, non-technical language when explaining DIY steps
    - Break complex instructions into smaller, manageable steps
    - Always confirm understanding before moving forward
    - Show empathy for their frustration or concern
    """,
    
    description="Agent Assitant",
    tools=[
        FunctionTool(get_customer_personalized_retention_message),
        FunctionTool(get_customer_info),
        FunctionTool(get_business_solution_recommendations),
        FunctionTool(get_ticket_solution)
    ]
)

##Design the Techncian assistant agent
##They are powered with bigquery tools
technician_assistant = LlmAgent(
    name="technician_assistant",
    model="gemini-2.5-flash",
    instruction= """You are a technician assistant at TriLink. Your job is to help technicians find answers to their questions using the appropriate tools you have access to.
    If you don't know or don't have the tools to answer, say Sorry I can't help with that.
    
    **Tool Usage Guidelines:**
    
    - **If technician asks for details on tickets assigned to them** - use get_tech_reports tool
    
    - **If technician asks a technical question or needs help troubleshooting an issue** - use get_tech_solution tool
    
    **When using get_tech_reports tool:**
    1. The tool will return multiple tickets if there are any assigned to the technician
    2. Always present tickets in order of urgency (highest urgency first)
    3. Format the output as follows:
    
       **Brief Overview:** 
       Provide a one-sentence summary of each ticket type/device issue
       
       Then for each ticket, present:
       
       **Ticket [ticket_id]:**
       - **Device Affected:** [device_name]
       - **Urgency Level:** [urgency]/5
       - **Location:** [city], [postal_code]
       - **Issue Description:** [issue_description]
       - **Technician Report:** 
         [Present the complete technician report exactly as provided - do not modify or summarize]
       
       ---
    
    **When using get_tech_solution tool:**
    1. The tool searches the knowledge base for similar past issues and solutions
    2. Check the has_relevant_solutions field:
       
       **If has_relevant_solutions = True:**
       - Analyze the matched_problem, recommended_solution, and technician_notes from the results
       - Consider the similarity distance (lower is better, <=0.3 is highly relevant)
       - Synthesize the information to provide detailed next step actions
       - Format your response as:
         
         **Knowledge Base Match Found:**
         - **Similar Issue:** [matched_problem]
         - **Similarity Score:** [show how close the match is]
         - **Recommended Solution Steps:**
           [Present the solution steps clearly]
         - **Technician Notes:**
           [Include important notes and tips from past cases]
         - **Suggested Next Actions:**
           [Based on the retrieved information, provide specific next steps]
       
       **If has_relevant_solutions = False:**
       - Inform the technician: "This appears to be a new or unique issue that we don't have highly relevant information for in our knowledge base."
       - Suggest: "Please consult the device manual or contact technical support for guidance."
       - If there are partial matches (distance > 0.3), you can mention them but note they may not be directly applicable
    
    **Important Guidelines:**
    - Never modify or summarize technician reports from get_tech_reports - present them exactly as they appear
    - For technical solutions, provide actionable next steps based on the knowledge base results
    - Always prioritize safety and proper procedures
    - If multiple similar solutions are found, synthesize the best practices from all of them
    """,
    
    description="Technician Assistant",
    tools=[
        FunctionTool(get_tech_reports),
        FunctionTool(get_tech_solution)
    ]
)

# Define the main agent
trilink_agents = LlmAgent(
    name="trilink_assistant",
    model="gemini-2.5-flash",
    instruction= """You are an assitant at TriLink. Your job is to help the user find answers to their questions by routing the question to appropriate subagents.
    If you don't know or don't have the subagents to answer, say Sorry I can't help with that
    
    
    **Sub Agent Routing Guidelines:**
    
    - If the user is an agent (callcenter) route to agent_assistant subagent
    - If the user is a technician route to technician_assitant subagent

    """,
    
    description="TriLink AI Assitant",
    sub_agents=[agent_assistant,technician_assistant]
)

# %% [markdown]
# ##### Create a session for the call agent where they will use this ADK app powered by BigQuery tools for assistance on demand

# %%
# Constants
APP_NAME = "trilink_app"
USER_ID = "agent_1234"

# Create InMemoryRunner with BOTH agent and app_name
runner = InMemoryRunner(agent=trilink_agents, app_name=APP_NAME)

# Create a session using the runner's session service
session = await runner.session_service.create_session(
    app_name=APP_NAME,  # This must match the app_name used in InMemoryRunner
    user_id=USER_ID
)

PERSISTENT_SESSION_ID = session.id

async def chat_with_trilink_agent_persistent(query: str):
    """Use persistent session to maintain conversation history"""
    print(f"User: {query}")
    
    user_content = types.Content(
        role='user', 
        parts=[types.Part(text=query)]
    )
    
    final_response = ""
    async for event in runner.run_async(
        user_id=USER_ID, 
        session_id=PERSISTENT_SESSION_ID,  # Now this session exists
        new_message=user_content
    ):
        if event.is_final_response() and event.content:
            final_response = event.content.parts[0].text
            
    print(f"TriLink Assistant: {final_response}")
    # return final_response

# %% [markdown]
# Agent started a call wityh customer C00086327. Agent first asks the ADK app who this customer is. ADK agent will:-
#
#     - Will assign the task to agent_assistant agent
#     - agent_assistant will use get_customer_info tool to pull the details of the customers using bigquery AI.GENERATE (To see how look at get_customer_info in queries/querystore.py)
#     - The tool will return the summary to agent and main agent displays the result to agent all under 10sec

# %%
await chat_with_trilink_agent_persistent("I'm a customer agent. Tell me who this customer is : C00086327")
# Out:
# User: I'm a customer agent. Tell me who this customer is : C00086327
# Warning: there are non-text parts in the response: ['thought_signature', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['thought_signature', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# TriLink Assistant: This customer is a 29-year-old with a young family, living in a low-crime neighborhood. They work from home and currently have active mobile and internet services.
#
# Here's a quick note for your conversation:
#
# *   **Mobile Data:** They are on a Limited 10GB plan. You might want to discuss their data usage and potential overage concerns.
# *   **Internet Speed:** Since they work from home, it's worth asking about their current internet experience.
# *   **Home Safety:** You can gently inquire about their home security needs.
#
# There are also some potential upgrade opportunities:
#
# *   **Mobile:** You could offer an upgrade to an **Unlimited Standard** plan ($70/month) to help with data overages, or **Unlimited Premium** ($90/month) which includes benefits like Disney+ and a hotspot.
# *   **Internet:** If their work-from-home demands are high, a **Premium Gig** plan (1000 Mbps at $100/month) might be beneficial.
# *   **Security:** Given their neighborhood, you could introduce **Smart Security** (doorbell + camera for $200 + free install) or **Complete Protection** ($30/month + $50 off equipment).
#
# Would you like me to generate a personalized retention script for them, or help with anything else?

# %% [markdown]
# - Agent in the call understood from customer that they are facing multiple overage charges
# - Agent uses ADK assistant for solution. ADK assistant agent uses get_business_solution_tool
# - This tool takes the agents question and find the most similar business solution from business_solution_embeddings table
# - This soltion is passed to main agent and then main agent presents the next best solution to solve the customers probelms for the agent. All in under 8 seconds
# - Very dynamic personalized issue resolution saving time and adding customer satisfaction and higher retention. This will increase the Lifetime value of customer at fraction of a cost also

# %%
await chat_with_trilink_agent_persistent("Customer experiencing multiple overage charges. WHat is the best nsolution for this")
# Out:
# User: Customer experiencing multiple overage charges. WHat is the best nsolution for this
# Warning: there are non-text parts in the response: ['thought_signature', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# TriLink Assistant: I understand the customer is experiencing multiple overage charges. Based on similar business problems, the general solution focuses on transparent pricing and understanding billing.
#
# For this specific customer, since they are on a Limited 10GB mobile plan and experiencing overage charges, the best solution would be to upgrade their mobile plan to an unlimited option. This will help them avoid future overage charges and provide more predictability in their monthly bill.
#
# I recommend offering them one of the following mobile plan upgrades:
#
# *   **Unlimited Standard** ($70/month): This plan would help them save on overages.
# *   **Unlimited Premium** ($90/month): This plan not only eliminates overages but also includes added benefits like Disney+ and a mobile hotspot.
#
# Would you like me to help you formulate a personalized message to offer this solution to the customer?

# %% [markdown]
# - Now agent is in a call with another customer. This customer have raised couple of tickets via app on their home security service
# - We have already ran the automated ticket handling process and the resolution for tickets is available in `database.active_customer_tickets` table
# - The query is passed by main agent to agent_assiatnt agent agin since this is a request from customer service. The agent_assistant uses get_diy_solution tool to pull the ticket resolution info an dpasses it to back agent_assistant
# - Agent assistant will look at each tickets and provide it in proper format for customer rep
# - Here the customer had 2 tickets. First ticket is complex and resolution says the technciain is on way
# - Seond ticket is DIY and the agent can help the customer to do it step by step following the instructions we pulled in

# %%
await chat_with_trilink_agent_persistent("Help me solve the home security tickets open for customer  : C00025032")
# Out:
# User: Help me solve the home security tickets open for customer  : C00025032
# Warning: there are non-text parts in the response: ['thought_signature', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# TriLink Assistant: I see two open home security tickets for customer C00025032.
#
# Let's go through them one by one. Which issue would you like to focus on first?
#
# **Ticket 1:**
# *   **Device:** Security Panel
# *   **Issue:** The touchscreen on the Security Panel is completely frozen, and none of the buttons are working.
# *   **Resolution:** A technician has been scheduled to visit the site soon to resolve this issue. They have all the details regarding the Security Panel problem and will ensure it's professionally resolved. Please let me know if you have any questions while the customer waits.
#
# **Ticket 2:**
# *   **Device:** Smoke Alarm
# *   **Issue:** All interconnected smoke alarms went off, and the customer can't figure out which one initiated the alert.
# *   **Resolution Mode:** We can troubleshoot this over the phone right now!
#
# Here are the step-by-step DIY instructions to help the customer identify which smoke alarm initiated the alert:
#
# 1.  **Look for the unique light:** Most modern interconnected smoke alarms will show a rapidly flashing red light or a steady red light on the specific alarm that first detected the issue. Ask the customer to walk through their home and observe each alarm carefully. The other alarms will usually flash differently or not at all, besides sounding.
# 2.  **Silence the alarm:** Once the customer finds the alarm with the unique light, ask them to press and hold its 'Hush' or 'Silence' button for a few seconds. This should quiet all the interconnected alarms.
# 3.  **Check for a cause:** With the alarms silenced, ask them to carefully look around the initiating alarm for any signs of smoke, steam, or anything that might have triggered it (e.g., cooking fumes).
# 4.  **Allow to clear and reset:** If there’s no real threat, the alarm should clear and reset itself once the air is fresh. If it doesn't, they might need to briefly remove the battery from that specific alarm to reset it.
# 5.  **Test the system:** Once everything is calm, ask the customer to press the 'Test' button on the initiating alarm to confirm it's working properly.
#
# Would you like me to walk you through these steps one at a time with the customer? Or do you need clarification on any specific step?

# %% [markdown]
# - Now another customer called in and they say they want to churn and leave
# - customer agent can ask the ADK agent how to save this customer from churn
# - ADK agent calls agent_assitant which uses the get_retention_call_script_mobile_query tool
# - This tool is an extension of the ML powered personzlied retention email, but designed to generate live call scripts for agent to follow
# - Now this tool using Bigquery AI have created personalized steps analyzing the customer model prediction, feature contribution, previous issues and create a hyperpresonalized callscript or agent to follow
# - Customer agent can now use this to continue the retention action
# - Odds of retention are much higher now that we understand what the problem for the customer is and have a tailored plan created to solve he problem for them all automatically and the customer agent gets this without the need for any technical expertise by just asking for this

# %%
await chat_with_trilink_agent_persistent("Provide me the live agent retention callscript for customer id : C00000025")
# Out:
# User: Provide me the live agent retention callscript for customer id : C00000025
# Warning: there are non-text parts in the response: ['thought_signature', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# TriLink Assistant: Here's a personalized retention call script for customer C00000025:
#
# **Customer Problem Identified:**
# This customer is a 70-year-old on an expensive, over-provisioned mobile plan ($75/month for Unlimited_Standard) that doesn't match their actual usage (0 data overages). This creates a significant perceived value gap. Despite their age, which typically lowers churn, their high household income and month-to-month contract make them financially capable and free to switch providers. Their relatively short tenure (1.33 years) further indicates a lack of strong loyalty. The core problem is a mismatch between the high cost of their plan and the value derived, making them susceptible to competitors offering more tailored or cost-effective solutions for individual, non-heavy data users.
#
# ---
#
# **Live Call Retention Script:**
#
# **(Agent picks up the call)**
#
# **Agent:** "Thank you for calling [Company Name], my name is [Agent Name]. I see you've been a valued customer with us for over a year now, 1.33 years to be exact, and we truly appreciate your loyalty. What brings you to call us today, [Customer Name]?"
#
# **(Listen actively. Allow the customer to explain fully. Show empathy with phrases like "I understand," or "That sounds frustrating.")**
#
# **Agent:** "Thank you for sharing that, [Customer Name]. I completely understand how important it is to feel you're getting the best value for your services, especially as a long-standing customer. Let me take a look at your account right now and see how I can help you save money and make your services work even better for you."
#
# **(Pause for a few seconds as if reviewing the account)**
#
# **Agent:** "Okay, [Customer Name], I'm looking at your current mobile plan, the Unlimited Standard, which is $75 a month. I also see you're consistently using very little data – in fact, you’ve had zero data overages. While that’s great, it tells me you might be paying for more data than you actually need. My main goal right now is to ensure you're not spending a dollar more than you have to."
#
# **Agent:** "We actually have a special plan specifically designed for our senior customers, like yourself, who primarily use their phone for essential calls and messages. It's called our Limited 5GB plan, and it's only $35 a month. Switching to this would save you a remarkable $40 every single month! It still includes unlimited talk and text, so you can stay connected without any worries. How does the idea of saving $40 each month sound to you?"
#
# **(Pause for customer response. Address any immediate questions or concerns.)**
#
# **Agent:** "And to make things even simpler and more convenient, this senior-friendly plan comes with fantastic benefits such as simplified billing, priority access to our dedicated senior customer support, and we can even explore options like a large-button phone if that would be helpful. Plus, it includes an option for medical alert integration through the mobile app, offering extra peace of mind."
#
# **(Transition to Value Reinforcement)**
#
# **Agent:** "You've been with us for a significant time, [Customer Name], and we truly value having you as part of the [Company Name] family. We want to ensure you always feel appreciated, and part of that is making sure your services are perfectly tailored to your needs and budget. This new mobile plan is a great way to do exactly that."
#
# **(Transition to Strategic Cross-Sell - Security)**
#
# **Agent:** "Now, [Customer Name], since we're looking at ways to enhance your overall experience and peace of mind, I also noticed something else. Your home is in an area with a crime rate of 1.1, and I don't see any home security services currently on your account. Many of our customers, especially those living alone, find a lot of comfort in knowing their home is secure."
#
# **Agent:** "We have options like our Smart Security doorbell and camera system, which is a great visual deterrent and lets you see who’s at your door from anywhere. Or, for comprehensive safety, our Complete Protection package offers full monitoring for $30 a month. To help you get started with ensuring your safety, if you're interested in adding either of these, I can offer you $50 off the equipment right away."
#
# **(Offer and Close)**
#
# **Agent:** "So, to recap, my primary recommendation is to switch you to our Limited 5GB mobile plan for just $35/month, which saves you $40 monthly, and includes those beneficial senior-friendly features. Additionally, if the idea of a more secure home appeals to you, we can get you started with a security solution today with $50 off the equipment. How would you like to proceed with that mobile plan adjustment first, and then we can discuss the security options further?"
#
# **Agent:** "This change to your mobile plan will be effective immediately, and you’ll see the savings reflected on your very next bill. For the security, we can schedule a consultation or installation at your convenience. What sounds best for you today?"

# %% [markdown]
# ##### Create a session for the Technician where they will use this ADK app powered by BigQuery tools for assistance on demand

# %%
# Constants
APP_NAME = "trilink_app"
USER_ID = "tech002"

# Create InMemoryRunner with BOTH agent and app_name
runner = InMemoryRunner(agent=trilink_agents, app_name=APP_NAME)

# Create a session using the runner's session service
session = await runner.session_service.create_session(
    app_name=APP_NAME,  # This must match the app_name used in InMemoryRunner
    user_id=USER_ID
)

PERSISTENT_SESSION_ID = session.id

async def chat_with_trilink_agent_persistent(query: str):
    """Use persistent session to maintain conversation history"""
    print(f"User: {query}")
    
    user_content = types.Content(
        role='user', 
        parts=[types.Part(text=query)]
    )
    
    final_response = ""
    async for event in runner.run_async(
        user_id=USER_ID, 
        session_id=PERSISTENT_SESSION_ID,  # Now this session exists
        new_message=user_content
    ):
        if event.is_final_response() and event.content:
            final_response = event.content.parts[0].text
            
    print(f"TriLink Assistant: {final_response}")
    # return final_response

# %% [markdown]
# - Technician asks for all the tickets he have open in a city
# - Main agent gives task to technician_assistant sub agent filters for tickets assigned to technician in the city that needs agent visit from `database.active_customer_tickets`
# - Creates a proper formatted report for each ticket and actions from techncian report created

# %%
await chat_with_trilink_agent_persistent("I am technician. ID:tech002...Give me details of all the tickets open for me in toronto ")
# Out:
# User: I am technician. ID:tech002...Give me details of all the tickets open for me in toronto
# Warning: there are non-text parts in the response: ['thought_signature', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['thought_signature', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# TriLink Assistant: **Brief Overview:**
# There is a high-urgency security system issue where the panel displays 'Device Fault', and three medium-urgency camera-related issues: one requiring an outdoor camera to be repositioned due to an obstruction, another with an outdoor camera showing flickering video feed, and a video doorbell with a fogged-up lens.
#
# **Ticket TICKET_005:**
# - **Device Affected:** security system
# - **Urgency Level:** 5/5
# - **Location:** Toronto, M6G 0L8
# - **Issue Description:** I can't arm my system. The panel says 'Device Fault' but doesn't tell me which sensor is the problem. All my doors and windows are closed. This just started happening today.
# - **Technician Report:**
#   Customer (58, Empty_Nest, working from home in a Toronto Townhouse, Postal: M6G 0L8) is unable to arm their security system due to a 'Device Fault' message displayed on the panel/app. The system does not specify which sensor is causing the problem, despite the customer confirming all doors and windows are closed. This issue began today.
#
#   Issue verification: Confirm 'Device Fault' message and inability to arm the system. Attempt to access the system's diagnostic menu or fault log to identify the specific faulty device. Perform a full walk-test of all zones if system diagnostics are unspecific.
#   Severity: Medium (Security system compromised).
#   Required tools and parts: Security system diagnostic tool, multimeter, various sensor batteries (e.g., CR2032, AA, AAA, 12V), common replacement sensors (door/window contact, motion detector), small electronics screwdriver set.
#   Step-by-step repair actions:1. Verify the 'Device Fault' message on the customer's panel/app and confirm the inability to arm the system.2. Access the security system's main panel or technician interface to retrieve detailed fault codes or status for all connected devices.3. Identify the specific sensor or device causing the 'Device Fault'. If not immediately apparent, perform a comprehensive walk-test of all installed sensors to pinpoint the non-responsive or faulty unit.4. Once the faulty device is identified, troubleshoot it by: a. Checking and replacing its battery. b. Inspecting for any physical damage, misalignment, or obstruction. c. Verifying wireless signal strength or wired connections.5. If troubleshooting steps fail, replace the faulty sensor/device with a new one and re-enroll it into the system.6. Conduct a full system test, including arming/disarming cycles and a complete walk-test, to ensure all zones are functioning correctly and the system can be armed without issues.7. Review basic system status checking with the customer to help them identify future minor issues.
#   Estimated time: 1.5 - 2 hours.
#
# ---
#
# **Ticket TICKET_067:**
# - **Device Affected:** camera
# - **Urgency Level:** 4/5
# - **Location:** Toronto, M2D 8N4
# - **Issue Description:** My outdoor camera view is blocked by a large tree branch that grew over the summer. I need the camera moved a few feet to the left.
# - **Technician Report:**
#   Customer context: Customer is 36 years old, part of a Young_Family, and owns a Single_Family home in Toronto (M2D 8N4). They work from home. Issue verification: The customer's outdoor camera, identified as 'Front Yard Cam', has its view obstructed by a large tree branch that grew over the summer. The customer has requested the camera be moved a few feet to the left to restore a clear line of sight. Severity: Medium. Required tools and parts: Standard technician toolkit including various screwdrivers (Phillips, flathead), power drill with appropriate bits, mounting hardware (screws, wall anchors if applicable), cable management clips/ties, and a ladder for elevated access. Step-by-step repair actions: 1. Upon arrival, confirm the specific outdoor camera ('Front Yard Cam') and verify the obstruction by checking the live view with the customer. 2. Discuss with the customer the preferred new mounting location, a few feet to the left, ensuring the new position offers a clear, unobstructed view and is within cable reach. 3. Carefully disconnect the camera from its power source. 4. Using appropriate tools, safely unmount the camera from its current position, taking care not to damage the camera or the mounting surface. 5. Prepare the new mounting surface, drilling pilot holes if necessary, and secure the camera mounting bracket. 6. Mount the camera at the new location, ensuring it is level and securely fastened. 7. Reconnect the camera to its power source and check the live feed on the customer's app to adjust the camera's angle for optimal coverage. 8. Neatly route and secure any exposed cables to prevent damage and maintain aesthetics. 9. Confirm with the customer that the camera view is clear and meets their expectations. Estimated time: Approximately 45 minutes.
#
# ---
#
# **Ticket TICKET_018:**
# - **Device Affected:** camera
# - **Urgency Level:** 4/5
# - **Location:** Toronto, M0F 8F7
# - **Issue Description:** My outdoor camera's video feed is flickering like an old TV, with horizontal lines running through it. It's getting worse.
# - **Technician Report:**
#   Customer is 40 years old, Established_Family, located in Toronto (Postal: M0F 8F7). Single_Family home with work from home setup. Issue verification: Outdoor camera video feed exhibiting severe flickering and horizontal lines, consistent with customer report. Image quality is severely degraded, rendering the camera ineffective for security monitoring. Severity: High. Required tools and parts: Ladder (if mounted high), Multimeter, Cable tester, Replacement outdoor camera unit, Mounting hardware, Basic hand tools (screwdriver set, wire strippers), Electrical tape/weatherproofing supplies. Step-by-step repair actions: 1. Inspect physical connection of the camera for loose cables or damage. 2. Test power supply to the camera using a multimeter for stable voltage. 3. Test data cable for continuity and integrity using a cable tester. 4. If power/data issues are confirmed, repair or replace faulty wiring/power adapter. 5. If connections are sound, troubleshoot camera settings via app/NVR to rule out software glitches (e.g., resolution, frame rate). 6. If problem persists after checking connections and software, replace the outdoor camera unit. 7. Securely mount and weatherproof the new camera. 8. Configure and test the new camera's functionality, ensuring clear video feed. Estimated time: 1.5 - 2.5 hours
#
# ---
#
# **Ticket TICKET_038:**
# - **Device Affected:** video doorbell
# - **Urgency Level:** 4/5
# - **Location:** Toronto, M3H 8B6
# - **Issue Description:** The camera lens on my video doorbell is fogged up on the inside. It happens every morning when it's cool and humid. The image is useless until it burns off midday.
# - **Technician Report:**
#   Customer is 36 years old, part of a Young_Family, located in Toronto (Postal: M3H 8B6). They own a Single_Family home and do not work from home. Issue verification: The Trilinlk video doorbell camera lens is fogged up internally every morning during cool, humid conditions, making the video feed unusable until midday. This is a recurring issue indicating a compromised seal or internal moisture. Severity: Medium. Required tools and parts: New video doorbell unit (Trilinlk compatible), small screwdriver set, wire cutters/strippers, multimeter for power verification, sealant (if needed for weatherproofing). Step-by-step repair actions: 1. Confirm appointment with customer at Toronto (M3H 8B6) residence. 2. Upon arrival, visually confirm the internal fogging of the existing Trilinlk video doorbell's camera lens. 3. Power off the doorbell at the breaker. 4. Carefully remove the existing faulty doorbell unit, disconnecting the wiring. 5. Inspect the wiring and mounting area for any signs of moisture or damage. 6. Install the new, replacement Trilinlk video doorbell unit, ensuring proper electrical connections and secure mounting. 7. Apply appropriate sealant around the unit if necessary to prevent future moisture ingress. 8. Restore power and configure the new doorbell with the customer's account/app. 9. Test the camera's live view, motion detection, and two-way audio functionality to ensure full operation. 10. Advise the customer on best practices for outdoor device care. Estimated time: 60 minutes.

# %% [markdown]
# - Technician now wants some help on understanding what the problem could be in first ticket
# - Tehnciain asks the main agent what issue could be about
# - Mian agent routes to technciain assistant which uses get_tech_solution tool
# - This tool looks at the `database.device_problem_solution_embeddings` and returns the solutions other techncians have added for similar issues using VECTOR_SEARCH
# - The solution is then returne back to the technician

# %%
await chat_with_trilink_agent_persistent(" Outdoor camera video feed exhibiting severe flickering and horizontal lines. Image quality is severely degraded, rendering the camera ineffective for security monitoring. What could be the possible solutions for this? ")
# Out:
# User:  Outdoor camera video feed exhibiting severe flickering and horizontal lines. Image quality is severely degraded, rendering the camera ineffective for security monitoring. What could be the possible solutions for this?
# Warning: there are non-text parts in the response: ['thought_signature', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['thought_signature', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# TriLink Assistant: **Knowledge Base Match Found:**
# - **Similar Issue:** trilink outdoor camera has a blurry or foggy image, especially at night.
# - **Similarity Score:** 0.2359
# - **Recommended Solution Steps:**
#     1. Cleaned the camera's outer lens dome with a microfiber cloth. The image remained foggy.
#     2. Powered down the camera.
#     3. Carefully unscrewed the outer dome/casing.
#     4. Found moisture had gotten inside the housing, causing condensation on the inner lens.
#     5. Used a lint-free cloth to gently dry the inside of the dome and the camera lens.
#     6. Inspected the rubber gasket seal around the housing. It was cracked and brittle from sun exposure.
#     7. Replaced the weatherproof gasket with a new one.
#     8. Reassembled the camera housing, ensuring a tight seal.
#     9. Powered the camera back on and verified the image was clear in both day and night (IR) mode.
# - **Technician Notes:** Weather seals on outdoor cameras degrade over time. A compromised seal is the most common cause of internal condensation. Replacing the gasket is critical for a long-term fix.
# - **Suggested Next Actions:**
#     1. **Power down the camera** to prevent any potential electrical damage.
#     2. **Carefully inspect the camera's outer casing and lens for any visible condensation or signs of moisture intrusion.**
#     3. **If moisture is suspected, gently open the camera housing.**
#     4. **Using a lint-free cloth, thoroughly dry any moisture found on the inner lens or internal components.**
#     5. **Examine the weatherproof gasket seal around the camera housing.** If it's cracked, brittle, or shows signs of wear, replace it to ensure a proper seal against the elements.
#     6. **Reassemble the camera, making sure all seals are properly seated and the housing is secured tightly.**
#     7. **Power on the camera** and observe if the flickering and horizontal lines have been resolved.
#
# If the issue persists after addressing potential moisture, consider checking the camera's power supply and network connection, as these can also contribute to video degradation.
